# %% [markdown]
# # riot api 활용

# %%
import bs4
import pandas as pd
import requests
import cx_Oracle
import pymysql
import my_utils as mu
from tqdm import tqdm
import numpy as np

# %%
riot_api_key = 'RGAPI-45acd7cf-59a4-495d-ba1f-08133475f074'

# %%
url = f'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={riot_api_key}'

# %%
res = requests.get(url).json()

# %%
res.keys()
# Out:
# dict_keys(['tier', 'leagueId', 'queue', 'name', 'entries'])

# %%
res['entries'][0]['summonerId']
# Out:
# '3QK_xiWjybX10lo8_F3FcPWbSZ7Kznyv5FlP3zawham_X8M'

# %%
# 1번
lst = []
for i in range(len(res['entries'])):
    lst.append(res['entries'][i]['summonerId'])

# %%
lst
# Out:
# ['3QK_xiWjybX10lo8_F3FcPWbSZ7Kznyv5FlP3zawham_X8M',
#  'LXI9Hth3kbpUO8I3MG_tAXV0o2ng-5PDRE_eKpkcl7WDDDY',
#  'UHed6vTJPDqDQMASpQDgmSGYSanAHR7_MkLUMIQhQjxasUg',
#  'FGjBFXpFMyfwDogLJd-evau1_Noy9VWDMdZ4PbLiVxMMXgCA-aP4jkwnbQ',
#  'UWUIXdHwcmxjeAZKH7Pup-HhXJA8K-PZNAofEEjUKesnv14',
#  'bvB2IzBg67VpDy0yoHs1_YCw3OM0R8OWxoBGY-vMGR-7U_A',
#  'Nwl946HMIP9kx_ZQXYjQ58KK76NZ6VFJrxgk-GgokZ6Mougm',
#  '2NS_0OgvdOIxdQO8Wnn5YKzTXvr5inJ9EfX7crtxlIHH7Xya',
#  'k0ZguB1vs8NBYEoIG9c-zjOvxh1B8Fet-z6wD6feCEPDptA',
#  'sFYgtV3MIRmt7cfwQ5Mnyk9QNczbc1TzD-pYqNvhOD7MRlmk3X7JyzN8nA',
#  'KYHNPlzF9tgH0r7dM1-a5ZqJ91ciORQ5ocjLNJCsx30iPg',
#  'avtpjxV_7M2BFPfmPx63SiHTdtOkhUFKQH8hiQ-7kYlEJY67pwDuWkKnTg',
#  'QCm3rrN17OPMhqH-A4RYDyD0XGT5RSg6e8JCnV3hImIZJlS2pIlNPQkYGg',
#  '_37saB-EotCMWXybM0NgcH6ilaVJCnF3545r21nhfZvVMvU',
#  'PkiIImY0uGntEcsxNoclZwm_yTT-ZmYJryJ1i8L7Iod2emw',
#  '4EJ7ZBvnBUvXY8iM7XI2Nn-IkeRh6SQaVCDQ1riaHADkHc8',
#  'irnmBdfdATCBsKUqHM_xnLrMpYgBSxQfR6JXPzlvLT898EMel3LRuzaXWw',
#  'vTi7NA9wVsT-mh9TdtigkBsTjygsrM8tyOC5AqhZps6fVpVHIKd4d3-yBw',
#  'ZlhbABgGBw5Lx9gY0MZZV8ol7zdrpSIOvmNuf2eQy6AMtpo',
#  'mpF8Nn-3LnxLyE-jtXepXbpHjSqu2zMd_WdpdBNEOpv0RC0',
#  'P-FYPsg6qSlc-BNxAxp8FKI9Igan4-RZ74PnQCj0O24aiwV0tKbeXzfgDA',
#  'mQtCSt5o0NstR5U5KsM9rVECHs8i5Iz_bRErr78Ivgs8ipg',
f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{res3["puuid"]}/ids?type=ranked&start=0&count=100&api_key={riot_api_key}'

# %%
res4 = requests.get(url3).json()

# %%
res4[0]
# Out:
# 'KR_6403575108'

# %%
url4 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{res4[0]}?api_key={riot_api_key}'

# %%
matches = requests.get(url4).json()

# %%
matches
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6403575108',
#   'participants': ['Z-LPaYwfPtnMOF_dnCFyExE-IwmHX-0FC-jYH1ohO7Bnh40hq0cB_Lo_4uDIezeKjq7EBCcDSYmTSw',
#    'coMdLdZ6jx4rzI0W3EMzKEjrf0xUzrgXswSDN7zkjBy5s0yuWIuxC_wE9rQMiQ7-c2W5xZRrmpYyTA',
#    'a-tB2hJidodN77cs_gNbJrHuu8N-IBXpH7bu36rTpnTrDFwuRI0LhxxjdZD1VbOLkenfD2KvCkbpYQ',
#    'MCHwZK8au_E3j7yP2cMCwHCZjKNwhiuw64sZREqwkIJwHk7GDj0i8bES_bvHcjq2Y-CgWIR3wx0IWQ',
#    'xuIaA6BjamGWUnZ3yKhC7gveQtbbneOHr3Rdwh3ET99zwZhqa88rB_wTKJdrSZK1BQyIKObqShwQew',
#    'aYBC3BUwltuGr-3XlyXefEHLoz0JQE3o7EA0q_DpC1Sv6eHcgpJa3wDa2jVeJFv6_lYFdIimRy4fWw',
#    'TXRwr3PukyRX-ZpC-OlcGpqmf60Iz8q5TJ678rmouL9EVW3IOgfzDYYn7BKqv8LOl2U3UHkHMI4bBg',
#    'fD3JUAYc6mFSnJtAJpdYoVgjyRH8oI8V4OFDl6ZkF0FcK5yWWxHk1IKMWpeQu9gy9EAOBgdtKOMOsw',
#    'pUVDNdZqLcEtLz19SfhvUg0p3PcoZ-WKMgElkqH2I-Rf_f_nH4V20QA7AhfxcQgp4u6szRrtdkJqBA',
#    'y32QkHYFwYmPrURqgQaJY-Tq38CihFNE1DgSBIvFXot1URAAgnK_qj-07uAM0_vKunhlKtro_f0jBw']},
#  'info': {'gameCreation': 1678651762223,
#   'gameDuration': 1820,
#   'gameEndTimestamp': 1678653608786,
#   'gameId': 6403575108,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-6403575108',
#   'gameStartTimestamp': 1678651788174,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '13.5.495.8836',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 14,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 405,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 685.1657087639934,
#      'damageTakenOnTeamPercentage': 0.24930911463750083,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 6,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 422.5719299316406,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 95,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1820.646644280887,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 378.09974676780104,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 13,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.7142857142857144,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.48717948717948717,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 5,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 67,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 6,
#      'maxKillDeficit': 10,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6662,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 17,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 10.679791099846852,
#      'skillshotsDodged': 38,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 5,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 19,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 1,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.15792826097038623,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 8,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.2991214394569397,
#      'visionScorePerMinute': 0.46032818168846884,
#      'wardTakedowns': 4,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 15556,
#     'champLevel': 16,
#     'championId': 897,
#     'championName': 'KSante',
#     'championTransform': 0,
#     'commandPings': 13,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 2920,
#     'damageDealtToObjectives': 2920,
#     'damageDealtToTurrets': 2920,
#     'damageSelfMitigated': 42663,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 6,
#     'enemyVisionPings': 2,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11473,
#     'goldSpent': 10350,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 6662,
#     'item1': 1028,
#     'item2': 3075,
#     'item3': 1057,
#     'item4': 3066,
#     'item5': 3111,
#     'item6': 3364,
#     'itemsPurchased': 21,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'TOP',
#     'largestCriticalStrike': 32,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 597,
#     'magicDamageDealt': 10622,
#     'magicDamageDealtToChampions': 2629,
#     'magicDamageTaken': 16756,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 9,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8437, 'var1': 1783, 'var2': 1029, 'var3': 0},
#         {'perk': 8446, 'var1': 2257, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 2401, 'var2': 0, 'var3': 0},
#         {'perk': 8451, 'var1': 250, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 100429,
#     'physicalDamageDealtToChampions': 16888,
#     'physicalDamageTaken': 15676,
#     'profileIcon': 5257,
#     'pushPings': 0,
#     'puuid': 'Z-LPaYwfPtnMOF_dnCFyExE-IwmHX-0FC-jYH1ohO7Bnh40hq0cB_Lo_4uDIezeKjq7EBCcDSYmTSw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 233,
#     'spell2Casts': 40,
#     'spell3Casts': 123,
#     'spell4Casts': 9,
#     'summoner1Casts': 6,
#     'summoner1Id': 6,
#     'summoner2Casts': 5,
#     'summoner2Id': 12,
#     'summonerId': 'nSgS7ahPD2hvZen-ar8vtGdETjQY37KKC54h3RDio646GWE',
#     'summonerLevel': 222,
#     'summonerName': '꺾여가는 마음',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 57,
#     'timePlayed': 1820,
#     'totalDamageDealt': 128989,
#     'totalDamageDealtToChampions': 20790,
#     'totalDamageShieldedOnTeammates': 422,
#     'totalDamageTaken': 35681,
#     'totalHeal': 3228,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 175,
#     'totalTimeCCDealt': 2100,
#     'totalTimeSpentDead': 237,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 17937,
#     'trueDamageDealtToChampions': 1272,
#     'trueDamageTaken': 3247,
#     'turretKills': 1,
#     'turretTakedowns': 4,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 13,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 4,
#     'wardsPlaced': 5,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 23,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 242,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 76.00000008940697,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.13783318660010002,
#      'controlWardsPlaced': 3,
#      'damagePerMinute': 530.849507803169,
#      'damageTakenOnTeamPercentage': 0.24761430194178818,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 5329.81005859375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 39,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1820.646644280887,
#      'goldPerMinute': 341.6055874213324,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 17,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 48.00000008940697,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.166666666666667,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.6410256410256411,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnLanersEarlyJungleAsJungler': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 5,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 4.000000029802322,
#      'maxKillDeficit': 10,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': -30.500000089406967,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6667,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 24,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 3,
#      'scuttleCrabKills': 1,
#      'shortestTimeToAceFromFirstTakedown': 10.679791099846852,
#      'skillshotsDodged': 20,
#      'skillshotsHit': 7,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 3,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 6,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 25,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.12235892504833083,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 1,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.5830670595169067,
#      'visionScorePerMinute': 0.6157943480086268,
#      'wardTakedowns': 6,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 0},
#     'champExperience': 14004,
#     'champLevel': 15,
#     'championId': 113,
#     'championName': 'Sejuani',
#     'championTransform': 0,
#     'commandPings': 10,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 932,
#     'damageDealtToObjectives': 2514,
#     'damageDealtToTurrets': 932,
#     'damageSelfMitigated': 49019,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10365,
#     'goldSpent': 9325,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 4401,
#     'item1': 0,
#     'item2': 6667,
#     'item3': 1028,
#     'item4': 3082,
#     'item5': 3047,
#     'item6': 3364,
#     'itemsPurchased': 23,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 298,
#     'magicDamageDealt': 26335,
#     'magicDamageDealtToChampions': 7468,
#     'magicDamageTaken': 14274,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 83,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 4,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5002, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 1067, 'var2': 1046, 'var3': 0},
#         {'perk': 8463, 'var1': 3479, 'var2': 0, 'var3': 0},
#         {'perk': 8429, 'var1': 60, 'var2': 17, 'var3': 15},
#         {'perk': 8451, 'var1': 197, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9111, 'var1': 2275, 'var2': 500, 'var3': 0},
#         {'perk': 9105, 'var1': 15, 'var2': 20, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 71637,
#     'physicalDamageDealtToChampions': 7748,
#     'physicalDamageTaken': 19086,
#     'profileIcon': 5663,
#     'pushPings': 0,
#     'puuid': 'coMdLdZ6jx4rzI0W3EMzKEjrf0xUzrgXswSDN7zkjBy5s0yuWIuxC_wE9rQMiQ7-c2W5xZRrmpYyTA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 70,
#     'spell2Casts': 101,
#     'spell3Casts': 62,
#     'spell4Casts': 9,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 15,
#     'summoner2Id': 11,
#     'summonerId': 'jKahXNKiqKpWCIymearvm3cMF0gsfDu7941QdUPVyo8NdFyk1Q4DtULlmg',
#     'summonerLevel': 344,
#     'summonerName': 'AfreecaTV 양만득',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 41,
#     'timePlayed': 1820,
#     'totalDamageDealt': 121299,
#     'totalDamageDealtToChampions': 16108,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 35438,
#     'totalHeal': 17081,
#     'totalHealsOnTeammates': 5329,
#     'totalMinionsKilled': 31,
#     'totalTimeCCDealt': 304,
#     'totalTimeSpentDead': 148,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 23326,
#     'trueDamageDealtToChampions': 891,
#     'trueDamageTaken': 2078,
#     'turretKills': 2,
#     'turretTakedowns': 5,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 18,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 6,
#     'wardsPlaced': 6,
#     'win': True},
#    {'allInPings': 1,
#     'assistMePings': 0,
#     'assists': 14,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 415,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.10847121461517326,
#      'controlWardsPlaced': 7,
#      'damagePerMinute': 788.4613396546769,
#      'damageTakenOnTeamPercentage': 0.17329163679969603,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 6,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestDragonTakedown': 1153.4961382439112,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 917.2175903320312,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 33,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1820.646644280887,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 424.4975602605259,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 6,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 1,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.142857142857143,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.5641025641025641,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 7,
#      'landSkillShotsEarlyGame': 5,
#      'laneMinionsFirst10Minutes': 64,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 1,
#      'maxKillDeficit': 10,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6692,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 20,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 10.679791099846852,
#      'skillshotsDodged': 35,
#      'skillshotsHit': 33,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 6,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.181737536805035,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 7,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.6295549273490906,
#      'visionScorePerMinute': 0.6219833398481562,
#      'wardTakedowns': 4,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14350,
#     'champLevel': 15,
#     'championId': 64,
#     'championName': 'LeeSin',
#     'championTransform': 0,
#     'commandPings': 10,
#     'consumablesPurchased': 9,
#     'damageDealtToBuildings': 5484,
#     'damageDealtToObjectives': 11953,
#     'damageDealtToTurrets': 5484,
#     'damageSelfMitigated': 23602,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 7,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 8,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 5,
#     'goldEarned': 12881,
#     'goldSpent': 11550,
#     'holdPings': 1,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 3026,
#     'item1': 2055,
#     'item2': 6692,
#     'item3': 3071,
#     'item4': 0,
#     'item5': 3111,
#     'item6': 3340,
#     'itemsPurchased': 29,
#     'killingSprees': 4,
#     'kills': 8,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 390,
#     'magicDamageDealt': 55125,
#     'magicDamageDealtToChampions': 5346,
#     'magicDamageTaken': 15753,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 1,
#     'onMyWayPings': 9,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 398, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 1857, 'var2': 440, 'var3': 0},
#         {'perk': 9104, 'var1': 15, 'var2': 20, 'var3': 0},
#         {'perk': 8299, 'var1': 793, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8444, 'var1': 1012, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 96, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 80514,
#     'physicalDamageDealtToChampions': 17812,
#     'physicalDamageTaken': 8313,
#     'profileIcon': 7,
#     'pushPings': 0,
#     'puuid': 'a-tB2hJidodN77cs_gNbJrHuu8N-IBXpH7bu36rTpnTrDFwuRI0LhxxjdZD1VbOLkenfD2KvCkbpYQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 181,
#     'spell2Casts': 109,
#     'spell3Casts': 113,
#     'spell4Casts': 12,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 14,
#     'summonerId': 'N8UZh2deFJ1M3ITu_llhb1uOx5s_AJk3RMF2tn3WA5MTXRYdgv6x2LqlTQ',
#     'summonerLevel': 81,
#     'summonerName': 'FA R0se',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 24,
#     'timePlayed': 1820,
#     'totalDamageDealt': 142727,
#     'totalDamageDealtToChampions': 23925,
#     'totalDamageShieldedOnTeammates': 917,
#     'totalDamageTaken': 24801,
#     'totalHeal': 5345,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 171,
#     'totalTimeCCDealt': 398,
#     'totalTimeSpentDead': 198,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 7087,
#     'trueDamageDealtToChampions': 766,
#     'trueDamageTaken': 735,
#     'turretKills': 1,
#     'turretTakedowns': 5,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 18,
#     'visionWardsBoughtInGame': 8,
#     'wardsKilled': 4,
#     'wardsPlaced': 13,
#     'win': True},
#    {'allInPings': 4,
#     'assistMePings': 25,
#     'assists': 13,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 11,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 261,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 11.000000029802322,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1450,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 3,
#      'damagePerMinute': 1919.9174430580613,
#      'damageTakenOnTeamPercentage': 0.16477490004669088,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 2,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 1153.4961382439112,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 8,
#      'enemyJungleMonsterKills': 4,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 1,
#      'epicMonsterStolenWithoutSmite': 1,
#      'fastestLegendary': 1763.4556940611792,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1820.646644280887,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 718.2547850074479,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.375,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.8974358974358975,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 5,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 66,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 1,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 67.79999995231628,
#      'maxKillDeficit': 10,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 7,
#      'multikillsAfterAggressiveFlash': 1,
#      'mythicItemUsed': 6672,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 7,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 33,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'shortestTimeToAceFromFirstTakedown': 10.679791099846852,
#      'skillshotsDodged': 18,
#      'skillshotsHit': 38,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 35,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 8,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.4425341477404718,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 12,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.20086556673049927,
#      'visionScorePerMinute': 0.9415781616302565,
#      'wardTakedowns': 8,
#      'wardTakedownsBefore20M': 4,
#      'wardsGuarded': 0},
#     'champExperience': 16580,
#     'champLevel': 17,
#     'championId': 222,
#     'championName': 'Jinx',
#     'championTransform': 0,
#     'commandPings': 18,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 10607,
#     'damageDealtToObjectives': 10947,
#     'damageDealtToTurrets': 10607,
#     'damageSelfMitigated': 19870,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 5,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 3,
#     'enemyVisionPings': 4,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 10,
#     'goldEarned': 21794,
#     'goldSpent': 18175,
#     'holdPings': 1,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 6672,
#     'item1': 3156,
#     'item2': 3072,
#     'item3': 3031,
#     'item4': 3094,
#     'item5': 3006,
#     'item6': 3363,
#     'itemsPurchased': 28,
#     'killingSprees': 4,
#     'kills': 22,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 991,
#     'largestKillingSpree': 11,
#     'largestMultiKill': 4,
#     'longestTimeSpentLiving': 330,
#     'magicDamageDealt': 3591,
#     'magicDamageDealtToChampions': 1333,
#     'magicDamageTaken': 15868,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 23,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 1,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 102,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 162, 'var2': 23, 'var3': 0},
#         {'perk': 8009, 'var1': 3908, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 16, 'var2': 30, 'var3': 0},
#         {'perk': 8017, 'var1': 4192, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 20, 'var2': 10, 'var3': 0},
#         {'perk': 8236, 'var1': 28, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 243373,
#     'physicalDamageDealtToChampions': 49752,
#     'physicalDamageTaken': 6754,
#     'profileIcon': 5464,
#     'pushPings': 1,
#     'puuid': 'MCHwZK8au_E3j7yP2cMCwHCZjKNwhiuw64sZREqwkIJwHk7GDj0i8bES_bvHcjq2Y-CgWIR3wx0IWQ',
#     'quadraKills': 1,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 164,
#     'spell2Casts': 61,
#     'spell3Casts': 24,
#     'spell4Casts': 12,
#     'summoner1Casts': 7,
#     'summoner1Id': 6,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'aWeonYKYElQj-ET2Dh0q5NoMYAsAvVeP0X3oROj7_Jzg2Xo',
#     'summonerLevel': 320,
#     'summonerName': 'Fatty',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 28,
#     'timePlayed': 1820,
#     'totalDamageDealt': 266471,
#     'totalDamageDealtToChampions': 58258,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23582,
#     'totalHeal': 8651,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 268,
#     'totalTimeCCDealt': 192,
#     'totalTimeSpentDead': 196,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 19507,
#     'trueDamageDealtToChampions': 7171,
#     'trueDamageTaken': 959,
#     'turretKills': 2,
#     'turretTakedowns': 5,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 28,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 8,
#     'wardsPlaced': 10,
#     'win': True},
#    {'allInPings': 2,
#     'assistMePings': 16,
#     'assists': 32,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 2,
#      'abilityUses': 237,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 1,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.17479293273514093,
#      'controlWardsPlaced': 6,
#      'damagePerMinute': 414.0676829675324,
#      'damageTakenOnTeamPercentage': 0.16501004657432408,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 1153.4961382439112,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 9109.810546875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 45,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fasterSupportQuestCompletion': 1,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1820.646644280887,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 306.1420543393805,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 18,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.25,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.8717948717948718,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 14,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 2,
#      'maxKillDeficit': 10,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 2065,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 32,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 9,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 10.679791099846852,
#      'skillshotsDodged': 30,
#      'skillshotsHit': 25,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 35,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 34,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 9,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.09544112943577615,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.17083555459976196,
#      'visionScorePerMinute': 2.6339161517645437,
#      'wardTakedowns': 10,
#      'wardTakedownsBefore20M': 4,
#      'wardsGuarded': 1},
#     'champExperience': 12885,
#     'champLevel': 14,
#     'championId': 497,
#     'championName': 'Rakan',
#     'championTransform': 0,
#     'commandPings': 27,
#     'consumablesPurchased': 8,
#     'damageDealtToBuildings': 307,
#     'damageDealtToObjectives': 307,
#     'damageDealtToTurrets': 307,
#     'damageSelfMitigated': 23132,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 7,
#     'enemyVisionPings': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 17,
#     'goldEarned': 9289,
#     'goldSpent': 7900,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3860,
#     'item1': 2065,
#     'item2': 0,
#     'item3': 1057,
#     'item4': 3111,
#     'item5': 3011,
#     'item6': 3364,
#     'itemsPurchased': 25,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 478,
#     'magicDamageDealt': 14059,
#     'magicDamageDealtToChampions': 8821,
#     'magicDamageTaken': 14901,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 39,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8465, 'var1': 2510, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 1089, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 829, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 64, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8136, 'var1': 11, 'var2': 30, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 6138,
#     'physicalDamageDealtToChampions': 2585,
#     'physicalDamageTaken': 8071,
#     'profileIcon': 5659,
#     'pushPings': 0,
#     'puuid': 'xuIaA6BjamGWUnZ3yKhC7gveQtbbneOHr3Rdwh3ET99zwZhqa88rB_wTKJdrSZK1BQyIKObqShwQew',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 34,
#     'spell2Casts': 70,
#     'spell3Casts': 123,
#     'spell4Casts': 10,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 8,
#     'summoner2Id': 14,
#     'summonerId': 'penV32D6RvY4pKPJNhOyo8YLWF1J9Zp1XHSfXju5AfbxxY8',
#     'summonerLevel': 555,
#     'summonerName': 'Honpi',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 47,
#     'timePlayed': 1820,
#     'totalDamageDealt': 27153,
#     'totalDamageDealtToChampions': 12564,
#     'totalDamageShieldedOnTeammates': 6054,
#     'totalDamageTaken': 23616,
#     'totalHeal': 6683,
#     'totalHealsOnTeammates': 3055,
#     'totalMinionsKilled': 34,
#     'totalTimeCCDealt': 95,
#     'totalTimeSpentDead': 198,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 6955,
#     'trueDamageDealtToChampions': 1157,
#     'trueDamageTaken': 643,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 79,
#     'visionWardsBoughtInGame': 7,
#     'wardsKilled': 10,
#     'wardsPlaced': 53,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 6,
#     'assists': 6,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 364,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 6.5,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 700.8165911864608,
#      'damageTakenOnTeamPercentage': 0.22667105129211357,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1217.3830032552264,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 2863.864013671875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 7,
#      'enemyJungleMonsterKills': 13.300000011920929,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 647.6759105263218,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 1820.646644280887,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 421.0215137889989,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.1666666666666667,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.19444444444444445,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 74,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 72.55000001192093,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6632,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 5,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 12,
#      'skillshotsHit': 18,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'soloTurretsLategame': 2,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 7,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 7,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.17942115685592272,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 10,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.42678070068359375,
#      'visionScorePerMinute': 0.6567873596382825,
#      'wardTakedowns': 6,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 1},
#     'champExperience': 16091,
#     'champLevel': 16,
#     'championId': 114,
#     'championName': 'Fiora',
#     'championTransform': 0,
#     'commandPings': 11,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 10407,
#     'damageDealtToObjectives': 13026,
#     'damageDealtToTurrets': 10407,
#     'damageSelfMitigated': 37549,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 2,
#     'goldEarned': 12775,
#     'goldSpent': 13030,
#     'holdPings': 1,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 3074,
#     'item1': 6632,
#     'item2': 3158,
#     'item3': 3161,
#     'item4': 3082,
#     'item5': 1029,
#     'item6': 3364,
#     'itemsPurchased': 25,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'TOP',
#     'largestCriticalStrike': 662,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 612,
#     'magicDamageDealt': 5233,
#     'magicDamageDealtToChampions': 3466,
#     'magicDamageTaken': 5209,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 22,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8437, 'var1': 2655, 'var2': 1596, 'var3': 0},
#         {'perk': 8446, 'var1': 2513, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 1717, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 65, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 1545, 'var3': 0},
#         {'perk': 8237, 'var1': 911, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 151240,
#     'physicalDamageDealtToChampions': 13083,
#     'physicalDamageTaken': 31106,
#     'profileIcon': 4896,
#     'pushPings': 0,
#     'puuid': 'aYBC3BUwltuGr-3XlyXefEHLoz0JQE3o7EA0q_DpC1Sv6eHcgpJa3wDa2jVeJFv6_lYFdIimRy4fWw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 279,
#     'spell2Casts': 22,
#     'spell3Casts': 58,
#     'spell4Casts': 5,
#     'summoner1Casts': 5,
#     'summoner1Id': 12,
#     'summoner2Casts': 5,
#     'summoner2Id': 6,
#     'summonerId': '3QK_xiWjybX10lo8_F3FcPWbSZ7Kznyv5FlP3zawham_X8M',
#     'summonerLevel': 1078,
#     'summonerName': '잠이안와아보카도',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 18,
#     'timePlayed': 1820,
#     'totalDamageDealt': 165147,
#     'totalDamageDealtToChampions': 21265,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 39270,
#     'totalHeal': 15728,
#     'totalHealsOnTeammates': 2863,
#     'totalMinionsKilled': 216,
#     'totalTimeCCDealt': 128,
#     'totalTimeSpentDead': 202,
#     'totalUnitsHealed': 7,
#     'tripleKills': 0,
#     'trueDamageDealt': 8673,
#     'trueDamageDealtToChampions': 4715,
#     'trueDamageTaken': 2954,
#     'turretKills': 3,
#     'turretTakedowns': 4,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 19,
# ...
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 18,
#      'enemyJungleMonsterKills': 9.200000047683716,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 647.6759105263218,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 1820.646644280887,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 446.4581320891369,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.5555555555555554,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.6388888888888888,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 9,
#      'laneMinionsFirst10Minutes': 64,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 28,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6657,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 4,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 15,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 19,
#      'skillshotsHit': 63,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 5,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 23,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 11,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.2672533198159047,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 4,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 8,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.2513538599014282,
#      'visionScorePerMinute': 1.1782474950650044,
#      'wardTakedowns': 4,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 15747,
#     'champLevel': 16,
#     'championId': 45,
#     'championName': 'Veigar',
#     'championTransform': 0,
#     'commandPings': 5,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 2470,
#     'damageDealtToObjectives': 12610,
#     'damageDealtToTurrets': 2470,
#     'damageSelfMitigated': 28789,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 8,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13547,
#     'goldSpent': 13435,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3040,
#     'item1': 3020,
#     'item2': 3089,
#     'item3': 6657,
#     'item4': 4630,
#     'item5': 1026,
#     'item6': 3363,
#     'itemsPurchased': 23,
#     'killingSprees': 2,
#     'kills': 7,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 358,
#     'magicDamageDealt': 185792,
#     'magicDamageDealtToChampions': 29481,
#     'magicDamageTaken': 6574,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 17,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 24,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8360, 'var1': 6, 'var2': 0, 'var3': 0},
#         {'perk': 8304, 'var1': 7, 'var2': 3, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 1239, 'var3': 0},
#         {'perk': 8210, 'var1': 12, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 11586,
#     'physicalDamageDealtToChampions': 1952,
#     'physicalDamageTaken': 25047,
#     'profileIcon': 20,
#     'pushPings': 0,
#     'puuid': 'pUVDNdZqLcEtLz19SfhvUg0p3PcoZ-WKMgElkqH2I-Rf_f_nH4V20QA7AhfxcQgp4u6szRrtdkJqBA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 177,
#     'spell2Casts': 113,
#     'spell3Casts': 30,
#     'spell4Casts': 13,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 10,
#     'summoner2Id': 12,
#     'summonerId': 'xswxRJRS8vRzsPdm5DjVN1kLmuwXowY1qJ9RBkMHQy_ZPZH011aGykusFw',
#     'summonerLevel': 146,
#     'summonerName': '9277',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 27,
#     'timePlayed': 1820,
#     'totalDamageDealt': 200584,
#     'totalDamageDealtToChampions': 31675,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 33517,
#     'totalHeal': 3809,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 196,
#     'totalTimeCCDealt': 118,
#     'totalTimeSpentDead': 270,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 3205,
#     'trueDamageDealtToChampions': 242,
#     'trueDamageTaken': 1895,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 35,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 4,
#     'wardsPlaced': 13,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 17,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 130,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.2903491648913037,
#      'controlWardsPlaced': 8,
#      'damagePerMinute': 290.4075606555087,
#      'damageTakenOnTeamPercentage': 0.12256499686766838,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1217.3830032552264,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 332.98828125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 50,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 647.6759105263218,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 1820.646644280887,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 306.4932023275188,
#      'hadOpenNexus': 0,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 9,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.375,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.5277777777777778,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 6,
#      'landSkillShotsEarlyGame': 4,
#      'laneMinionsFirst10Minutes': 15,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 8,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 2065,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 14,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 11.526494380049144,
#      'skillshotsDodged': 19,
#      'skillshotsHit': 17,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 28,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 19,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 10,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.07434935352244633,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 6,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 1,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.2060333490371704,
#      'visionScorePerMinute': 3.176590811853992,
#      'wardTakedowns': 11,
#      'wardTakedownsBefore20M': 7,
#      'wardsGuarded': 0},
#     'champExperience': 9258,
#     'champLevel': 12,
#     'championId': 53,
#     'championName': 'Blitzcrank',
#     'championTransform': 0,
#     'commandPings': 19,
#     'consumablesPurchased': 14,
#     'damageDealtToBuildings': 1392,
#     'damageDealtToObjectives': 4186,
#     'damageDealtToTurrets': 1392,
#     'damageSelfMitigated': 19391,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 9,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 8,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 9300,
#     'goldSpent': 7950,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3222,
#     'item1': 3860,
#     'item2': 2065,
#     'item3': 2055,
#     'item4': 3009,
#     'item5': 3082,
#     'item6': 3364,
#     'itemsPurchased': 29,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 434,
#     'magicDamageDealt': 11362,
#     'magicDamageDealtToChampions': 5610,
#     'magicDamageTaken': 3000,
#     'needVisionPings': 1,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 5,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8351, 'var1': 62, 'var2': 1074, 'var3': 0},
#         {'perk': 8306, 'var1': 11, 'var2': 0, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8136, 'var1': 16, 'var2': 30, 'var3': 0},
#         {'perk': 8105, 'var1': 13, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 6648,
#     'physicalDamageDealtToChampions': 2077,
#     'physicalDamageTaken': 16793,
#     'profileIcon': 20,
#     'pushPings': 0,
#     'puuid': 'y32QkHYFwYmPrURqgQaJY-Tq38CihFNE1DgSBIvFXot1URAAgnK_qj-07uAM0_vKunhlKtro_f0jBw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 29,
#     'spell2Casts': 52,
#     'spell3Casts': 39,
#     'spell4Casts': 10,
#     'summoner1Casts': 7,
#     'summoner1Id': 14,
#     'summoner2Casts': 17,
#     'summoner2Id': 4,
#     'summonerId': 'm9hAFM30QFbcHspn8apvbKqWb4UU5KpEWhJo4X6HDgoFoxvkYunM3i8n2Q',
#     'summonerLevel': 66,
#     'summonerName': 'Manycpyfjtjkyxf',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 44,
#     'timePlayed': 1820,
#     'totalDamageDealt': 26326,
#     'totalDamageDealtToChampions': 8812,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 21234,
#     'totalHeal': 878,
#     'totalHealsOnTeammates': 332,
#     'totalMinionsKilled': 40,
#     'totalTimeCCDealt': 260,
#     'totalTimeSpentDead': 240,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 8316,
#     'trueDamageDealtToChampions': 1124,
#     'trueDamageTaken': 1440,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 96,
#     'visionWardsBoughtInGame': 10,
#     'wardsKilled': 11,
#     'wardsPlaced': 54,
#     'win': False}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 51, 'pickTurn': 1},
#      {'championId': 412, 'pickTurn': 2},
#      {'championId': 24, 'pickTurn': 3},
#      {'championId': 30, 'pickTurn': 4},
#      {'championId': 7, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 39},
#      'dragon': {'first': False, 'kills': 1},
#      'inhibitor': {'first': False, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 6}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 30, 'pickTurn': 6},
#      {'championId': 60, 'pickTurn': 7},
#      {'championId': 58, 'pickTurn': 8},
#      {'championId': 119, 'pickTurn': 9},
#      {'championId': 9, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': True, 'kills': 2},
#      'champion': {'first': True, 'kills': 36},
#      'dragon': {'first': True, 'kills': 3},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': True, 'kills': 2},
#      'tower': {'first': True, 'kills': 7}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
matches.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
matches['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_6403575108',
#  'participants': ['Z-LPaYwfPtnMOF_dnCFyExE-IwmHX-0FC-jYH1ohO7Bnh40hq0cB_Lo_4uDIezeKjq7EBCcDSYmTSw',
#   'coMdLdZ6jx4rzI0W3EMzKEjrf0xUzrgXswSDN7zkjBy5s0yuWIuxC_wE9rQMiQ7-c2W5xZRrmpYyTA',
#   'a-tB2hJidodN77cs_gNbJrHuu8N-IBXpH7bu36rTpnTrDFwuRI0LhxxjdZD1VbOLkenfD2KvCkbpYQ',
#   'MCHwZK8au_E3j7yP2cMCwHCZjKNwhiuw64sZREqwkIJwHk7GDj0i8bES_bvHcjq2Y-CgWIR3wx0IWQ',
#   'xuIaA6BjamGWUnZ3yKhC7gveQtbbneOHr3Rdwh3ET99zwZhqa88rB_wTKJdrSZK1BQyIKObqShwQew',
#   'aYBC3BUwltuGr-3XlyXefEHLoz0JQE3o7EA0q_DpC1Sv6eHcgpJa3wDa2jVeJFv6_lYFdIimRy4fWw',
#   'TXRwr3PukyRX-ZpC-OlcGpqmf60Iz8q5TJ678rmouL9EVW3IOgfzDYYn7BKqv8LOl2U3UHkHMI4bBg',
#   'fD3JUAYc6mFSnJtAJpdYoVgjyRH8oI8V4OFDl6ZkF0FcK5yWWxHk1IKMWpeQu9gy9EAOBgdtKOMOsw',
#   'pUVDNdZqLcEtLz19SfhvUg0p3PcoZ-WKMgElkqH2I-Rf_f_nH4V20QA7AhfxcQgp4u6szRrtdkJqBA',
#   'y32QkHYFwYmPrURqgQaJY-Tq38CihFNE1DgSBIvFXot1URAAgnK_qj-07uAM0_vKunhlKtro_f0jBw']}

# %%
len(matches['info']['participants'])
# Out:
# 10

# %%
matches['info']['participants'][0] #1번 유저
# Out:
# {'allInPings': 0,
#  'assistMePings': 1,
#  'assists': 14,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 1,
#  'challenges': {'12AssistStreakCount': 1,
#   'abilityUses': 405,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 0,
#   'damagePerMinute': 685.1657087639934,
#   'damageTakenOnTeamPercentage': 0.24930911463750083,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 7,
#   'dodgeSkillShotsSmallWindow': 6,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 422.5719299316406,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 95,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'flawlessAces': 0,
#   'fullTeamTakedown': 9,
#   'gameLength': 1820.646644280887,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 378.09974676780104,
#   'hadOpenNexus': 0,
#   'highestCrowdControlScore': 1,
#   'immobilizeAndKillWithAlly': 13,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 0,
#   'kda': 2.7142857142857144,
#   'killAfterHiddenWithAlly': 2,
#   'killParticipation': 0.48717948717948717,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 1,
#   'killsNearEnemyTurret': 0,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 0,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 5,
#   'landSkillShotsEarlyGame': 0,
#   'laneMinionsFirst10Minutes': 67,
#   'laningPhaseGoldExpAdvantage': 0,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 1,
#   'maxCsAdvantageOnLaneOpponent': 6,
#   'maxKillDeficit': 10,
#   'maxLevelLeadLaneOpponent': 1,
#   'moreEnemyJungleThanOpponent': 0,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 2,
#   'multikillsAfterAggressiveFlash': 0,
#   'mythicItemUsed': 6662,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 0,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 17,
#   'playedChampSelectPosition': 1,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'shortestTimeToAceFromFirstTakedown': 10.679791099846852,
#   'skillshotsDodged': 38,
#   'skillshotsHit': 0,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 1,
#   'stealthWardsPlaced': 5,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 0,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 19,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 1,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 0,
#   'teamDamagePercentage': 0.15792826097038623,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 0,
#   'threeWardsOneSweeperCount': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 1,
#   'turretTakedowns': 4,
#   'turretsTakenWithRiftHerald': 0,
#   'twentyMinionsIn3SecondsCount': 8,
#   'unseenRecalls': 0,
#   'visionScoreAdvantageLaneOpponent': -0.2991214394569397,
#   'visionScorePerMinute': 0.46032818168846884,
#   'wardTakedowns': 4,
#   'wardTakedownsBefore20M': 1,
#   'wardsGuarded': 0},
#  'champExperience': 15556,
#  'champLevel': 16,
#  'championId': 897,
#  'championName': 'KSante',
#  'championTransform': 0,
#  'commandPings': 13,
#  'consumablesPurchased': 2,
#  'damageDealtToBuildings': 2920,
#  'damageDealtToObjectives': 2920,
#  'damageDealtToTurrets': 2920,
#  'damageSelfMitigated': 42663,
#  'dangerPings': 0,
#  'deaths': 7,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 1,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'enemyMissingPings': 6,
#  'enemyVisionPings': 2,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'getBackPings': 0,
#  'goldEarned': 11473,
#  'goldSpent': 10350,
#  'holdPings': 0,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 1,
#  'inhibitorsLost': 1,
#  'item0': 6662,
#  'item1': 1028,
#  'item2': 3075,
#  'item3': 1057,
#  'item4': 3066,
#  'item5': 3111,
#  'item6': 3364,
#  'itemsPurchased': 21,
#  'killingSprees': 1,
#  'kills': 5,
#  'lane': 'TOP',
#  'largestCriticalStrike': 32,
#  'largestKillingSpree': 3,
#  'largestMultiKill': 3,
#  'longestTimeSpentLiving': 597,
#  'magicDamageDealt': 10622,
#  'magicDamageDealtToChampions': 2629,
#  'magicDamageTaken': 16756,
#  'needVisionPings': 0,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 1,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'onMyWayPings': 9,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8437, 'var1': 1783, 'var2': 1029, 'var3': 0},
#      {'perk': 8446, 'var1': 2257, 'var2': 0, 'var3': 0},
#      {'perk': 8444, 'var1': 2401, 'var2': 0, 'var3': 0},
#      {'perk': 8451, 'var1': 250, 'var2': 0, 'var3': 0}],
#     'style': 8400},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#      {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#     'style': 8300}]},
#  'physicalDamageDealt': 100429,
#  'physicalDamageDealtToChampions': 16888,
#  'physicalDamageTaken': 15676,
#  'profileIcon': 5257,
#  'pushPings': 0,
#  'puuid': 'Z-LPaYwfPtnMOF_dnCFyExE-IwmHX-0FC-jYH1ohO7Bnh40hq0cB_Lo_4uDIezeKjq7EBCcDSYmTSw',
#  'quadraKills': 0,
#  'riotIdName': '',
#  'riotIdTagline': '',
#  'role': 'SOLO',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 233,
#  'spell2Casts': 40,
#  'spell3Casts': 123,
#  'spell4Casts': 9,
#  'summoner1Casts': 6,
#  'summoner1Id': 6,
#  'summoner2Casts': 5,
#  'summoner2Id': 12,
#  'summonerId': 'nSgS7ahPD2hvZen-ar8vtGdETjQY37KKC54h3RDio646GWE',
#  'summonerLevel': 222,
#  'summonerName': '꺾여가는 마음',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 57,
#  'timePlayed': 1820,
#  'totalDamageDealt': 128989,
#  'totalDamageDealtToChampions': 20790,
#  'totalDamageShieldedOnTeammates': 422,
#  'totalDamageTaken': 35681,
#  'totalHeal': 3228,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 175,
#  'totalTimeCCDealt': 2100,
#  'totalTimeSpentDead': 237,
#  'totalUnitsHealed': 1,
#  'tripleKills': 1,
#  'trueDamageDealt': 17937,
#  'trueDamageDealtToChampions': 1272,
#  'trueDamageTaken': 3247,
#  'turretKills': 1,
#  'turretTakedowns': 4,
#  'turretsLost': 7,
#  'unrealKills': 0,
#  'visionClearedPings': 0,
#  'visionScore': 13,
#  'visionWardsBoughtInGame': 0,
#  'wardsKilled': 4,
#  'wardsPlaced': 5,
#  'win': True}

# %%
url5 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{res4[0]}/timeline?api_key={riot_api_key}'

# %%
timeline = requests.get(url5).json()

# %%
timeline.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
timeline['info'].keys()
# Out:
# dict_keys(['frameInterval', 'frames', 'gameId', 'participants'])

# %%
len(timeline['info']['frames'])
# Out:
# 32

# %%
timeline['info']['frames'][0].keys()
# Out:
# dict_keys(['events', 'participantFrames', 'timestamp'])

# %%
timeline['info']['frames'][10]['events'] #분 별 상황
# Out:
# [{'level': 8, 'participantId': 3, 'timestamp': 543805, 'type': 'LEVEL_UP'},
#  {'itemId': 3076,
#   'participantId': 1,
#   'timestamp': 545424,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2055,
#   'participantId': 2,
#   'timestamp': 545721,
#   'type': 'ITEM_DESTROYED'},
#  {'creatorId': 2,
#   'timestamp': 545721,
#   'type': 'WARD_PLACED',
#   'wardType': 'CONTROL_WARD'},
#  {'level': 7, 'participantId': 7, 'timestamp': 548066, 'type': 'LEVEL_UP'},
#  {'assistingParticipantIds': [8],
#   'bounty': 0,
#   'killerId': 7,
#   'killerTeamId': 200,
#   'monsterType': 'RIFTHERALD',
#   'position': {'x': 4648, 'y': 9958},
#   'timestamp': 548066,
#   'type': 'ELITE_MONSTER_KILL'},
#  {'creatorId': 9,
#   'timestamp': 549089,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 2,
#   'timestamp': 549287,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 3364,
#   'participantId': 7,
#   'timestamp': 549815,
#   'type': 'ITEM_DESTROYED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 3,
#   'skillSlot': 3,
#   'timestamp': 553023,
#   'type': 'SKILL_LEVEL_UP'},
#  {'level': 8, 'participantId': 8, 'timestamp': 555862, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 8,
#   'skillSlot': 3,
#   'timestamp': 558207,
#   'type': 'SKILL_LEVEL_UP'},
#  {'killerId': 2,
#   'timestamp': 558539,
#   'type': 'WARD_KILL',
#   'wardType': 'UNDEFINED'},
#  {'level': 5, 'participantId': 5, 'timestamp': 564120, 'type': 'LEVEL_UP'},
#  {'itemId': 2055,
#   'participantId': 3,
#   'timestamp': 566038,
#   'type': 'ITEM_DESTROYED'},
#  {'creatorId': 3,
#   'timestamp': 566038,
#   'type': 'WARD_PLACED',
#   'wardType': 'CONTROL_WARD'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 5,
#   'skillSlot': 2,
#   'timestamp': 566369,
#   'type': 'SKILL_LEVEL_UP'},
#  {'creatorId': 8,
#   'timestamp': 566997,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'itemId': 2010,
#   'participantId': 9,
#   'timestamp': 570497,
#   'type': 'ITEM_DESTROYED'},
#  {'killerId': 10,
#   'timestamp': 574759,
#   'type': 'WARD_KILL',
#   'wardType': 'CONTROL_WARD'},
#  {'creatorId': 10,
#   'timestamp': 574759,
#   'type': 'WARD_PLACED',
#   'wardType': 'UNDEFINED'},
#  {'assistingParticipantIds': [5],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 4,
#   'position': {'x': 10988, 'y': 3700},
#   'shutdownBounty': 150,
#   'timestamp': 576245,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'Veigar',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'veigarbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 543,
#     'name': 'Veigar',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'veigarbalefulstrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Veigar',
#     'participantId': 5,
#     'physicalDamage': 134,
#     'spellName': 'veigarbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_OrderMinionSiege',
#     'participantId': 0,
#     'physicalDamage': 14,
#     'spellName': 'sru_orderminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_OrderMinionSiege',
#     'participantId': 0,
#     'physicalDamage': 42,
#     'spellName': 'sru_orderminionrangedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_OrderMinionSiege',
#     'participantId': 0,
#     'physicalDamage': 108,
#     'spellName': 'sru_orderminionsiegebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'SRU_OrderMinionSiege',
#     'participantId': 0,
#     'physicalDamage': 121,
#     'spellName': 'sru_orderminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 4,
#     'physicalDamage': 308,
#     'spellName': 'jinxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 4,
#     'physicalDamage': 101,
#     'spellName': 'jinxq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 4,
#     'physicalDamage': 376,
#     'spellName': 'jinxr',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 4,
#     'physicalDamage': 91,
#     'spellName': 'jinxbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 4,
#     'physicalDamage': 202,
#     'spellName': 'jinxqattack2',
#     'spellSlot': 70,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 4,
#     'physicalDamage': 183,
#     'spellName': 'jinxbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Rakan',
#     'participantId': 5,
#     'physicalDamage': 91,
#     'spellName': 'rakanbasicattack2',
#     'spellSlot': 49,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 244,
#     'name': 'Rakan',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'rakanw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Rakan',
#     'participantId': 5,
#     'physicalDamage': 91,
#     'spellName': 'rakanbasicattack',
#     'spellSlot': 49,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 131,
#     'name': 'Rakan',
#     'participantId': 5,
#     'physicalDamage': 0,
#     'spellName': 'rakanq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Rakan',
#     'participantId': 5,
#     'physicalDamage': 47,
#     'spellName': 'rakanbasicattackshort',
#     'spellSlot': 49,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 9},
#  {'itemId': 3513,
#   'participantId': 7,
#   'timestamp': 578426,
#   'type': 'ITEM_DESTROYED'},
#  {'level': 8, 'participantId': 1, 'timestamp': 580804, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 3,
#   'timestamp': 582720,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1028,
#   'participantId': 9,
#   'timestamp': 585164,
#   'type': 'ITEM_PURCHASED'},
#  {'assistingParticipantIds': [2],
#   'bounty': 300,
#   'killStreakLength': 1,
#   'killerId': 3,
#   'position': {'x': 5874, 'y': 5813},
#   'shutdownBounty': 150,
#   'timestamp': 588236,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'XinZhao',
#     'participantId': 2,
#     'physicalDamage': 98,
#     'spellName': 'xinzhaor',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'XinZhao',
#     'participantId': 3,
#     'physicalDamage': 205,
#     'spellName': 'xinzhaor',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 140,
#     'name': 'Sejuani',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': 'sejuanir',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sejuani',
#     'participantId': 2,
#     'physicalDamage': 151,
#     'spellName': 'sejuaniw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 81,
#     'name': 'Sejuani',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': 'sejuanipassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sejuani',
#     'participantId': 2,
#     'physicalDamage': 49,
#     'spellName': 'sejuanibasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 162,
#     'name': 'LeeSin',
#     'participantId': 3,
#     'physicalDamage': 0,
#     'spellName': 'blindmonkeone',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 3,
#     'physicalDamage': 131,
#     'spellName': 'blindmonkqone',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 3,
#     'physicalDamage': 192,
#     'spellName': 'blindmonkqtwo',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 3,
#     'physicalDamage': 213,
#     'spellName': 'blindmonkrkick',
#     'spellSlot': 3,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Turret',
#     'participantId': 0,
#     'physicalDamage': 200,
#     'spellName': 'turretbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'TOWER'}],
#   'victimId': 7},
#  {'killerId': 7,
#   'laneType': 'MID_LANE',
#   'position': {'x': 5846, 'y': 6396},
#   'teamId': 100,
#   'timestamp': 588831,
#   'type': 'TURRET_PLATE_DESTROYED'},
#  {'killerId': 7,
#   'laneType': 'MID_LANE',
#   'position': {'x': 5846, 'y': 6396},
#   'teamId': 100,
#   'timestamp': 588831,
#   'type': 'TURRET_PLATE_DESTROYED'},
#  {'level': 7, 'participantId': 4, 'timestamp': 589393, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 1,
#   'timestamp': 590383,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 6029,
#   'participantId': 7,
#   'timestamp': 592365,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3133,
#   'participantId': 7,
#   'timestamp': 592365,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 6630,
#   'participantId': 7,
#   'timestamp': 592365,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1028,
#   'participantId': 5,
#   'timestamp': 594150,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3067,
#   'participantId': 5,
#   'timestamp': 594150,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1001,
#   'participantId': 7,
#   'timestamp': 596793,
#   'type': 'ITEM_PURCHASED'},
#  {'killerId': 4,
#   'laneType': 'BOT_LANE',
#   'position': {'x': 13866, 'y': 4505},
#   'teamId': 200,
#   'timestamp': 597851,
#   'type': 'TURRET_PLATE_DESTROYED'},
#  {'itemId': 1036,
#   'participantId': 7,
#   'timestamp': 599965,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1036,
#   'participantId': 7,
#   'timestamp': 600064,
#   'type': 'ITEM_PURCHASED'}]

# %%
timeline['info']['frames'][10]['participantFrames'] #플레이어 데이터
# Out:
# {'1': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 72,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 115,
#    'attackSpeed': 124,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 519,
#    'healthMax': 1444,
#    'healthRegen': 202,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 42,
#    'movementSpeed': 355,
#    'omnivamp': 11,
#    'physicalVamp': 0,
#    'power': 621,
#    'powerMax': 756,
#    'powerRegen': 25,
#    'spellVamp': 0},
#   'currentGold': 336,
#   'damageStats': {'magicDamageDone': 692,
#    'magicDamageDoneToChampions': 422,
#    'magicDamageTaken': 1662,
#    'physicalDamageDone': 21704,
#    'physicalDamageDoneToChampions': 3261,
#    'physicalDamageTaken': 4882,
#    'totalDamageDone': 27628,
#    'totalDamageDoneToChampions': 3735,
#    'totalDamageTaken': 7095,
#    'trueDamageDone': 5231,
#    'trueDamageDoneToChampions': 51,
#    'trueDamageTaken': 550},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 8,
#   'minionsKilled': 67,
#   'participantId': 1,
#   'position': {'x': 2973, 'y': 13142},
#   'timeEnemySpentControlled': 127129,
#   'totalGold': 2886,
#   'xp': 4195},
#  '2': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 91,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 81,
#    'attackSpeed': 123,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 13,
#    'cooldownReduction': 0,
#    'health': 1027,
#    'healthMax': 1356,
#    'healthRegen': 24,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 40,
#    'movementSpeed': 365,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 293,
#    'powerMax': 558,
#    'powerRegen': 89,
#    'spellVamp': 0},
#   'currentGold': 773,
#   'damageStats': {'magicDamageDone': 8815,
#    'magicDamageDoneToChampions': 670,
#    'magicDamageTaken': 2111,
#    'physicalDamageDone': 21392,
#    'physicalDamageDoneToChampions': 1035,
#    'physicalDamageTaken': 5588,
#    'totalDamageDone': 42610,
#    'totalDamageDoneToChampions': 1761,
#    'totalDamageTaken': 7756,
#    'trueDamageDone': 12402,
#    'trueDamageDoneToChampions': 56,
#    'trueDamageTaken': 56},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 48,
#   'level': 6,
#   'minionsKilled': 5,
#   'participantId': 2,
#   'position': {'x': 4049, 'y': 7362},
#   'timeEnemySpentControlled': 125448,
#   'totalGold': 3048,
#   'xp': 3035},
#  '3': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 64,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 157,
#    'attackSpeed': 137,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 18,
#    'cooldownReduction': 0,
#    'health': 722,
#    'healthMax': 1331,
#    'healthRegen': 134,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 51,
#    'movementSpeed': 345,
#    'omnivamp': 2,
#    'physicalVamp': 0,
#    'power': 200,
#    'powerMax': 200,
#    'powerRegen': 100,
#    'spellVamp': 0},
#   'currentGold': 937,
#   'damageStats': {'magicDamageDone': 10398,
#    'magicDamageDoneToChampions': 588,
#    'magicDamageTaken': 2976,
#    'physicalDamageDone': 20699,
#    'physicalDamageDoneToChampions': 3412,
#    'physicalDamageTaken': 1910,
#    'totalDamageDone': 32582,
#    'totalDamageDoneToChampions': 4000,
#    'totalDamageTaken': 4946,
#    'trueDamageDone': 1483,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 60},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 8,
#   'minionsKilled': 64,
#   'participantId': 3,
#   'position': {'x': 5906, 'y': 6261},
#   'timeEnemySpentControlled': 118288,
#   'totalGold': 3937,
#   'xp': 4581},
#  '4': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 48,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 138,
#    'attackSpeed': 184,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 1194,
#    'healthMax': 1194,
#    'healthRegen': 12,
#    'lifesteal': 3,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 44,
#    'movementSpeed': 350,
#    'omnivamp': 2,
#    'physicalVamp': 0,
#    'power': 137,
#    'powerMax': 502,
#    'powerRegen': 23,
#    'spellVamp': 0},
#   'currentGold': 1540,
#   'damageStats': {'magicDamageDone': 228,
#    'magicDamageDoneToChampions': 158,
#    'magicDamageTaken': 1662,
#    'physicalDamageDone': 27875,
#    'physicalDamageDoneToChampions': 4703,
#    'physicalDamageTaken': 1995,
#    'totalDamageDone': 28160,
#    'totalDamageDoneToChampions': 4917,
#    'totalDamageTaken': 3836,
#    'trueDamageDone': 56,
#    'trueDamageDoneToChampions': 56,
#    'trueDamageTaken': 178},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 7,
#   'minionsKilled': 79,
#   'participantId': 4,
#   'position': {'x': 13288, 'y': 3088},
#   'timeEnemySpentControlled': 22194,
#   'totalGold': 4770,
#   'xp': 3216},
#  '5': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 30,
#    'armor': 47,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 72,
#    'attackSpeed': 109,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 34,
#    'cooldownReduction': 0,
#    'health': 1183,
#    'healthMax': 1215,
#    'healthRegen': 22,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 71,
#    'movementSpeed': 380,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 371,
#    'powerMax': 469,
#    'powerRegen': 20,
#    'spellVamp': 0},
#   'currentGold': 207,
#   'damageStats': {'magicDamageDone': 1910,
#    'magicDamageDoneToChampions': 1301,
#    'magicDamageTaken': 1660,
#    'physicalDamageDone': 3153,
#    'physicalDamageDoneToChampions': 1232,
#    'physicalDamageTaken': 2596,
#    'totalDamageDone': 8665,
#    'totalDamageDoneToChampions': 2737,
#    'totalDamageTaken': 4564,
#    'trueDamageDone': 3600,
#    'trueDamageDoneToChampions': 203,
#    'trueDamageTaken': 308},
#   'goldPerSecond': 30,
#   'jungleMinionsKilled': 0,
#   'level': 5,
#   'minionsKilled': 14,
#   'participantId': 5,
#   'position': {'x': 2436, 'y': 1677},
#   'timeEnemySpentControlled': 16756,
#   'totalGold': 2907,
#   'xp': 2173},
#  '6': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 66,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 92,
#    'attackSpeed': 128,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 23,
#    'cooldownReduction': 0,
#    'health': 577,
#    'healthMax': 1709,
#    'healthRegen': 74,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 43,
#    'movementSpeed': 452,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 435,
#    'powerMax': 896,
#    'powerRegen': 24,
#    'spellVamp': 0},
#   'currentGold': 1330,
#   'damageStats': {'magicDamageDone': 2872,
#    'magicDamageDoneToChampions': 1662,
#    'magicDamageTaken': 527,
#    'physicalDamageDone': 18228,
#    'physicalDamageDoneToChampions': 3749,
#    'physicalDamageTaken': 5825,
#    'totalDamageDone': 21651,
#    'totalDamageDoneToChampions': 5961,
#    'totalDamageTaken': 6403,
#    'trueDamageDone': 550,
#    'trueDamageDoneToChampions': 550,
#    'trueDamageTaken': 51},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 8,
#   'minionsKilled': 74,
#   'participantId': 6,
#   'position': {'x': 3454, 'y': 13368},
#   'timeEnemySpentControlled': 34264,
#   'totalGold': 3335,
#   'xp': 4681},
#  '7': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 63,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 157,
#    'attackSpeed': 144,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 0,
#    'healthMax': 1453,
#    'healthRegen': 22,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 41,
#    'movementSpeed': 395,
#    'omnivamp': 8,
#    'physicalVamp': 0,
#    'power': 313,
#    'powerMax': 540,
#    'powerRegen': 18,
#    'spellVamp': 0},
#   'currentGold': 176,
#   'damageStats': {'magicDamageDone': 2823,
#    'magicDamageDoneToChampions': 141,
#    'magicDamageTaken': 1190,
#    'physicalDamageDone': 36822,
#    'physicalDamageDoneToChampions': 2920,
#    'physicalDamageTaken': 6214,
#    'totalDamageDone': 51709,
#    'totalDamageDoneToChampions': 3085,
#    'totalDamageTaken': 7437,
#    'trueDamageDone': 12063,
#    'trueDamageDoneToChampions': 24,
#    'trueDamageTaken': 32},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 48,
#   'level': 7,
#   'minionsKilled': 11,
#   'participantId': 7,
#   'position': {'x': 5874, 'y': 5813},
#   'timeEnemySpentControlled': 178537,
#   'totalGold': 5071,
#   'xp': 3502},
#  '8': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 77,
#    'armor': 61,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 75,
#    'attackSpeed': 122,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 1639,
#    'healthMax': 1801,
#    'healthRegen': 25,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 47,
#    'movementSpeed': 370,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 1092,
#    'powerMax': 2146,
#    'powerRegen': 27,
#    'spellVamp': 0},
#   'currentGold': 1065,
#   'damageStats': {'magicDamageDone': 29685,
#    'magicDamageDoneToChampions': 3717,
#    'magicDamageTaken': 608,
#    'physicalDamageDone': 7391,
#    'physicalDamageDoneToChampions': 1121,
#    'physicalDamageTaken': 3869,
#    'totalDamageDone': 37230,
#    'totalDamageDoneToChampions': 4992,
#    'totalDamageTaken': 4501,
#    'trueDamageDone': 154,
#    'trueDamageDoneToChampions': 154,
#    'trueDamageTaken': 24},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 8,
#   'minionsKilled': 81,
#   'participantId': 8,
#   'position': {'x': 7386, 'y': 7520},
#   'timeEnemySpentControlled': 38922,
#   'totalGold': 5040,
#   'xp': 4354},
#  '9': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 184,
#    'armor': 52,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 65,
#    'attackSpeed': 110,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 1668,
#    'healthMax': 1668,
#    'healthRegen': 18,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 38,
#    'movementSpeed': 605,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 1873,
#    'powerMax': 1873,
#    'powerRegen': 23,
#    'spellVamp': 0},
#   'currentGold': 192,
#   'damageStats': {'magicDamageDone': 23428,
#    'magicDamageDoneToChampions': 2981,
#    'magicDamageTaken': 768,
#    'physicalDamageDone': 5171,
#    'physicalDamageDoneToChampions': 1218,
#    'physicalDamageTaken': 4631,
#    'totalDamageDone': 31804,
#    'totalDamageDoneToChampions': 4441,
#    'totalDamageTaken': 5407,
#    'trueDamageDone': 3205,
#    'trueDamageDoneToChampions': 242,
#    'trueDamageTaken': 8},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 7,
#   'minionsKilled': 70,
#   'participantId': 9,
#   'position': {'x': 14340, 'y': 14391},
#   'timeEnemySpentControlled': 68348,
#   'totalGold': 4042,
#   'xp': 3578},
#  '10': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 22,
#    'armor': 60,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 72,
#    'attackSpeed': 103,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 1149,
#    'healthMax': 1149,
#    'healthRegen': 29,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 34,
#    'movementSpeed': 513,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 319,
#    'powerMax': 510,
#    'powerRegen': 32,
#    'spellVamp': 0},
#   'currentGold': 634,
#   'damageStats': {'magicDamageDone': 1255,
#    'magicDamageDoneToChampions': 442,
#    'magicDamageTaken': 455,
#    'physicalDamageDone': 2678,
#    'physicalDamageDoneToChampions': 971,
#    'physicalDamageTaken': 2519,
#    'totalDamageDone': 6867,
#    'totalDamageDoneToChampions': 1595,
#    'totalDamageTaken': 3226,
#    'trueDamageDone': 2934,
#    'trueDamageDoneToChampions': 182,
#    'trueDamageTaken': 251},
#   'goldPerSecond': 20,
#   'jungleMinionsKilled': 0,
#   'level': 5,
#   'minionsKilled': 15,
#   'participantId': 10,
#   'position': {'x': 10622, 'y': 5184},
#   'timeEnemySpentControlled': 100522,
#   'totalGold': 2850,
#   'xp': 1945}}

# %% [markdown]
# # puuid얻어야함 아이디를 통해 : summoner-v4
#
# # matchid 얻기 puuid :match -v5
#
# # match_id로  match정보 timeline 조회
#
# #

# %% [markdown]
# # 3개의 함수를 통해
#
# # puuid를 구하는 함수
#
# # matchid를 구하는 함수
#
# # match, timeline을 가져오는 함수
#
# # 자신의 닉네임(롤 아이디)를 작성하면
#
# # puuid->matchid-> 첫번째 matchid로
#
# # match,timeline을 가져오는 함수
#
# # hide on bush

# %%
riot_api_key = 'RGAPI-45acd7cf-59a4-495d-ba1f-08133475f074'

# %%
user = input('이름을 입력해 주세요')
# Out:
# 이름을 입력해 주세요hide on bush

# %%
user
# Out:
# 'hide on bush'

# %%
def get_puid(user):
    if ' ' in user:
        user = user.replace(" ", "%20")
        
    url10 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{user}?api_key={riot_api_key}'
    res10 = requests.get(url10).json()
    print('h2')
    get_matchid(res10['puuid'])

# %%
def get_matchid(puuid):
    url11 = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20&api_key={riot_api_key}'
    res11 = requests.get(url11).json()
    return get_match_timeline(res11[0]), get_match(res11[0])

# %%
def get_match(machid):
    url13 =f'https://asia.api.riotgames.com/lol/match/v5/matches/{machid}?api_key={riot_api_key}'
    res13 = requests.get(url13).json()
    print('매치:',res13['info'].keys())

# %%
def get_match_timeline(machid):
    url12 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{machid}/timeline?api_key={riot_api_key}'
    res12 = requests.get(url12).json()
    print('타임라인:',res12['info']['frames'][0]['events'])

# %%
get_puid(user)
# Out:
# h2
# 타임라인: [{'realTimestamp': 1678473746772, 'timestamp': 0, 'type': 'PAUSE_END'}]
# 매치: dict_keys(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
url =f'https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5?api_key={riot_api_key}'

# %%
res = requests.get(url).json()

# %%
res
# Out:
# {'tier': 'GRANDMASTER',
#  'leagueId': '446781dd-2147-3d8a-be18-f9a4f27e87bd',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Nami's Elite",
#  'entries': [{'summonerId': 'fkR5Jaadv1MHfEVQoRvWtmTmFH8DXkDsIjwKkezuAVXr_jg',
#    'summonerName': 'ToianD',
#    'leaguePoints': 445,
#    'rank': 'I',
#    'wins': 305,
#    'losses': 293,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KkcdvRwr4W2m_PIAYOmxGWfvtokNSZKcjIxEVITHCEILevrZAc8uQaFvKw',
#    'summonerName': '아이스티좋아해용',
#    'leaguePoints': 403,
#    'rank': 'I',
#    'wins': 95,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ra8839m8IhjLaKQiWY7_wQxSMrMhTmpjSGIpfPOf7HB3JqNqRo4LdkO4hw',
#    'summonerName': 'Promise myself',
#    'leaguePoints': 496,
#    'rank': 'I',
#    'wins': 222,
#    'losses': 194,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'l1CORbPdWClGj4na7bguGBPAlF0xQ16kIKKk6QfaSXoiJ_Y',
#    'summonerName': '이 차가 식기전에',
#    'leaguePoints': 463,
#    'rank': 'I',
#    'wins': 323,
#    'losses': 315,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'Be6IEP1KstLvAqWCEvfV6JkGDwRKEJ_o03kI4gbQG5p8ElA',
#    'summonerName': 'keskgdkfkt',
#    'leaguePoints': 499,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rAXsO5KA0yXVnJuMtB2Q6iO-Ny8ftO8EjfPChDC5T-Knxe4',
#    'summonerName': 'MoMoKoKo',
#    'leaguePoints': 530,
#    'rank': 'I',
#    'wins': 187,
#    'losses': 171,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'X7QQngUAdS83s3VTKR9hKU8h8TgLxK2CFDsPd3kOS8kfcqE5eBil9cA5CA',
#    'summonerName': 'Straight to Hel1',
#    'leaguePoints': 487,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 61,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'fY_I4FjdeBT3JeOTJKJCNPQo4o4gvGW7TTwDA11KtfUY7cq22H2xMaAALQ',
#    'summonerName': '슈퍼왕초딩잼민이',
#    'leaguePoints': 444,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 152,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'm43IYBxg6DJqAm2s2jneDhsMWXZO3CuA7FBQlXuhjHgVy-0',
#    'summonerName': ' i love luIu',
#    'leaguePoints': 443,
#    'rank': 'I',
#    'wins': 55,
#    'losses': 32,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '-lRM2J0AUCUj_xkWK-mtiG5IRgZqCy23EWQ73eF9yzOGpzg',
#    'summonerName': '황매돌',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '-q4lz7KhxiIEZx555wBWP0GvUhxhChiiWNGSWGFK113cYoM',
#    'summonerName': '쿠자니',
#    'leaguePoints': 428,
#    'rank': 'I',
#    'wins': 58,
#    'losses': 32,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'xeEHIZ6-g9dffyUaj9fMHZHecwE0ef9eyExaJzqAm615fOs',
#    'summonerName': '화려하게카타리나',
#    'leaguePoints': 462,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'BHeCnloVgSM7LJMruTFcgV0uAzJmvrjup9NgDVFaSck7vW0',
#    'summonerName': 'FlawIess',
#    'leaguePoints': 471,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 71,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'CgHCcVRzlCYmIEk_-yCy1LS3kixF5_FWHdaW4fDW20FOue3JF6EJuMLnRw',
#    'summonerName': 'openbye3',
#    'leaguePoints': 412,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mABRUkuW1XIWzsxmboDMA90UrK0Epwpv9Omf3N5vG35Es-TOsBlB9Dc1qg',
#    'summonerName': 'na xie nian',
#    'leaguePoints': 410,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'GRRLWE4WcACguU_XFlDunkjooAa-s8tNQE-O2IBwpJHQvBXvSrqLAOlz_A',
#    'summonerName': '2023 NC Dinos',
#    'leaguePoints': 588,
#    'rank': 'I',
#    'wins': 343,
#    'losses': 315,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'I9AQ1O9UGdeort9ngfBVi1zY849SacvjT3S43FPQCE018VZDgxz0wMyBPA',
#    'summonerName': 'xi1',
#    'leaguePoints': 605,
#    'rank': 'I',
#    'wins': 192,
#    'losses': 172,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'LgXdaBZjn9CTyEvJJbjQ_gjA4KvwsxihiC8LFFxgXx5FXUdShnghJa-F3Q',
#    'summonerName': 'omp5',
#    'leaguePoints': 464,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tjdVFaK5Yq-ADXHoqvfHkPvnVgO9bErDUE1tBxMbVDr4PoE',
#    'summonerName': '귀여워서 죄송합니다',
#    'leaguePoints': 479,
#    'rank': 'I',
#    'wins': 223,
#    'losses': 203,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8Nwt0_5u1akMPwZiN7q_3Fdo1LjhJGuVmgCgPT__Xgo5bZSH-jYJ55hUYw',
#    'summonerName': '베르테르',
#    'leaguePoints': 412,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 145,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'aRCJCJesTgzf_G0NuI237rSbA7ow_xlUTurEtasE3X3fB-g',
#    'summonerName': '간다라쿤다',
#    'leaguePoints': 459,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'U73vI64510zr_etSPi2Qo7df4ACZmiGJQ7BQ5ba-qvMW9Wk',
#    'summonerName': 'gnpm',
#    'leaguePoints': 481,
#    'rank': 'I',
#    'wins': 233,
#    'losses': 226,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'I_Gavf_o6X9wao1uuc0i7hb21nigQNXOnSZftjip1Iz9og',
#    'summonerName': 'White Canvas',
#    'leaguePoints': 594,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 120,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Yf45MSmpTM1al-pej5Uv9hAPQMUVt52k9uyJeHRB4dQOcit83UueidLF0w',
#    'summonerName': 'gxpnmx',
#    'leaguePoints': 472,
#    'rank': 'I',
#    'wins': 192,
#    'losses': 185,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'odXn4rNcp7un3gw93duwApsiFAPgO1v42JPqK1OEcn83XL0',
#    'summonerName': 'Sereno',
#    'leaguePoints': 584,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 109,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'uoCy9okDkub69pX5RTcozrFpfS2A37M__H0tNfUPVU92c1c',
#    'summonerName': '드 쉽',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 62,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'H2cgEquc4yFUh2aknrY-ZMWtiazecmuQkRPIXGQca0njDAo6yGfzPokryw',
#    'summonerName': '아 왜캐 졸리지',
#    'leaguePoints': 465,
#    'rank': 'I',
#    'wins': 116,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'W7rzHElR9euyflLTijkiVEIk3zSexkZlCCVGRVO7VPH3mJgp__JVIf5Avg',
#    'summonerName': '노오란감귤',
#    'leaguePoints': 459,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 193,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '-GG3sOYQ84IX_Doi7J-kmDtBzT8kzDyuk36gY0nKzi9RIw',
#    'summonerName': '응애서코',
#    'leaguePoints': 426,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 102,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'HMjQZRdQhIkrsOqL93F5cIuYv0IOs9gl8de_rwdg4orMK7Av9fflhq9w7w',
#    'summonerName': 'tiancaishaonvjie',
#    'leaguePoints': 477,
#    'rank': 'I',
#    'wins': 186,
#    'losses': 174,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'q7UijbGr7FU1OQYiUmIv00F-9casU_0VhpQVDClAkV_ougw',
#    'summonerName': '매트릭스 탈출자',
#    'leaguePoints': 471,
#    'rank': 'I',
#    'wins': 76,
#    'losses': 55,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'fzU55mw9H2DZjYCfISM9rzntigj1U9qQitM2ImVRNkQZkg',
#    'summonerName': 'NekoL',
#    'leaguePoints': 441,
#    'rank': 'I',
#    'wins': 128,
#    'losses': 112,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tQGY2al1XUpYmk5yesKL6zTRVyIgI1pz_rdQWWdOroGTqXG1QZXkfQdalw',
#    'summonerName': 'maxx',
#    'leaguePoints': 543,
#    'rank': 'I',
#    'wins': 135,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ryMCs0kpWZP_ac7uIVK3fEHX7sYnN0uD_Vrba6XA_6aB8DbSFflHfnWo9Q',
#    'summonerName': '미안말걸지말아줘',
#    'leaguePoints': 630,
#    'rank': 'I',
#    'wins': 429,
#    'losses': 408,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7ZYCNsi8Y7JUWfcBG5bvVDrQ9mQhr3tXhZomXA2Jlm-nwvw',
#    'summonerName': 'xxxxlululu',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 125,
#    'losses': 108,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'zfNymmBN0Rlw-6BXCnayjBonXueBzsEV3lK4nLgFZ-T3IYM',
#    'summonerName': '귀엽고착한여자',
#    'leaguePoints': 441,
#    'rank': 'I',
#    'wins': 217,
#    'losses': 190,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'cFShiPZ4Pm3TLekCRIShoR3Mou-nfT5KY1n_PzsJVpLMm2_sIRi4JqpLRA',
#    'summonerName': '하트 둥글다',
#    'leaguePoints': 407,
#    'rank': 'I',
#    'wins': 279,
#    'losses': 261,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'NDGeT2d1n2cvRob7NRWC_Y06PR2vUDZMaeZBKtaA8jIzqaw',
#    'summonerName': '06년생 김유빈',
#    'leaguePoints': 424,
#    'rank': 'I',
#    'wins': 217,
#    'losses': 190,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'dSiF0MJdM8xEiktqrm9LKkN9h5Spt0-ELnUcY2y2neaIYMEJzqFvw3NRLw',
#    'summonerName': '대머리',
#    'leaguePoints': 540,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 179,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BqGH3YcpHPjcFxPEKPPuaSrIoU7h1v0MXN8jup26jJNTRHuQlIjRmXIH8w',
#    'summonerName': '비위맞출바엔자살',
#    'leaguePoints': 415,
#    'rank': 'I',
#    'wins': 101,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'K9Y2_CJ_FvwGKHSPdLUfrYa5ArwxE7KS-JNt1nbBfD0uTXLw6Xi5KKtfuQ',
#    'summonerName': '작멍2',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 469,
#    'losses': 450,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'dGNaI0gLv83WF1CzCWHue6hwjOr8DtpN6pz9p5DN0LTkcFfb37_qWABPyg',
#    'summonerName': '귀큰둥이',
#    'leaguePoints': 605,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 149,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '_pp4nRg0Hj5SywT0a0Q6ZA7iUeUKCQ5h0cambwafyyyRt_4',
#    'summonerName': '망나니박진수',
#    'leaguePoints': 646,
#    'rank': 'I',
#    'wins': 198,
#    'losses': 182,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HCnQ2dddyHQUCXHVfBnCqwJc1zMVmdQFDmYVyS0-NgbrSGMB64M8QVQ0qA',
#    'summonerName': '원딜가는보민이',
#    'leaguePoints': 367,
#    'rank': 'I',
#    'wins': 234,
#    'losses': 220,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8bpzqvwqBFf-RzMz9oMq2tOW6IZuxSbL2nBvBUMEbb1Hdg',
#    'summonerName': 'Hide on bush',
#    'leaguePoints': 542,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 135,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'bjrAffOyQlPW8WdVmhX7jHx2u99DGbq0U2Yi0fy01F3qzAA',
#    'summonerName': '가만히진정하다',
#    'leaguePoints': 417,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 107,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'gvdtZGcU-dHNXl0_0X3PASwuHG2RJWqfgrXbNPfUOyBjGVw',
#    'summonerName': '유미장인을꿈꾼1',
#    'leaguePoints': 429,
#    'rank': 'I',
#    'wins': 280,
#    'losses': 258,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'U8JeWNbab_o5IlczyeR_OZR7YNQBCYwbL0k--dDD_OrdOw',
#    'summonerName': 'Azhy',
#    'leaguePoints': 523,
#    'rank': 'I',
#    'wins': 117,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'kkdgWGYYOOld-h-1PrDzn48lDd7MxzIVLhugqvMbtPSaz49dIv0INVTyXw',
#    'summonerName': '달팽이는 부러워',
#    'leaguePoints': 430,
#    'rank': 'I',
#    'wins': 65,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UlpjM1xwq5T6C8q4RC2INzfuDpAzhAbsjpYYXeKJk-GUOiI',
#    'summonerName': 'wudi shangdan',
#    'leaguePoints': 631,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'V8ugQUT-y9fO3-mdWRwGQ0miUnd2DM7bU8rXYXFivr4EGis',
#    'summonerName': '잘떠먹여주세요',
#    'leaguePoints': 431,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'IpE0k7XqTJp2q_aYTdlITXO0rXQjpdhhRci8uTBRQ79-NmIQosHWs6E3RA',
#    'summonerName': '철학자',
#    'leaguePoints': 549,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 91,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '4vllCuQQjp_J7A22_1fWokBUgcTKI2tJFDJ0wXdmLgYT3VjrdO35DBX4-A',
#    'summonerName': '울팀이길MOM없음',
#    'leaguePoints': 411,
#    'rank': 'I',
#    'wins': 335,
#    'losses': 311,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'lGUbQfTWqr52V9LIdfY2_lV77PpGvN8CjBclK8dDjToCsgd-HWnfDPAIXg',
#    'summonerName': 'qiyaaibeibei',
#    'leaguePoints': 441,
#    'rank': 'I',
#    'wins': 68,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'fEbJ91NzgY3-gQMqgYmnQT5giySh-vej03qp48WNSJOhXiGF9W5cJe6kLw',
#    'summonerName': 'YKEY',
#    'leaguePoints': 457,
#    'rank': 'I',
#    'wins': 192,
#    'losses': 178,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'RfjgPa2Rs45RzXTEExnJGofBU18w_qvXR7wIT5o9_5GCWFo',
#    'summonerName': 'XiaoHuaSheng7',
#    'leaguePoints': 608,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'jW_bv5j_tpG25pu47cAapoGHVKLBVfHdg4vsnny7yyCZ7Uf4UCSaLveVlg',
#    'summonerName': 'lIllIllIIlIl',
#    'leaguePoints': 428,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '1D_Bxj0gX_dw-LizAzXsJcv5WzE4B2oPRSdcsAd7BwVwKIAX',
#    'summonerName': '우기영',
#    'leaguePoints': 410,
#    'rank': 'I',
#    'wins': 354,
#    'losses': 336,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FF7L88n_XkvyFCuCqkxzgffUhuJfj-zTGzboqHYhaP7od6ktJej39m2KAA',
#    'summonerName': '게살버거',
#    'leaguePoints': 465,
#    'rank': 'I',
#    'wins': 78,
#    'losses': 58,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'OVrAjOnfajhhxBzmJu52CtlyKTXz6zA_xyj09yY0-YNcwwAkJCEJVQqJ3w',
#    'summonerName': '20001202112',
#    'leaguePoints': 511,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'QD1QFD7KD4ExdKuZ-sUf-7r9g0vbjvF7Z1Bn5qmRFyM14y4',
#    'summonerName': '콩벌레는동글동글',
#    'leaguePoints': 609,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 172,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '-WFdQgZX6f_voGypLdZWYt0tKeXdGFe4NPo6mkUe1qSAdEfv',
#    'summonerName': '황혼 우주 자야',
#    'leaguePoints': 543,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 231,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '4C9SBuWQCobzgJRByfaZR2TYNZftH8HwUJQLbx2jlgrpPqmAVHRmWUYHXg',
#    'summonerName': 'RA 05topking',
#    'leaguePoints': 448,
#    'rank': 'I',
#    'wins': 371,
#    'losses': 355,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tV7bf8aUpe-8G0xHqAH8DLomb5gXrH-bKUuH3TiSkmQ4Ri7E-nErH12X4A',
#    'summonerName': '눈이 보고 싶다',
#    'leaguePoints': 642,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '5xieyI8eKwi3sXMBwDYSCwOvvrPrAMNjGIR2vGugUJIwsQ',
#    'summonerName': '차니는왕쟈디',
#    'leaguePoints': 409,
#    'rank': 'I',
#    'wins': 229,
#    'losses': 209,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '54eQfVboDZYtr0VUvagnjqnMK_DulzilxJaeR9DibAPLq0A',
#    'summonerName': '김연지 03',
#    'leaguePoints': 454,
#    'rank': 'I',
#    'wins': 196,
#    'losses': 177,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jHmwEj6FviK0-8qsS8BlfCJer24x4mx5QLj508o3gYbSWQ',
#    'summonerName': '빤 쓰',
#    'leaguePoints': 521,
#    'rank': 'I',
#    'wins': 253,
#    'losses': 230,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'RbZ9MJxK4K3Pe5io0ZX12LkGACVaPe4TOA8X9A_CegLVHGE5',
#    'summonerName': 'Gen G MilliM',
#    'leaguePoints': 446,
#    'rank': 'I',
#    'wins': 307,
#    'losses': 293,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'jvZRUqpDH95Qks5vhDRaENoN3J5JTMEtCr-gc9j8jNAjMuQ',
#    'summonerName': 'Eunah',
#    'leaguePoints': 401,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'bYf7VO2A8QM95DAh8Uf-tFnzcjoV_QwyTUF37eb0UZd0VMA',
#    'summonerName': 'Felix It S',
#    'leaguePoints': 420,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '6BSm89Qe-VnSfTxAZDI2QUijbr0m32RQEleXp3oX1SCEYAqTpCEA-gKKWw',
#    'summonerName': 'qvttzxcc',
#    'leaguePoints': 532,
#    'rank': 'I',
#    'wins': 145,
#    'losses': 124,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '0tfvQqfaIJ8TWvHjiiaPUqRDwY37WRTw0qaQ-tEOLMUI18wU',
#    'summonerName': 'louii',
#    'leaguePoints': 485,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 119,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oyZ8JqIHnQ5nhWZbWxjN1JmdOe6Cuk54RHnvn7nIKadLF_iw_72mqPI_Og',
#    'summonerName': 'yuffffffff',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 83,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'pbhjm__Q4sYnm-g_k5nArxJTHdOZEhN-OQ7tdnKAqCbACA',
#    'summonerName': '이세돌프리아 fan',
#    'leaguePoints': 533,
#    'rank': 'I',
#    'wins': 299,
#    'losses': 270,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'i_hHISocMxnsOh1PA7zKHBZpB6G-MucywFlMz3vF16XGZCQa5kc1FcxTMA',
#    'summonerName': 'ssunm',
#    'leaguePoints': 466,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 131,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KAb2S2bY9yAFEIYHuONdv3WVJwz1hHHR4Dj_wQDs8pDwmNTOr3BlER1wyg',
#    'summonerName': 'Island School',
#    'leaguePoints': 606,
#    'rank': 'I',
#    'wins': 245,
#    'losses': 201,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'qVXeoyJvJuv_MWeGYLdyqWkSeuzgsSJWnvxrkoL2e324zGyDpjVyg1envA',
#    'summonerName': 'Maquia',
#    'leaguePoints': 438,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 111,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'b5fTB9ZAER0XJ_F76M_rujDd7va6u_rpDnVT2b2mjZLSBSg',
#    'summonerName': 'dontknowrong',
#    'leaguePoints': 476,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 210,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'K7G9KA7ohN3d7HU3oWzQSX-06_viVZYGkN2j7w-LkmiwjGI',
#    'summonerName': '꼬마딩구리',
#    'leaguePoints': 501,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 90,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8401RHlGOwh7y9W0MUrHV4oj-6HNDka4gD3fdHoRG2RjiJLRhtmLCnuEYw',
#    'summonerName': '1997 01 14',
#    'leaguePoints': 406,
#    'rank': 'I',
#    'wins': 108,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '7R3OiFIzcmNaCwFOu1N_2WCwizIiWqZjERNxYgqorkqZxd4GnDNiA0Gitg',
#    'summonerName': 'zyb',
#    'leaguePoints': 458,
#    'rank': 'I',
#    'wins': 171,
#    'losses': 154,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'K8gu-xrgxXn1kEmlVauFbtBNAOYn2b1Sk_2kJpVmYOPBbEw',
#    'summonerName': 'NS Calix',
#    'leaguePoints': 579,
#    'rank': 'I',
#    'wins': 256,
#    'losses': 237,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'NgRXx7R3Mb0owNR1bTJdUUX1wO5tLsTByJFNv4P7hL49CQ',
#    'summonerName': '빌드깎기 장인',
#    'leaguePoints': 411,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7llhpzlA1VBLVqLR0-6ssaNZQR014D8dEEK42sY_rbVlSAY',
#    'summonerName': '시 드',
#    'leaguePoints': 491,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '8jIiG8ZYJrFQcrXVwn9c33hKx6xpNWGcQnE1le7ofyNjSwc',
#    'summonerName': '손덩연',
#    'leaguePoints': 427,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'yxAjl6HMpMvj6R-Z9mDm3Egut5bR8JOaMfoW42zEVn-WPyo',
#    'summonerName': 'Sung Eun',
#    'leaguePoints': 636,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 98,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tnDtfRn82ZGig6YTa6MbfAqx4KU-BEy-3wm_2VYPedT3a-FRkCB9U1dWPQ',
#    'summonerName': '한전드',
#    'leaguePoints': 550,
#    'rank': 'I',
#    'wins': 222,
#    'losses': 193,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wda9mdEKgAKfq11p0mbxz7w4M0iKoAGzMTemNm1irsTtCxk',
#    'summonerName': '죄승호',
#    'leaguePoints': 561,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 132,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'JwM9IMBv_h-nCqXQfPHJYqqtWv5VVLVBZ-DQLeoj5KUzvSg',
#    'summonerName': '읏 자',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 74,
#    'losses': 49,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Labbfs_FlZ4o7InTnXoIenxDRM3gPO3PnPilmBKXDsJDWcjq',
#    'summonerName': 'Dile',
#    'leaguePoints': 469,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'AFgVZBI31JeRaiKDuPFgfaxF6czaztNRaVd7N_dbaREJqb0',
#    'summonerName': '뀨두한',
#    'leaguePoints': 450,
#    'rank': 'I',
#    'wins': 249,
#    'losses': 226,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '7ws4aOKM0brlyTK6h_tlqtYjNBtmE9tES7gM7LCDqvJdPfEoexiJ9dgD6A',
#    'summonerName': 'BLGzhao735395996',
#    'leaguePoints': 524,
#    'rank': 'I',
#    'wins': 266,
#    'losses': 253,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'TwK3Q6Ue_XKC9yCjXnSjnbUbQWRKtrqGvT-XcaYBgTUEpHpMmeuFH0E9jQ',
#    'summonerName': '구오일삼육칠구',
#    'leaguePoints': 667,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 124,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'nkt3UhARzKkYvl45JusXigaTetMgNkJOCCkpzVZhG6RWX6KhhaMq54IeoA',
#    'summonerName': '포식자',
#    'leaguePoints': 474,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 130,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'SoVo2K9hpccjOG4GU_g9uO1LUCC7gRdyUBtegvawzFXPTwe_jxBgvPt0hw',
#    'summonerName': 'Trough',
#    'leaguePoints': 460,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 158,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'FBzS2o9z3AIv89jNFqUtK7Bby2V4pdiPUv0ZtClH0AxGNp0',
#    'summonerName': '김검메',
#    'leaguePoints': 439,
#    'rank': 'I',
#    'wins': 157,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '4LkyjEkM2rCumu-h4lwO8MleA5Tt8q1ol3aC1oL49ZW8W1Y',
#    'summonerName': '쪼잔하게 굴거야',
#    'leaguePoints': 657,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FHsBoG5X16ocSNJru7aAjconYnVjmT118-g4M_2RhNPfyhgr',
#    'summonerName': '넌고라니내꼬라니',
#    'leaguePoints': 453,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'hlKtXmmS5ypvdRU7R4SKHUA23zI-IAqzJdnEBIFq6XGxUKk',
#    'summonerName': '뒤지지좀말아',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'Q1JjDp3xg1nOtvma2s5s5p1uPPRqyOfhj9Aybo4e5ivBEu4',
#    'summonerName': 'O1nce',
#    'leaguePoints': 420,
#    'rank': 'I',
#    'wins': 171,
#    'losses': 149,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OP7G1neTJMWyiGO_8jZ1hBt0AWsJZ1rszv749_7HuEdyblHNB0f1sJBiGQ',
#    'summonerName': '카나비1',
#    'leaguePoints': 612,
#    'rank': 'I',
#    'wins': 220,
#    'losses': 198,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'mVLUVStkDeVcpyNd4WtuPjtRT8PufeZV3ZT4as9LA_O8HCk',
#    'summonerName': 'Sry Sup Gap ToT',
#    'leaguePoints': 415,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'YyL0Lqd47Sww4pQ8U_FRcD9HLrORw-v5qgDql8t2n2idvj8oyCmv-7Jfrg',
#    'summonerName': 'not too far',
#    'leaguePoints': 539,
#    'rank': 'I',
#    'wins': 75,
#    'losses': 52,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1zC6gs1zizrl72_WCM-ILWsLdpVuNag15RebZH5YEJVQ0A',
#    'summonerName': '갈과 배 음료',
#    'leaguePoints': 671,
#    'rank': 'I',
#    'wins': 204,
#    'losses': 185,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Dw57al6sfXdwZkxVZldX_DX3kb9TAiB2XmW5gkabTa_1YA',
#    'summonerName': '오수빈너뿐이야',
#    'leaguePoints': 429,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'qLGvJOgIlWtRVQ3KacTuZ-3WFootHzeE1-NUEOZ0djQI0FRLw2EhMVz8vA',
#    'summonerName': '08 Seong',
#    'leaguePoints': 608,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 153,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mZbrUtM1BYEz8a8XnON73xHJ4PB5Dqqn8nvOLN7FuHt8UAsEveSAa0siPw',
#    'summonerName': '근히키',
#    'leaguePoints': 658,
#    'rank': 'I',
#    'wins': 139,
#    'losses': 124,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'cRNFkSz60V8VUgg5FmGCA8nQVIlyIh06hTmvn3Shdask5e6RkSX7LpkXmg',
#    'summonerName': 'whatisfreedom',
#    'leaguePoints': 627,
#    'rank': 'I',
#    'wins': 223,
#    'losses': 196,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'L6K75gI1uhXtnhB403EFbpQPLjZ-yrFleM6cRWNX88GckaI',
#    'summonerName': 'Faked',
#    'leaguePoints': 333,
#    'rank': 'I',
#    'wins': 264,
#    'losses': 262,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KFBZSaXRCAcrLtJWQJXu2zNeqD0NfKUku5T042JBuciW6ROOpYEFhxIJ2A',
#    'summonerName': '또 한 해',
#    'leaguePoints': 448,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 130,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Gare5J9ESnaCylsZkGqzldZAE0rQgkSqNNrba-A4EgF0APw',
#    'summonerName': 'lIIIlllIIIIlll',
#    'leaguePoints': 627,
#    'rank': 'I',
#    'wins': 236,
#    'losses': 214,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'asCqtscjsX1MaCZFVkWxJW9YTgbt-D12enNlXQRaQaATPvHFD0Q5o8zfOg',
#    'summonerName': 'UNDER THE TREEE',
#    'leaguePoints': 462,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 279,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ZO0W83KiVmbuMCxJjT9jOlP47slptSVW1HlTeMyVcjsBg06wi7n_uTg48g',
#    'summonerName': '성진우 fan',
#    'leaguePoints': 537,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 131,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'NMnEwvOoV_Fb47itDjQr99DJbwHVL5UiHXn0e1HlAi_ltA',
#    'summonerName': '송창근SONG',
#    'leaguePoints': 619,
#    'rank': 'I',
#    'wins': 192,
#    'losses': 173,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'gM7ZIKlC4aBaMyE1xNaP2hbObN4mv6c4r6DQZEePoaFq3_VmPcffV3O2jg',
#    'summonerName': 'xiaogaozi9',
#    'leaguePoints': 599,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '0IbjIqS1SSs2Dn8iPzOtNl3O8YtcrGR7OBu_uHk3l4ht_mQ',
#    'summonerName': '애니비아안한다',
#    'leaguePoints': 442,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'kRvo9lYs73CzLzgur4JcFKMX5e7w5srBKgH6J14HrGUDgHc',
#    'summonerName': '1vsAll',
#    'leaguePoints': 524,
#    'rank': 'I',
#    'wins': 193,
#    'losses': 161,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'myKDmRMXqvBApqcG-tTSiEZ-UifhZyGIwU0z9-09qoHPQxW2YAq6oaO2CQ',
#    'summonerName': 'Fzzovo',
#    'leaguePoints': 460,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'rKgFI8fhLlqZisnA_0tDbRwW3sER0d9JgwhaTA_EJFUagH0',
#    'summonerName': 'Lukalux',
#    'leaguePoints': 519,
#    'rank': 'I',
#    'wins': 157,
#    'losses': 135,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Gbr3Bl71OCl6Yhy1e4sWR2TFH7HPHnIZJT1mqrbLuyR7fF8',
#    'summonerName': '주니어 네키',
#    'leaguePoints': 574,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 161,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'gtaWsm2KgGQdflq_M1-fT_CrCpw-B7Bh7J0Hywo6S6EecLEFFEsIN9hi1w',
#    'summonerName': 'Dongjingshuaige',
#    'leaguePoints': 464,
#    'rank': 'I',
#    'wins': 88,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'EhGyCsLIYvan0pD01gzGs_0RKfV2ZLg2P3o9zU0B6rOfOCY_eXd5VXGbGQ',
#    'summonerName': 'kiiiiin',
#    'leaguePoints': 488,
#    'rank': 'I',
#    'wins': 441,
#    'losses': 425,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wHecFdNauDwQkENUBsedbx584Fm0urjq1Q3KaD-0Gh4_JGI',
#    'summonerName': '교이스갱생시키기',
#    'leaguePoints': 490,
#    'rank': 'I',
#    'wins': 234,
#    'losses': 211,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'rK_DZ6SpHZH12sLlrBJ0DU9fIvItyIbHWHNKwc_66hxbtsQ',
#    'summonerName': '조고마한 달기',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '0RPpyl6jYrNBPn4_ys50Y6Tz2vBg5tx5OjjZMT4I0qflSYqUlnoZ5s686g',
#    'summonerName': '단대미',
#    'leaguePoints': 457,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 145,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'PGPaM1aipjvZQUXzv89DU755F4ibWvZ0SXo1BXS0RQ3ibAI',
#    'summonerName': 'Incident',
#    'leaguePoints': 425,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'tj-tHI13JS-G8kZYBuZ_Z8TqIw0jQUwkVv8oFzzB1dYRrds-EpqzRnPJig',
#    'summonerName': '1slonely',
#    'leaguePoints': 496,
#    'rank': 'I',
#    'wins': 73,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'dB7g8Z31oy6IRzdMym3PHQQNi84u6zf6U_UGYXtw8-dksLc',
#    'summonerName': 'Real Graves',
#    'leaguePoints': 519,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'aK3PgbEKsrvk32QVhiRDBNOSzVdRxLmtxRYjY1UI_6bphB0tx2IGTNb2VA',
#    'summonerName': '잘 생긴 아프로',
#    'leaguePoints': 509,
#    'rank': 'I',
#    'wins': 321,
#    'losses': 301,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'f3Xdc6_hwcgbRZGX9uLQYO7E8KMNRYj2vzga1cfcVumz8PI',
#    'summonerName': 'Beau Voyage',
#    'leaguePoints': 464,
#    'rank': 'I',
#    'wins': 70,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PM83GQAn4Y9sdLeFbqhUmDk-1j-pbduNjd4-jQXRCRrg-AzhVin_HKysJQ',
#    'summonerName': '항상 웃는 승민이',
#    'leaguePoints': 655,
#    'rank': 'I',
#    'wins': 200,
#    'losses': 171,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'YwQMfg2n4wE2Dx30kLMn1JpfYUsuMs3ido3uEMaIEIBP4mM',
#    'summonerName': 'mhxt',
#    'leaguePoints': 412,
#    'rank': 'I',
#    'wins': 71,
#    'losses': 46,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'IBQSsS3FxWNTwXRmba5Y0jBWYmizkLSVniEFx4O8esoEzpo',
#    'summonerName': 'RUMBLE',
#    'leaguePoints': 592,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 233,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'O8em38BU-OXB1fGtEnZ3sEe2YbyR-Q7lu4feZUxuCWjvOEbWLXFFR2PfPQ',
#    'summonerName': ' 육식동물거북이',
#    'leaguePoints': 459,
#    'rank': 'I',
#    'wins': 186,
#    'losses': 161,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'powBSQO8FjHhnmf7fmY9jG4t1LAHtd8H23gG99AesqPeLw',
#    'summonerName': '말랑쪼꼬미',
#    'leaguePoints': 421,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 110,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'pyDErkNwPBGACzFktazjoxisreRHaHaO7O2otEScL0MkYtyRm147m-tbJw',
#    'summonerName': 'tirrrrrrrrred',
#    'leaguePoints': 493,
#    'rank': 'I',
#    'wins': 62,
#    'losses': 37,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ub5s_R8zcT3ZFr0w4dXhGbIjk_3l_G4wAYUKWoJb6dp1mg',
#    'summonerName': '180cm73kg19cm',
#    'leaguePoints': 485,
#    'rank': 'I',
#    'wins': 163,
#    'losses': 124,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'blAFSazLwCwa1shxRwzAyTAzbeMzsZ3D3-YPiMuLQ3thEFM',
#    'summonerName': 'kepa de jinyu',
#    'leaguePoints': 452,
#    'rank': 'I',
#    'wins': 171,
#    'losses': 145,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'owVibezoV0YQCSsdWxQDNDLBxnFnryFAuq5N2T8UBXPc8qtWKbuUhMmZVg',
#    'summonerName': 'Run Hlgh2r',
#    'leaguePoints': 431,
#    'rank': 'I',
#    'wins': 139,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'gaAxj0XkJQkmnxKZ0EICrGHAwE8XQ8ioqmMdKUe4s4p1s3MhnYbxx42TYw',
#    'summonerName': '5leec',
#    'leaguePoints': 485,
#    'rank': 'I',
#    'wins': 341,
#    'losses': 318,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nKivNfbOCGAvlZ1f2_CsNJz6ipr3qg9isg5wdiqH-UUZb_AdYAGiMXI0kA',
#    'summonerName': 'igcse',
#    'leaguePoints': 412,
#    'rank': 'I',
#    'wins': 69,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'trZg2dE-PhLYtNsg4sdEL69c6432jbMmucJjPL9wt-6y7SAA',
#    'summonerName': 'dubooyeon',
#    'leaguePoints': 463,
#    'rank': 'I',
#    'wins': 322,
#    'losses': 294,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '02rUl37XV7PXM3TYDdoQsda_uWFYOX264HjzheOAd_G_5XA',
#    'summonerName': 'Lehends',
#    'leaguePoints': 535,
#    'rank': 'I',
#    'wins': 65,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'GDOsIWR9BGXhJaZ8ttRns4q1E_DsKR5keI36WATngwmJ4zI',
#    'summonerName': '미스포츈외길인생',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 279,
#    'losses': 270,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'NHRNzsvt5LsYEVzoJCVuvjcxdVlxxyhxtgfE1-j3KRhxtXs',
#    'summonerName': '세 가족 행복하게',
#    'leaguePoints': 301,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 168,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Cs4kz1ZJmY1hs_-dyXOzvwxVdW5d35IWQhsQ5ANQNtZ027c',
#    'summonerName': 'NS HH',
#    'leaguePoints': 654,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 130,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'XkmxWDQywIV9I8QSeHxqGWtdVTD_0TEvd41dPkLg6sdqlA',
#    'summonerName': 'Pooh n Bene',
#    'leaguePoints': 425,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'MotdpMd7abAwcY6mijrQohg0pvonlJtUbpA4gYcluZ-C2_M',
#    'summonerName': 'Caitan',
#    'leaguePoints': 498,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 64,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0tK6CAHNgW53otAxSQsHBTFyYZac55fj3IbwyoeE6T6TWzi36zaFEOU7DA',
#    'summonerName': 'Change in life',
#    'leaguePoints': 521,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 149,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'PbyKLpKM475ywUGCqNTdrRD6WGkINYVTbig9eZ-9SfhdS1M',
#    'summonerName': '초보자입니둥',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 180,
#    'losses': 175,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'zJ4K0k0SmBpCjlaJ5AKb2k9A_CmdU5e_70b9nCKvxVa31NEl',
#    'summonerName': 'chi1',
#    'leaguePoints': 598,
#    'rank': 'I',
#    'wins': 121,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'YhxWTPSXeToLyy0YJM7rGi2W-BrGxX1825dlCrq04qbw4XE',
#    'summonerName': '04sup프로지망',
#    'leaguePoints': 444,
#    'rank': 'I',
#    'wins': 128,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Vw8wiIwfntTpRkI999N4S4b76mKcrYTm3nBXdq1uFEA0eqA',
#    'summonerName': '화려한 솔로킬',
#    'leaguePoints': 618,
#    'rank': 'I',
#    'wins': 224,
#    'losses': 193,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'cS7_KLyAfFl71yEWSHlpkbDd4h6qFGWfAVk3h5n04UTsGFFAm9vAkSvkLg',
#    'summonerName': 'FA Yursan7',
#    'leaguePoints': 414,
#    'rank': 'I',
#    'wins': 136,
#    'losses': 131,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'MKMsOIRWqizORoxhriyPMfQHxI4uJKAyC7JuPaXUZsM7a9g',
#    'summonerName': 'fkch',
#    'leaguePoints': 444,
#    'rank': 'I',
#    'wins': 312,
#    'losses': 296,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'sII00IuwEKbZzkvTuflFEbPpGSRNCu1krguCFKmzhIw7r2QPoERV4cc45g',
#    'summonerName': 'mliw',
#    'leaguePoints': 495,
#    'rank': 'I',
#    'wins': 126,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bqc8oLaio0tFK8ACpAkygTMrxhUdZzd4fkAUZy7qBuv3vw',
#    'summonerName': '콩알탄콩콩',
#    'leaguePoints': 443,
#    'rank': 'I',
#    'wins': 115,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'sZ248c5IzEFTdjjdXtaLQOWL4zswLXcfd7pR9TrlmgTltA',
#    'summonerName': '궁댕히',
#    'leaguePoints': 531,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '06tBboUuAN8_0sIukUXZzGcpFT1624ho7XrV53z6AHFFrA',
#    'summonerName': '뭐라고번역하지',
#    'leaguePoints': 613,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jm1QuYfaMd5Mcd0pYI3ABNsUF4JUJAuMzW9Qewb4ussmjBYSF4oJqCtgdQ',
#    'summonerName': 'IAKIL',
#    'leaguePoints': 558,
#    'rank': 'I',
#    'wins': 241,
#    'losses': 223,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VocpzlOR49kby5mdftP8Iej3ttOwjgHGnnbd8avBcDPT6CO8Bq_P1QFx_w',
#    'summonerName': 'mxmmmx',
#    'leaguePoints': 381,
#    'rank': 'I',
#    'wins': 156,
#    'losses': 142,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'doHG9yJlzq08d7oWAn-ltXsFOrlY6KaCUUNBYIdm4SqqzZUladFUp7wk5g',
#    'summonerName': 'DON BARON',
#    'leaguePoints': 617,
#    'rank': 'I',
#    'wins': 300,
#    'losses': 257,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'pUlS68LzfHG2tc9naqoPHYCg5Y53PgjZZZghaEt1ytakr6g',
#    'summonerName': '서머바이',
#    'leaguePoints': 441,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'YIDuh2sr_plnJku8R4CLYhn745Uk8bAPDixiymmRNAlz0vM',
#    'summonerName': '조관우급 늪 설치',
#    'leaguePoints': 550,
#    'rank': 'I',
#    'wins': 160,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'kXJwk4nrFNQArEIIxTZYpcGwF-R5nNlsMo0DWj9iSaLXhKXkL9CODF01KA',
#    'summonerName': 'R8 r',
#    'leaguePoints': 393,
#    'rank': 'I',
#    'wins': 237,
#    'losses': 198,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OsUJjv4gvsEwrvtZUtcNUzxQGlxAl7A9MfTiJKAa5ap9dg',
#    'summonerName': '물다이아',
#    'leaguePoints': 485,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 116,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Lh-XiOYjlm21X9Xbh9z1IdTfFLgnl_LNP2iOPWSDZ1j5DIhCL-h__2hRsQ',
#    'summonerName': '온 재',
#    'leaguePoints': 570,
#    'rank': 'I',
#    'wins': 227,
#    'losses': 205,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'yynIG9CV0Rnqw5bfcr5sw692yl4q-LJreYOME-4kpumfODQ',
#    'summonerName': '신재욱',
#    'leaguePoints': 420,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 125,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'wiLEDexl8cgwCygRaCN9bT743nYyCtIehnDC0K6axYF1rKs',
#    'summonerName': '현재메타머리박기',
#    'leaguePoints': 645,
#    'rank': 'I',
#    'wins': 209,
#    'losses': 181,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Bju56QDDFjTUP5FcHbZss9oduFVbd_rtwiuDygupsFAnT-I',
#    'summonerName': '예 샨',
#    'leaguePoints': 535,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'XmsfCzMEOibob6vgUDLQBl8-3YKxswyrXZoBbKoLJW8yxQM',
#    'summonerName': '비가 오고 나면',
#    'leaguePoints': 516,
#    'rank': 'I',
#    'wins': 397,
#    'losses': 372,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'L2XAb1yGOJ58nT3NNpV3JVnJ2OUYOC3EI6FKykuElbZUvaQ',
#    'summonerName': '앞에총노리쇠후퇴',
#    'leaguePoints': 580,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 112,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '60GIieD8pmZ4wE9UphCZlLnz2aHmmbjwskd5kpUkoCeTy2s',
#    'summonerName': 'Charlie2',
#    'leaguePoints': 531,
#    'rank': 'I',
#    'wins': 93,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'aPtCGwfBgY0x3oXkzbC1zy0FIx6lCwP6XMwlgnL_oHLf1Fs',
#    'summonerName': '통나무내려놓기',
#    'leaguePoints': 464,
#    'rank': 'I',
#    'wins': 252,
#    'losses': 233,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ZuhGrwY3THTiOMH4rX5ueXNf9voy4fjeT10GKQvYYRQfqi4',
#    'summonerName': '트위치이성진1234',
#    'leaguePoints': 419,
#    'rank': 'I',
#    'wins': 71,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'zIXGD413VSsamzP0ufyc28HWn_8Y6niPLI-OkrhIie3zi1VJ_c0BgpLe5Q',
#    'summonerName': '롤체프로게이머',
#    'leaguePoints': 415,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 81,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'zeyaL2MLjKGSZo41uu6eqGyxJOjBBmn9PKpTfqF2z2XZsa4',
#    'summonerName': 'NS Sounda',
#    'leaguePoints': 520,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'L0Zxj1-sSiL2yHyS9UFSV6cua074pfhCWCazv42CuD1guJd9XJHe0utk1A',
#    'summonerName': '저는요꿩꿩꿩',
#    'leaguePoints': 635,
#    'rank': 'I',
#    'wins': 138,
#    'losses': 111,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'CW_al0lKpWGdNh8vXVM7Vxd-Fi8KjFbGqq2n50-_brtbYFs',
#    'summonerName': '워키라카토키',
#    'leaguePoints': 546,
#    'rank': 'I',
#    'wins': 191,
#    'losses': 171,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'iCT3DTthCI1Sk4HzAuglojftjRJ9a1mV7WKAAXnc612B6QQ',
#    'summonerName': 'ecrrd',
#    'leaguePoints': 623,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 50,
# ...
#   {'summonerId': 'iE8AxsRQiEyZ2VZ-od38-FWMQ7kcO1YKIM67_hHuT7SUEIU',
#    'summonerName': 'SibasakiRoka',
#    'leaguePoints': 408,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 139,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PNy6igtjLjR-4QX7TriKGdeParWoMtqz645ebE2EdvkxrOs',
#    'summonerName': '개미1친놈',
#    'leaguePoints': 481,
#    'rank': 'I',
#    'wins': 257,
#    'losses': 230,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'wcwUqFtn1dYUDivhPWX9ZiZXABQ37ytdkibYVrc5aXV-dBU',
#    'summonerName': 'sick villain',
#    'leaguePoints': 648,
#    'rank': 'I',
#    'wins': 108,
#    'losses': 80,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'dEv_WoOcLT9zwrn46_c4RRjSmEaUYjFKz2jUeIQrSOIbsdimYjPsnM_8ww',
#    'summonerName': '한국인입니다6',
#    'leaguePoints': 466,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 93,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'xncYSmqAWmutlUR-oPU-l3xl-7UHOo_aWpmDVX_YgIy6mlI7exBkBok5yg',
#    'summonerName': '뒷각 볼게',
#    'leaguePoints': 382,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'uzlnjcgiwEPc1vxfQVlPEb5_ShARD7Fq1CbvH4lLwatyuF5JR8_hXDVZ2Q',
#    'summonerName': 'Kirby Mario Link',
#    'leaguePoints': 452,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'dlV5fFMf96fxuFPLda60ZYq8KEZSgPFZ0qhsnS9O-bS3vOgZbXLX-nJPdw',
#    'summonerName': '화려한화려한',
#    'leaguePoints': 589,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 108,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'LCTENccYVSxk-V_3jYy57dc3OMupUlr-ZEbX3UwQlDZmSw',
#    'summonerName': '우치하 찬스케',
#    'leaguePoints': 432,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bgqb-g0EQkQOh8e9UoZfTIne56A1Ls7YTce7Q19ETKvRAde10djVeC6reg',
#    'summonerName': 'YQYQ',
#    'leaguePoints': 524,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 139,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jtuXhaiuTjtWmaoPj5Xev2Dtm2lDAwGMPs3qCNEn0Y66954',
#    'summonerName': '역체폿 마타 ',
#    'leaguePoints': 454,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 109,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'sEOfVxb5Yi75Ag5qOn6VK_JoOdDv69j_dXvF-HI77Ry2LACH',
#    'summonerName': '98765432123',
#    'leaguePoints': 429,
#    'rank': 'I',
#    'wins': 141,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ih61I5hWgWR1htOwSv9N25wnTPcG5DLxOJUslgShr_hCS98',
#    'summonerName': 'KT 기리',
#    'leaguePoints': 474,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'WehYNi2TGgtz17Je6FsvAcoUXwrv_Zk2tR7Y_fIvEtvJlaA',
#    'summonerName': '뭐너가어쩔건데',
#    'leaguePoints': 700,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0EvMLoj0KbBfBN-PC3BWZnOkoRYQybv45V8cbmeW1vzbXos',
#    'summonerName': 'vzac',
#    'leaguePoints': 563,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 113,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wLN17VyLkO4UNQ_Mz-toNMX6e5iwLva7LytqsW-kxluUpXxu7NP-CqLvKQ',
#    'summonerName': 'HLE 이준민',
#    'leaguePoints': 457,
#    'rank': 'I',
#    'wins': 320,
#    'losses': 307,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '0tohceYntb2ksmwQ6i8Kq3hKol-Dsm501El3eyOs0NOj5gk',
#    'summonerName': '무서기',
#    'leaguePoints': 511,
#    'rank': 'I',
#    'wins': 183,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'SaXeGQ3cKXa9zDqUYJISpWJWgi6o_lt-Wk8zlJoSY4wN2JXqnnNXF2Ndaw',
#    'summonerName': 'Haeoreum',
#    'leaguePoints': 495,
#    'rank': 'I',
#    'wins': 138,
#    'losses': 110,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'H0sOVH5Y--FuU8Ft-OUmY05jFtX2epXNSmMQ98ojIPiFr9k',
#    'summonerName': 'lmperial',
#    'leaguePoints': 577,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 202,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'pMvL5lHz72SQGvNaPpALbdSMyCBVasn_KgAA3jlqlwBLQrA',
#    'summonerName': '마라탕맛있네',
#    'leaguePoints': 572,
#    'rank': 'I',
#    'wins': 141,
#    'losses': 129,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'IaXQINzO6qCxOMxluvYqd_q7b_W--oQf4UeU-TV_fcKUSg',
#    'summonerName': '00 OP2',
#    'leaguePoints': 414,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 126,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'dM4OWUreqcHtfj7tkh-5luMtnGtJe8r1NJ1eaEuz6yKIleo',
#    'summonerName': '자신감이필요해',
#    'leaguePoints': 506,
#    'rank': 'I',
#    'wins': 316,
#    'losses': 294,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'QPL5cJT_QyqFAjB4lYaNVbxF4Zld9BfI1HOo71QTGNukW5vM-bsL9N2YoA',
#    'summonerName': 'oh1oh2oh3',
#    'leaguePoints': 472,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 137,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'CIM8BqL-o3RS-KnaMBtl8uWSKhKlmbK0Nga40oX-43QSbIQ',
#    'summonerName': 'DoJerry',
#    'leaguePoints': 420,
#    'rank': 'I',
#    'wins': 196,
#    'losses': 181,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '2RWZblCNTQnQFPiJfNJHnXLlyttFTnSdVmpTlSXChNGIFGjYaq37frW3Uw',
#    'summonerName': '수요일은다먹는날',
#    'leaguePoints': 624,
#    'rank': 'I',
#    'wins': 198,
#    'losses': 172,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'BTIByh_HFWtmTENXJRyPsqj_jWNCZ3gkKroHRRahUeWLmls',
#    'summonerName': 'Loafers',
#    'leaguePoints': 420,
#    'rank': 'I',
#    'wins': 346,
#    'losses': 327,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FhSKVPMVn0PNTI-grZfWnfQMnyZXA98K1dcfEKUyQ5rbBbU',
#    'summonerName': 'NS Mihile',
#    'leaguePoints': 431,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 131,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'N_yO4ex5zGZM3knVOUGxxJBXyXVfVZ50EPwkRzUbInhsPP0M-sjAamNWeA',
#    'summonerName': 'bus승객입니다',
#    'leaguePoints': 417,
#    'rank': 'I',
#    'wins': 202,
#    'losses': 177,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'BY1TYRYQQKV_KtjTSqa4tUnNmNGPXaBX-MnOKd-LbHktKro',
#    'summonerName': 'Plz Gank',
#    'leaguePoints': 439,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 81,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'w_HwmtI8QJ67r10F4Zqqj_Yb1nart1b1oh3jYSYrq5g48Yg',
#    'summonerName': 'Onlyven',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 61,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'lLOZqsB0msBFJh5LE19FJvaKpm0GKEsViYubo5ztUZlaOG8',
#    'summonerName': 'Emperor penguin1',
#    'leaguePoints': 721,
#    'rank': 'I',
#    'wins': 396,
#    'losses': 367,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ePZVBZMzrHM2OaV3rPTx6d302xWvmnqt_lW-8AGQGRo_zA',
#    'summonerName': '강한행운형',
#    'leaguePoints': 638,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 204,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bHkT7vwLm2SdOGucc1RdIJTHCfVT69wkNvRBE0nV2Qd_g6w',
#    'summonerName': '아이린',
#    'leaguePoints': 612,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 85,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'YYIoHc3YWqXJsBWclWYDA-KwXlkrykvX2mzSdTnNtojTFjL_FFqwNN2ZcQ',
#    'summonerName': 'BX8KK',
#    'leaguePoints': 591,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 60,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Xe1cw4Sz-TuRsLmCtJifyNCuf3WcUkTmpBb8RUFYZ8XmdadBvNNSxVn_qA',
#    'summonerName': 'NuiTt',
#    'leaguePoints': 562,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 151,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'o26VkXzpod6boqoUR7Gej8iidx9slRFfwe6sPYWEx030wEE',
#    'summonerName': '이지만07',
#    'leaguePoints': 408,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 125,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'K9tzKY7YOxocBfBhnkIOmdUAR-VpN-1mIwLA4g8_Hh2Xyk4',
#    'summonerName': '조금만더잘해보자',
#    'leaguePoints': 411,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'Jh_Dg289-Wcbo_cwbBr6-iwbzpnZGBGtqaLQV0Ql6nKLHsS5S1qnofN1Qw',
#    'summonerName': '우주 럭스',
#    'leaguePoints': 412,
#    'rank': 'I',
#    'wins': 67,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1HtAo9ytUJEe_T7zYS4QHEWt-0QAdIA3KNOTrtQO3Srrjg',
#    'summonerName': '자메이카흑인',
#    'leaguePoints': 609,
#    'rank': 'I',
#    'wins': 244,
#    'losses': 219,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tOi32p6YrxuWrBAirCHrXy9wH0uljYirSM038UQT8Nk2pVw5Xf7dLvBujg',
#    'summonerName': 'born to lose',
#    'leaguePoints': 442,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'jTUwSxqyxzsd6uf8Onob7Ql6hpIpGPdtv09mh_BJ-fOYz6A',
#    'summonerName': '슈퍼빅고수',
#    'leaguePoints': 579,
#    'rank': 'I',
#    'wins': 116,
#    'losses': 89,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8dLfb2cniank9VYgq5l56lmCOqfGVE4vENYSUP0pGDM0vSEH72vGLk8lbQ',
#    'summonerName': 'asdfghjklqg',
#    'leaguePoints': 499,
#    'rank': 'I',
#    'wins': 59,
#    'losses': 30,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ahphE4NC6OKZ6TPG2CaxQaBQ6F6gI24lNFmkp5DKoSe8r9Izf9zMKAxPPQ',
#    'summonerName': '미니언14',
#    'leaguePoints': 678,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'cVW7_NO_bNs3Flw-ZUhGnpU4rM-0TVsBoi2RK6HP5tUBXQ0',
#    'summonerName': 'Baroh',
#    'leaguePoints': 570,
#    'rank': 'I',
#    'wins': 315,
#    'losses': 296,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'suQnUw5MoN7cRpT7cGV379WlXEEl_yJ5RFwZUpLN5ChBY4DTT7enqqU0Sw',
#    'summonerName': '미치에다 슌스케l',
#    'leaguePoints': 423,
#    'rank': 'I',
#    'wins': 350,
#    'losses': 330,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '48kLTDJdlxNY1oqhxayanhsU13YmGVnDXIF6oGWLzzXJfHot',
#    'summonerName': '짜니에몽',
#    'leaguePoints': 453,
#    'rank': 'I',
#    'wins': 167,
#    'losses': 141,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wJJ92qFqNELcLmk2jzsiJ5U8-Bnd7R2LmsRhNxaCL97RQ13OYcUdYZXVtg',
#    'summonerName': '첫 봄1',
#    'leaguePoints': 485,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 108,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KS3d4scNGV4ONmbniJACi4q_M8sq9vWWsJXSTe5JLou-smRHFZMf-34Lvg',
#    'summonerName': 'asdfqw',
#    'leaguePoints': 469,
#    'rank': 'I',
#    'wins': 279,
#    'losses': 261,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'BLYe4PKA1wa5R14o0wVfxkirzDIwltvfNooIHOybplkYmMsJjbCbFeMt6A',
#    'summonerName': '절대집중력2',
#    'leaguePoints': 463,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'e4hLKv8u0HI8JJ9Wb5YOzJGQw85CpEdYVCmfqDCt5-uAoBO7alH1AskOuA',
#    'summonerName': 'permenban0002256',
#    'leaguePoints': 630,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 116,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'W54OnOVhg6SXB97PF1qFrYNax30EOv0_yVShGmdlJ1oaxz4',
#    'summonerName': '생각또생각',
#    'leaguePoints': 547,
#    'rank': 'I',
#    'wins': 167,
#    'losses': 144,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'z_8Hsk-_JkaGyV-uk3CZw0oe4FHaLHlJutFtmkAHh_CwoMKH',
#    'summonerName': 'not want to fail',
#    'leaguePoints': 472,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ea2jPci_-k9i6eSR-zoMi0AqQaAMIuT2JEY4tPVm2O63RWlyDLY1padZ3g',
#    'summonerName': 'Inhp',
#    'leaguePoints': 623,
#    'rank': 'I',
#    'wins': 359,
#    'losses': 336,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'gEyUykST_OgI6DB9XOGnvrXQvu-iMoUeFz6LXgaHoa-GLlg',
#    'summonerName': 'THE JAB PACK Pt1',
#    'leaguePoints': 469,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jR-qU_R3bGGC8MFtku3ENWYJPJFbIXfYmiTkpFGEpuaLMQc',
#    'summonerName': '도천지',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 233,
#    'losses': 209,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OUD9EErfWKH6PuRAHs-2EkTKLX4d-8gZ_AO78lsp-dfPPTs',
#    'summonerName': '스물다섯번째밤',
#    'leaguePoints': 624,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 135,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'e-Xk3-rqXU8ToCd3Sa0bBnFl8x24UTTv50JRfaawiZR_MF0',
#    'summonerName': 'YOUSONOJAM',
#    'leaguePoints': 614,
#    'rank': 'I',
#    'wins': 305,
#    'losses': 258,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'F8koDBVm2W2JFylrsOO9KzMX9-yFBoKAp-B9Vm0-BddpKeGF',
#    'summonerName': '청포도육포',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'p0F11D7a_LdCOArcFbeeU4Gcn4D8NLCA47Q38CrAtne07UmOXljCNVsdPA',
#    'summonerName': 'xxmm',
#    'leaguePoints': 609,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 56,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2BmTR-bYxX_qjRt2GQZHiIvWY7fdr1Hqt263m3DCEZwyieM',
#    'summonerName': '누누교수',
#    'leaguePoints': 589,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 236,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AVTDeGO9gd3c8hUW0M1xdboQ0ybXWR8RSAeVijbPwMXAm-Q',
#    'summonerName': '야돈급 반응속도',
#    'leaguePoints': 450,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 110,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False}]}

# %%
len(res['entries'])
# Out:
# 700

# %%
import time

# %%
start = time.time()
summor_name_lst = [s['summonerName'] for s in res['entries']]
print(time.time()-start)
# Out:
# 0.0

# %%
start = time.time()
summoner_name_lst = list(map(lambda x: x['summonerName'],res['entries']))
print(time.time()-start)
# Out:
# 0.0

# %%
start = time.time()
summoner_name_lst = []
for i in res['entries']:
    summoner_name_lst.append(i['summonerName'])
print(time.time()-start)
# Out:
# 0.0010001659393310547

# %%
summoner_name_lst
# Out:
# ['ToianD',
#  '아이스티좋아해용',
#  'Promise myself',
#  '이 차가 식기전에',
#  'keskgdkfkt',
#  'MoMoKoKo',
#  'Straight to Hel1',
#  '슈퍼왕초딩잼민이',
#  ' i love luIu',
#  '황매돌',
#  '쿠자니',
#  '화려하게카타리나',
#  'FlawIess',
#  'openbye3',
#  'na xie nian',
#  '2023 NC Dinos',
#  'xi1',
#  'omp5',
#  '귀여워서 죄송합니다',
#  '베르테르',
#  '간다라쿤다',
#  'gnpm',
#  'White Canvas',
#  'gxpnmx',
#  'Sereno',
#  '드 쉽',
#  '아 왜캐 졸리지',
#  '노오란감귤',
#  '응애서코',
#  'tiancaishaonvjie',
#  '매트릭스 탈출자',
#  'NekoL',
#  'maxx',
#  '미안말걸지말아줘',
#  'xxxxlululu',
#  '귀엽고착한여자',
#  '하트 둥글다',
#  '06년생 김유빈',
#  '대머리',
#  '비위맞출바엔자살',
#  '작멍2',
#  '귀큰둥이',
#  '망나니박진수',
#  '원딜가는보민이',
#  'Hide on bush',
#  '가만히진정하다',
#  '유미장인을꿈꾼1',
#  'Azhy',
#  '달팽이는 부러워',
#  'wudi shangdan',
#  '잘떠먹여주세요',
#  '철학자',
#  '울팀이길MOM없음',
#  'qiyaaibeibei',
#  'YKEY',
#  'XiaoHuaSheng7',
#  'lIllIllIIlIl',
#  '우기영',
#  '게살버거',
#  '20001202112',
#  '콩벌레는동글동글',
#  '황혼 우주 자야',
#  'RA 05topking',
#  '눈이 보고 싶다',
#  '차니는왕쟈디',
#  '김연지 03',
#  '빤 쓰',
#  'Gen G MilliM',
#  'Eunah',
#  'Felix It S',
#  'qvttzxcc',
#  'louii',
#  'yuffffffff',
#  '이세돌프리아 fan',
#  'ssunm',
#  'Island School',
#  'Maquia',
#  'dontknowrong',
#  '꼬마딩구리',
#  '1997 01 14',
#  'zyb',
#  'NS Calix',
#  '빌드깎기 장인',
#  '시 드',
#  '손덩연',
#  'Sung Eun',
#  '한전드',
#  '죄승호',
#  '읏 자',
#  'Dile',
#  '뀨두한',
#  'BLGzhao735395996',
#  '구오일삼육칠구',
#  '포식자',
#  'Trough',
#  '김검메',
#  '쪼잔하게 굴거야',
#  '넌고라니내꼬라니',
#  '뒤지지좀말아',
#  'O1nce',
#  '카나비1',
#  'Sry Sup Gap ToT',
#  'not too far',
#  '갈과 배 음료',
#  '오수빈너뿐이야',
#  '08 Seong',
#  '근히키',
#  'whatisfreedom',
#  'Faked',
#  '또 한 해',
#  'lIIIlllIIIIlll',
#  'UNDER THE TREEE',
#  '성진우 fan',
#  '송창근SONG',
#  'xiaogaozi9',
#  '애니비아안한다',
#  '1vsAll',
#  'Fzzovo',
#  'Lukalux',
#  '주니어 네키',
#  'Dongjingshuaige',
#  'kiiiiin',
#  '교이스갱생시키기',
#  '조고마한 달기',
#  '단대미',
#  'Incident',
#  '1slonely',
#  'Real Graves',
#  '잘 생긴 아프로',
#  'Beau Voyage',
#  '항상 웃는 승민이',
#  'mhxt',
#  'RUMBLE',
#  ' 육식동물거북이',
#  '말랑쪼꼬미',
#  'tirrrrrrrrred',
#  '180cm73kg19cm',
#  'kepa de jinyu',
#  'Run Hlgh2r',
#  '5leec',
#  'igcse',
#  'dubooyeon',
#  'Lehends',
#  '미스포츈외길인생',
#  '세 가족 행복하게',
#  'NS HH',
#  'Pooh n Bene',
#  'Caitan',
#  'Change in life',
#  '초보자입니둥',
#  'chi1',
#  '04sup프로지망',
#  '화려한 솔로킬',
#  'FA Yursan7',
#  'fkch',
#  'mliw',
#  '콩알탄콩콩',
#  '궁댕히',
#  '뭐라고번역하지',
#  'IAKIL',
#  'mxmmmx',
#  'DON BARON',
#  '서머바이',
#  '조관우급 늪 설치',
#  'R8 r',
#  '물다이아',
#  '온 재',
#  '신재욱',
#  '현재메타머리박기',
#  '예 샨',
#  '비가 오고 나면',
#  '앞에총노리쇠후퇴',
#  'Charlie2',
#  '통나무내려놓기',
#  '트위치이성진1234',
#  '롤체프로게이머',
#  'NS Sounda',
#  '저는요꿩꿩꿩',
#  '워키라카토키',
#  'ecrrd',
#  '던갈교수',
#  '하민수2',
#  'SSRHHH',
#  'xoxslo',
#  'FA Arad',
#  'PUSGJIUN',
#  '꿍아가',
#  'dfdsfgdsfsdga',
#  'showmaker fans',
#  '에이핑크',
#  '멘탈존1나약해요',
#  '토끼예나 예쁘다',
#  'LOL good game ',
#  'rewind1',
#  '둥 2',
#  '정렉이',
#  '일주일동안천점',
#  '자유로워진영혼',
#  '빈 스토리',
#  'kitasanb',
#  '둠 심',
#  '송플랭크',
#  'DWG 암Canyon',
#  'ycx',
#  'CoBiT',
#  '피들서폿누가함',
#  '원광대 옥진영',
#  '교육잘받은도구',
#  '배나무',
#  'pilotl0l',
#  'lactea420',
#  '트빅카',
#  '토실토실한붕어',
#  '돈 비 어프레이드',
#  'Oh pretty baby',
#  'Dopeboy',
#  '트위찍1',
#  'JUMP DIVE',
#  '후쿠시마산꽃게',
#  'I1IllIIlII',
#  '송지 fan',
#  '초보강아지',
#  'vvwvvvvvvvvvvvvv',
#  '닉정할꺼없음',
#  '뽀삐의 피지컬',
#  'Iove poppy',
#  '벌레탑 부수기',
#  '차라리미치고싶다',
#  '아 도파 아닙니다',
#  'Wayf2',
#  'TES1',
#  'YeQiuFengTCO',
#  'wo shi bailan',
#  'zxczxcc',
#  'my몸에서나가 칸',
#  'NYN',
#  'qwcasxwdscawe',
#  'Bingbingjiang',
#  '안태준은살아있다',
#  '벨베슥',
#  '우또기',
#  'boqi',
#  '김치무말랭이',
#  'DRX B2ryL',
#  '고도의 집중력',
#  '팜 프',
#  'So Slck',
#  'Aerd',
#  'Juhana',
#  'cryscata',
#  'SLOW Shiba64',
#  '사냥꾼',
#  'Find Team',
#  '이우한',
#  '조이마더',
#  'Reply 2 This',
#  '가슴뛰는일',
#  'Aspidiske',
#  'TuTeddy',
#  'pikachao1',
#  'J4YCE',
#  'yoru1204',
#  '너 보고싶어',
#  'zenbucororong',
#  '난 아직 꿈이있어',
#  'shinyoonchul',
#  'BRO Effort',
#  'KATXSSQUIRREL',
#  'KDF Alvingo',
#  'DIOLUG',
#  '내성장막아봐',
#  '딩ger',
#  '더기 김경덕',
#  '상로방어탑',
#  '찌교수님',
#  '시드마이어의문명',
#  '점수 약탈꾼',
#  'Kingen',
#  'fazetwistzz',
#  '저 높은 곳으로',
#  '망토와단검',
#  '농심 흐흐',
#  'jdg369999',
#  'Aphromoo',
#  'Turned to leave',
#  'qwdfeqr',
#  'Vazzrock',
#  'Lv1 갑각류',
#  'qwerzxvcasd',
#  'llllIlllIIllF',
#  '픽셀 쪼가리',
#  '심권호선생님명언',
#  '잘가요 굿바이',
#  'xnmp',
#  '사랑스러운 슬기',
#  'SAD GAME GG XD',
#  'Pray u',
#  '평정심을 잃지마',
#  '불주먹 이준민',
#  'bcr3',
#  'EFFECT1',
#  '낭 만',
#  '슈퍼짱초딩잼민이',
#  'Strive1',
#  'WBG Easyhoon',
#  '구름뚱이',
#  '채 식 좋 아',
#  'BRO Morgan',
#  'Rough',
#  '야오공주님',
#  '초카와이수혁쿤',
#  'MWNNWM',
#  '갈아만든배마시따',
#  'sunghyuk39',
#  '우승을 차지하다',
#  'H1ng',
#  'wobuxianghuole',
#  'T1Muses',
#  'Deft DK',
#  'KPL AG Snorlax',
#  '칸 나',
#  'ASOUL DIANA',
#  '송제우',
#  '날아무도모르겠지',
#  'haishangshenghuo',
#  'Autumoo',
#  '배빵빵 재훈이',
#  'Luskan',
#  'zxcvnmzxc1223',
#  'baozaopiqi',
#  '뽀 소 ',
#  '동냥아치',
#  '날죽여   날',
#  '문영화',
#  'IIIlllIII1llII',
#  'NS hwichan',
#  '개화결실',
#  'JustLikeThatKR',
#  '진승민공주님',
#  '나화천이경근이야',
#  'btc and eos',
#  'Megalia',
#  'Ganbarou',
#  '희태시기',
#  'keainvren1',
#  'Gen G GGUL',
#  'Newbie Hunter',
#  '사이버 망령',
#  '워 드',
#  'LSB Dooti',
#  '소브 부계정',
#  'vinaka',
#  '베스트 프랜드',
#  'scyscy0304',
#  'Coach 3114',
#  'KDF 모함',
#  '재벌의 외아들',
#  'loveqiqi',
#  'boongwa',
#  '강붕스1',
#  'Let me sup',
#  'T1 Silky',
#  '준밧드쳐패는놈',
#  'zxsdaxnty',
#  'buxuyaoduiyou',
#  'PkUU',
#  '즐 팡',
#  'This game canwin',
#  '자기객관화시급',
#  'zenbucorona',
#  'Like a Dance',
#  'zuizuizui',
#  'find team 03',
#  '윙화백',
#  'dyjkbysb',
#  '121451132112',
#  '쉐 정',
#  '헤어지기 싫어',
#  '신을저주해',
#  '오송이동생',
#  '이렐아칼리',
#  '소우1',
#  'thx u next',
#  '김민교 수제자',
#  '물망망초',
#  '겨울지나봄이오듯',
#  'dlwlrma22',
#  '사소해zz',
#  '갱후닝',
#  'lovelovekeria',
#  '사람이름이전종진',
#  '지켜주세여',
#  '결 혼',
#  '히카리리',
#  'BRO Karis',
#  '마문2가 죽지않아',
#  'baybayya',
#  '끝난 이야기',
#  '스트레스로돌연사',
#  'peyzz',
#  '매일산책',
#  'NuoNuofans',
#  'DXnuf',
#  '강주연',
#  '30살 탑솔러',
#  'zkwlshqhkfk',
#  '쥬벨머스콩이',
#  'Rich3',
#  '않이익에',
#  'No longer love',
#  'Yuanhao fans',
#  '앤티앤스 프레즐',
#  '북극성 love',
#  'twtv soodangkim',
#  '다죽여버릴거다',
#  'MarcoPoIo',
#  '바론맛우유',
#  '초이통통',
#  '승패관심없는유저',
#  'Kishimiyu',
#  'DK SharveI',
#  'ying',
#  '캐 인',
#  '몽키다마 왕c',
#  '똥 방귀 뿡뿡',
#  'Academy KDF',
#  '유체화수귄',
#  '승재 비질게',
#  '하루평가',
#  '응봉산토깽이',
#  'CrazyCat99',
#  '약하다 별',
#  'Life1',
#  'real gankster',
#  'Gen G Seeder',
#  '하코자키 세리카',
#  '달 바라보다',
#  'Cuzz',
#  'Fatty',
#  '게임하고 싶어04',
#  'Binsenjokasano',
#  'sry adc',
#  '9277',
#  'Why break up',
#  'sry2022',
#  'slow die can win',
#  '너 완전 뱅이였어',
#  'iffffffffffff',
#  '열정은 식지 않아',
#  '수라차',
#  '누가 최고야',
#  'ZOEKlNG',
#  'cai lyn',
#  'Lebewohl Nacht',
#  'GG XD',
#  'WeMeetAtheSummiT',
#  '염 따',
#  '턱 발로 걷어차기',
#  '30H top',
#  'als en ghd',
#  '아이러니',
#  '수학30번',
#  'ye shan',
#  '단국 대표 미드 ',
#  'pinvvei',
#  'TnTnTuTuT',
#  'cherry merry',
#  'jkjkjkjkk',
#  '뇌 녹 사',
#  '정현심',
#  'January 30 L',
#  'NEED HER',
#  'zI존고수짱짱맨',
#  '지루한 현실 꿈',
#  '멘탈 잡는 이현',
#  'betelgeuse2',
#  'meiyounaodai',
#  '에스파 윈터어',
#  'Cody Pog',
#  '미니2',
#  '코알라우는중',
#  '9드론스포닝풀발업저글링',
#  'Ninja 3',
#  '헤 돈',
#  '그라가스할래요',
#  '주현이능만능',
#  '윤서스',
#  'EungNam',
#  '별에서온 이준민',
#  '시고루쟈부죵',
#  'Hanekawa Tsubasa',
#  'MooJin777',
#  'NS OddEye',
#  '항해사 안할래요',
#  '미친듯이 파이팅',
#  'elio7',
#  'Gen G Horange',
#  '10데스 박을게',
#  '수수한수민',
#  'Euphorbia',
#  '카스가장임',
#  'gao qi qiang',
#  'kasia',
#  '뜸뜸 끔',
#  '아이러브조이',
#  'AfreecaTV 양만득',
#  'frSs',
#  '진주 이민웅',
#  'Xiaolaoshuzzz',
#  '지응성',
#  'Im dinner',
#  '자자 목끊자',
#  '츄개잘해서미안해',
#  'cheon2',
#  'zxcokgvjdasal',
#  'srasoni',
#  '코 태',
#  '9474500519827645',
#  'aikafei',
#  '유이피 헤리1',
#  '앙까라다리우스',
#  'zbnx',
#  'Angle Beats',
#  '재능 보다 노력',
#  'Gen G Just',
#  'KR Spoon',
#  'Allo1',
#  'Ludee',
#  'darkman77543',
#  'lm dinner',
#  'YouShouldKnowMe',
#  '아이디뭐하g',
#  '나쁘지않았다',
#  '세상은부조리해',
#  'Imagine Legends',
#  'dkssudzz',
#  'Zztai',
#  'VioIa',
#  'Tong1',
#  '10 시즌 담원우승',
#  'Raphael 03',
#  '홍시연시단감',
#  '딸기따르트으',
#  '마장이에요',
#  'Akirameru',
#  'qwerzxcas',
#  '릴리아만큼잘재움',
#  '달콤주먹 박도준',
#  'qiu yu xin',
#  '하다하다하다',
#  'love yuxin',
#  '유징쓰',
#  'asdfghjkllkjhgf',
#  '채은이 귀여워',
#  '포소포소',
#  'Gen G Lucifer',
#  'hzw',
#  '진으로 뭘못하나',
#  '이보한병',
#  '서렌 반대하기',
#  '졸려졸려',
#  '날건들면알지',
#  '웅필승',
#  'GukBo',
#  '송 하 랑',
#  '렐서폿',
#  '브레인저그',
#  'unhappy i',
#  'abc11122',
#  'freezen',
#  'i half',
#  'Manycpyfjtjkyxf',
#  '허사피피',
#  '상랑해',
#  '너구리솔킬딴사람',
#  '냥카롱',
#  '1U JG',
#  '한 아 청',
#  '마이티 비버',
#  'vwdjlkasjhdqw',
#  'zodls',
#  '시2발 하지마',
#  '팀운18',
#  'MIDIKING',
#  'WE Sakura98',
#  '우우리',
#  'rste',
#  '루트커즈',
#  '서투덜',
#  '불빛 계약',
#  '잘해 파이팅',
#  'BRO Hena',
#  '토어문호두',
#  'T1 Smash1',
#  '경자고 김우민',
#  '북한수장김정은',
#  'Alteia',
#  'Sinkingendlessly',
#  '방송인 손주녁',
#  'pcxcxq',
#  '함볼게볼게',
#  '암흑 우주 럭스',
#  'THSGMDALS',
#  '부 닭',
#  'huya xiaohao',
#  '꼬마양씨',
#  '인생은김한기처럼',
#  'DRX Clear',
#  'feviknight',
#  'yixizhidl',
#  'wenyisup1',
#  '미엄캣',
#  'swordart7',
#  'Yeoubi',
#  '요리잘하는고양이',
#  'zihsihderen',
#  'yiuyuiuyi',
#  '이희태',
#  '왕따왕따',
#  'Chancedong',
#  '워워 도현',
#  '당장밴드만들자',
#  '마빡에 힘줄',
#  '다죽여버려1',
#  '언더덕',
#  'bilbili24400071',
#  'Seishiro Nagi',
#  'bgvc',
#  'Triple O',
#  'Dhorreur',
#  '세르델',
#  '박사모님전용기사',
#  '카카오배그',
#  'Daehu',
#  '백수 연수',
#  'Nevergank',
#  'Gen G Ruler',
#  '우 두',
#  '찬호주인마르쉐',
#  'DWG Ghost',
#  'SibasakiRoka',
#  '개미1친놈',
#  'sick villain',
#  '한국인입니다6',
#  '뒷각 볼게',
#  'Kirby Mario Link',
#  '화려한화려한',
#  '우치하 찬스케',
#  'YQYQ',
#  '역체폿 마타 ',
#  '98765432123',
#  'KT 기리',
#  '뭐너가어쩔건데',
#  'vzac',
#  'HLE 이준민',
#  '무서기',
#  'Haeoreum',
#  'lmperial',
#  '마라탕맛있네',
#  '00 OP2',
#  '자신감이필요해',
#  'oh1oh2oh3',
#  'DoJerry',
#  '수요일은다먹는날',
#  'Loafers',
#  'NS Mihile',
#  'bus승객입니다',
#  'Plz Gank',
#  'Onlyven',
#  'Emperor penguin1',
#  '강한행운형',
#  '아이린',
#  'BX8KK',
#  'NuiTt',
#  '이지만07',
#  '조금만더잘해보자',
#  '우주 럭스',
#  '자메이카흑인',
#  'born to lose',
#  '슈퍼빅고수',
#  'asdfghjklqg',
#  '미니언14',
#  'Baroh',
#  '미치에다 슌스케l',
#  '짜니에몽',
#  '첫 봄1',
#  'asdfqw',
#  '절대집중력2',
#  'permenban0002256',
#  '생각또생각',
#  'not want to fail',
#  'Inhp',
#  'THE JAB PACK Pt1',
#  '도천지',
#  '스물다섯번째밤',
#  'YOUSONOJAM',
#  '청포도육포',
#  'xxmm',
#  '누누교수',
#  '야돈급 반응속도']

# %%
riot_api_key = 'RGAPI-45acd7cf-59a4-495d-ba1f-08133475f074'

def get_puuid(user,riot_api_key):
    url = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{user}?api_key={riot_api_key}'
    res = requests.get(url).json()
    puuid = res['puuid']
    return puuid

    
def get_match_id(puuid,riot_api_key):
    url = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?type=ranked&start=0&count=100&api_key={riot_api_key}'
    res = requests.get(url).json()
    return res

def get_matches_timelines(match_id, riot_api_key):
    url1 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={riot_api_key}'
    res1 = requests.get(url1).json()
    url2 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}/timeline?api_key={riot_api_key}'
    res2 = requests.get(url2).json()
    return res1,res2

# %%
b = get_match_id(a, riot_api_key)

# %%
b
# Out:
# {'status': {'message': 'Bad Request - Exception decrypting %EC%95%84%EC%9D%B4%EC%8A%A4%ED%8B%B0%EC%A2%8B%EC%95%84%ED%95%B4%EC%9A%A9',
#   'status_code': 400}}

# %%
get_matches_timelines(b[0], riot_api_key)
# Out:
# ({'metadata': {'dataVersion': '2',
#    'matchId': 'KR_6399909863',
#    'participants': ['8AunLkgaDU3m47xdnrxE88Aeb62DurhCAJ9QmbL-HtxCQbs_FYiwAMgluYBnVOF8LrEQJycwFfx05Q',
#     'B-aTy61h3O6Oe5ZD80WZQh5idMTon3ZczhAW-MGJHCml4PGaRSdcEYTSLV0RZwbDtdQn5N7OjxImaQ',
#     'MC9KsS35GrZS77MPukC6F5dJTJCXBtxXFyKZF64QMIH4AYT3iEl6gnYq_Ejjl_x_eLGQAHOPNpB2Ng',
#     'nFpv88ijjLjVR_RG19pi7JpIyZHUWfew62mOibdLKsG2TO8DynlDlAKSBtF-NJ3cqzHX33fNbQrhsQ',
#     'hL_QTu6-avL_IlgFXkV4Vy2d_jeePAt0eS-Lh4czTwvxcEW-RnZzbQZgAxdNXTTHa8tWWxu9I-KQ8Q',
#     'O0JEmHM7IYGetsw4DhFF140O420ycBCTLMaEqK2BtvXIyEM3-r2S5IqgnB1eudwa7JUON_zsg4nSNA',
#     'ZWhJwDalbfURuNr7NlZ1oR3IEOlc1m9Ypz0SAH5c2ltw7RBMclfREqrYGfhJkZjeXYEaAgy-W0-I8g',
#     'S5nxI11RytiYvyRe_u54PHEEvmMCTsxBViCUM-VOUg18p1pVVB-8WNFcATVSiyyS4-UNPSxlrQmHnQ',
#     'yqyIKMKb76xxNPv1UAOUrt01h9bebodGYUsHh3DSsdAYzQikeK93hPWkJWbvhj_R_yeSqQfg-JVJwQ',
#     'dkwk4XGaTisr4TKrXEOgb_vO5Lp6K8m-ut4TNIvxwQ7PX_URECtdmpdxn-a5K_CO2D_QG0yetoEk2A']},
#   'info': {'gameCreation': 1678473686067,
#    'gameDuration': 968,
#    'gameEndTimestamp': 1678474715706,
#    'gameId': 6399909863,
#    'gameMode': 'CLASSIC',
#    'gameName': 'teambuilder-match-6399909863',
#    'gameStartTimestamp': 1678473746886,
#    'gameType': 'MATCHED_GAME',
#    'gameVersion': '13.5.495.8836',
#    'mapId': 11,
#    'participants': [{'allInPings': 0,
#      'assistMePings': 0,
#      'assists': 7,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 1,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 186,
#       'acesBefore15Minutes': 2,
#       'alliedJungleMonsterKills': 0,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 0,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardsPlaced': 1,
#       'damagePerMinute': 575.4339961458578,
#       'damageTakenOnTeamPercentage': 0.22922957901617455,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 3,
#       'dodgeSkillShotsSmallWindow': 0,
#       'doubleAces': 0,
#       'dragonTakedowns': 0,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 1030.36669921875,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 13,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'firstTurretKilledTime': 667.3156046607903,
#       'flawlessAces': 1,
#       'fullTeamTakedown': 0,
#       'gameLength': 968.9257434117164,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 382.2702481521467,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 3,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 3.3333333333333335,
#       'killAfterHiddenWithAlly': 1,
#       'killParticipation': 0.35714285714285715,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killsNearEnemyTurret': 0,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 0,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 12,
#       'laneMinionsFirst10Minutes': 53,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 14,
#       'maxKillDeficit': 1,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 0,
#       'multikillsAfterAggressiveFlash': 0,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 1,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 5,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'shortestTimeToAceFromFirstTakedown': 9.418938157588173,
#       'skillshotsDodged': 1,
#       'skillshotsHit': 27,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 2,
#       'stealthWardsPlaced': 4,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 10,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 9,
#       'takedownsInAlcove': 1,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.19393521994441595,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 3,
#       'turretTakedowns': 0,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 4,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': -0.15356028079986572,
#       'visionScorePerMinute': 0.5514272803544451,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 8467,
#      'champLevel': 11,
#      'championId': 43,
#      'championName': 'Karma',
#      'championTransform': 0,
#      'commandPings': 8,
#      'consumablesPurchased': 6,
#      'damageDealtToBuildings': 1044,
#      'damageDealtToObjectives': 1044,
#      'damageDealtToTurrets': 1044,
#      'damageSelfMitigated': 7666,
#      'dangerPings': 0,
#      'deaths': 3,
#      'detectorWardsPlaced': 1,
#      'doubleKills': 0,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 2,
#      'enemyVisionPings': 1,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': True,
#      'getBackPings': 2,
#      'goldEarned': 6173,
#      'goldSpent': 5075,
#      'holdPings': 0,
#      'individualPosition': 'TOP',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 2031,
#      'item1': 4642,
#      'item2': 0,
#      'item3': 3011,
#      'item4': 1056,
#      'item5': 3158,
#      'item6': 3363,
#      'itemsPurchased': 16,
#      'killingSprees': 0,
#      'kills': 3,
#      'lane': 'NONE',
#      'largestCriticalStrike': 0,
#      'largestKillingSpree': 0,
#      'largestMultiKill': 1,
#      'longestTimeSpentLiving': 329,
#      'magicDamageDealt': 42848,
#      'magicDamageDealtToChampions': 7430,
#      'magicDamageTaken': 2774,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 0,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 6,
#      'participantId': 1,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8214, 'var1': 674, 'var2': 124, 'var3': 0},
#          {'perk': 8226, 'var1': 250, 'var2': 305, 'var3': 0},
#          {'perk': 8210, 'var1': 1, 'var2': 0, 'var3': 0},
#          {'perk': 8237, 'var1': 392, 'var2': 0, 'var3': 0}],
#         'style': 8200},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#          {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#         'style': 8300}]},
#      'physicalDamageDealt': 9881,
#      'physicalDamageDealtToChampions': 1861,
#      'physicalDamageTaken': 8230,
#      'profileIcon': 4022,
#      'pushPings': 0,
#      'puuid': '8AunLkgaDU3m47xdnrxE88Aeb62DurhCAJ9QmbL-HtxCQbs_FYiwAMgluYBnVOF8LrEQJycwFfx05Q',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SUPPORT',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 75,
#      'spell2Casts': 21,
#      'spell3Casts': 64,
#      'spell4Casts': 26,
#      'summoner1Casts': 2,
#      'summoner1Id': 4,
#      'summoner2Casts': 2,
#      'summoner2Id': 12,
#      'summonerId': 'hgYOviTGpm-YDlW9iu8sWYi6AgZWVYOqTdAMWQI3Lzc_0tw',
#      'summonerLevel': 220,
#      'summonerName': '사랑하지 않아',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'TOP',
#      'timeCCingOthers': 27,
#      'timePlayed': 968,
#      'totalDamageDealt': 52730,
#      'totalDamageDealtToChampions': 9292,
#      'totalDamageShieldedOnTeammates': 1030,
#      'totalDamageTaken': 11409,
#      'totalHeal': 2183,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 100,
#      'totalTimeCCDealt': 225,
#      'totalTimeSpentDead': 67,
#      'totalUnitsHealed': 1,
#      'tripleKills': 0,
#      'trueDamageDealt': 0,
#      'trueDamageDealtToChampions': 0,
#      'trueDamageTaken': 404,
#      'turretKills': 0,
#      'turretTakedowns': 0,
#      'turretsLost': 0,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 8,
#      'visionWardsBoughtInGame': 1,
#      'wardsKilled': 0,
#      'wardsPlaced': 7,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 0,
#      'assists': 10,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 6,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 175,
#       'acesBefore15Minutes': 2,
#       'alliedJungleMonsterKills': 46.1000000834465,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 0,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5374307722843826,
#       'controlWardsPlaced': 4,
#       'damagePerMinute': 379.1272598619377,
#       'damageTakenOnTeamPercentage': 0.2436121373704092,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 1,
#       'dodgeSkillShotsSmallWindow': 0,
#       'doubleAces': 0,
#       'dragonTakedowns': 2,
#       'earliestDragonTakedown': 347.7597893361099,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 0,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 4,
#       'enemyJungleMonsterKills': 7.200000047683716,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'firstTurretKilledTime': 667.3156046607903,
#       'flawlessAces': 1,
#       'fullTeamTakedown': 0,
#       'gameLength': 968.9257434117164,
#       'goldPerMinute': 512.458485210267,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 3,
#       'initialBuffCount': 1,
#       'initialCrabCount': 1,
#       'jungleCsBefore10Minutes': 54.800000071525574,
#       'junglerKillsEarlyJungle': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 1,
#       'kda': 16,
#       'killAfterHiddenWithAlly': 1,
#       'killParticipation': 0.5714285714285714,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 1,
#       'killsNearEnemyTurret': 1,
#       'killsOnLanersEarlyJungleAsJungler': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 1,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 0,
#       'laneMinionsFirst10Minutes': 0,
#       'laningPhaseGoldExpAdvantage': 1,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 18.800000101327896,
#       'maxKillDeficit': 1,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': -35.29999998211861,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 1,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 6630,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 1,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 10,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 2,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 4,
#       'shortestTimeToAceFromFirstTakedown': 9.418938157588173,
#       'skillshotsDodged': 2,
#       'skillshotsHit': 0,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 0,
#       'stealthWardsPlaced': 1,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 1,
#       'takedowns': 16,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 16,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.1277750863186951,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 3,
#       'turretTakedowns': 2,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 0,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': 0.31490230560302734,
#       'visionScorePerMinute': 1.1111971044113873,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 7169,
#      'champLevel': 10,
#      'championId': 59,
#      'championName': 'JarvanIV',
#      'championTransform': 0,
#      'commandPings': 5,
#      'consumablesPurchased': 5,
#      'damageDealtToBuildings': 852,
#      'damageDealtToObjectives': 29917,
#      'damageDealtToTurrets': 852,
#      'damageSelfMitigated': 12428,
#      'dangerPings': 0,
#      'deaths': 1,
#      'detectorWardsPlaced': 4,
#      'doubleKills': 1,
#      'dragonKills': 2,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 12,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': True,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': True,
#      'getBackPings': 6,
#      'goldEarned': 8275,
#      'goldSpent': 7450,
#      'holdPings': 0,
#      'individualPosition': 'JUNGLE',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 6630,
#      'item1': 2420,
#      'item2': 1038,
#      'item3': 1036,
#      'item4': 1103,
#      'item5': 3047,
#      'item6': 3513,
#      'itemsPurchased': 17,
#      'killingSprees': 1,
#      'kills': 6,
#      'lane': 'NONE',
#      'largestCriticalStrike': 0,
#      'largestKillingSpree': 6,
#      'largestMultiKill': 2,
#      'longestTimeSpentLiving': 166,
#      'magicDamageDealt': 6357,
#      'magicDamageDealtToChampions': 304,
#      'magicDamageTaken': 2447,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 86,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 10,
#      'participantId': 2,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5003, 'flex': 5002, 'offense': 5005},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8010, 'var1': 94, 'var2': 0, 'var3': 0},
#          {'perk': 9111, 'var1': 842, 'var2': 320, 'var3': 0},
#          {'perk': 9104, 'var1': 8, 'var2': 50, 'var3': 0},
#          {'perk': 8014, 'var1': 255, 'var2': 0, 'var3': 0}],
#         'style': 8000},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8304, 'var1': 8, 'var2': 1, 'var3': 5},
#          {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#         'style': 8300}]},
#      'physicalDamageDealt': 65752,
#      'physicalDamageDealtToChampions': 5598,
#      'physicalDamageTaken': 9485,
#      'profileIcon': 4955,
#      'pushPings': 0,
#      'puuid': 'B-aTy61h3O6Oe5ZD80WZQh5idMTon3ZczhAW-MGJHCml4PGaRSdcEYTSLV0RZwbDtdQn5N7OjxImaQ',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SUPPORT',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 66,
#      'spell2Casts': 47,
#      'spell3Casts': 56,
#      'spell4Casts': 6,
#      'summoner1Casts': 2,
#      'summoner1Id': 4,
#      'summoner2Casts': 11,
#      'summoner2Id': 11,
#      'summonerId': '-CK-687U20DmdzK8jaeubArkh2GItQ82-VbpOce03-rVQXE',
#      'summonerLevel': 597,
#      'summonerName': '웅필승',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'JUNGLE',
#      'timeCCingOthers': 7,
#      'timePlayed': 968,
#      'totalDamageDealt': 103108,
#      'totalDamageDealtToChampions': 6122,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 12124,
#      'totalHeal': 7456,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 11,
#      'totalTimeCCDealt': 251,
#      'totalTimeSpentDead': 8,
#      'totalUnitsHealed': 1,
#      'tripleKills': 0,
#      'trueDamageDealt': 30998,
#      'trueDamageDealtToChampions': 219,
#      'trueDamageTaken': 192,
#      'turretKills': 2,
#      'turretTakedowns': 2,
#      'turretsLost': 0,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 17,
#      'visionWardsBoughtInGame': 4,
#      'wardsKilled': 0,
#      'wardsPlaced': 5,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 0,
#      'assists': 2,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 2,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 176,
#       'acesBefore15Minutes': 2,
#       'alliedJungleMonsterKills': 0,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 150,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardTimeCoverageInRiverOrEnemyHalf': 0.43034462843736626,
#       'controlWardsPlaced': 2,
#       'damagePerMinute': 986.5279870834026,
#       'damageTakenOnTeamPercentage': 0.24776500360419917,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 1,
#       'dodgeSkillShotsSmallWindow': 0,
#       'doubleAces': 0,
#       'dragonTakedowns': 0,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 0,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 0,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'fastestLegendary': 879.8674630047583,
#       'firstTurretKilledTime': 667.3156046607903,
#       'flawlessAces': 1,
#       'fullTeamTakedown': 0,
#       'gameLength': 968.9257434117164,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 542.4868481721197,
#       'hadOpenNexus': 0,
#       'highestChampionDamage': 1,
#       'immobilizeAndKillWithAlly': 0,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 12,
#       'killAfterHiddenWithAlly': 0,
#       'killParticipation': 0.42857142857142855,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 1,
#       'killsNearEnemyTurret': 5,
#       'killsOnOtherLanesEarlyJungleAsLaner': 1,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 0,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 14,
#       'laneMinionsFirst10Minutes': 96,
#       'laningPhaseGoldExpAdvantage': 1,
#       'legendaryCount': 1,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 26,
#       'maxKillDeficit': 1,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 3,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 3152,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 3,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 5,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'shortestTimeToAceFromFirstTakedown': 14.054446974975804,
#       'skillshotsDodged': 4,
#       'skillshotsHit': 49,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 2,
#       'stealthWardsPlaced': 5,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 3,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 12,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 9,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.3324838703270605,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 4,
#       'turretTakedowns': 0,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 6,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': 1.0835421085357666,
#       'visionScorePerMinute': 0.8379804221826953,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 8973,
#      'champLevel': 12,
#      'championId': 84,
#      'championName': 'Akali',
#      'championTransform': 0,
#      'commandPings': 2,
#      'consumablesPurchased': 3,
#      'damageDealtToBuildings': 1905,
#      'damageDealtToObjectives': 1905,
#      'damageDealtToTurrets': 1905,
#      'damageSelfMitigated': 6987,
#      'dangerPings': 0,
#      'deaths': 1,
#      'detectorWardsPlaced': 2,
#      'doubleKills': 3,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 1,
#      'enemyVisionPings': 2,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': True,
#      'getBackPings': 0,
#      'goldEarned': 8760,
#      'goldSpent': 8100,
#      'holdPings': 0,
#      'individualPosition': 'MIDDLE',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 3152,
#      'item1': 4645,
#      'item2': 0,
#      'item3': 3020,
#      'item4': 1054,
#      'item5': 0,
#      'item6': 3364,
#      'itemsPurchased': 14,
#      'killingSprees': 2,
#      'kills': 10,
#      'lane': 'NONE',
#      'largestCriticalStrike': 0,
#      'largestKillingSpree': 8,
#      'largestMultiKill': 2,
#      'longestTimeSpentLiving': 889,
#      'magicDamageDealt': 53440,
#      'magicDamageDealtToChampions': 14762,
#      'magicDamageTaken': 3727,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 0,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 12,
#      'participantId': 3,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5008},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8010, 'var1': 87, 'var2': 0, 'var3': 0},
#          {'perk': 9111, 'var1': 961, 'var2': 240, 'var3': 0},
#          {'perk': 9105, 'var1': 12, 'var2': 50, 'var3': 0},
#          {'perk': 8299, 'var1': 528, 'var2': 0, 'var3': 0}],
#         'style': 8000},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8444, 'var1': 847, 'var2': 0, 'var3': 0},
#          {'perk': 8242, 'var1': 26, 'var2': 0, 'var3': 0}],
#         'style': 8400}]},
#      'physicalDamageDealt': 8491,
#      'physicalDamageDealtToChampions': 1168,
#      'physicalDamageTaken': 8190,
#      'profileIcon': 6,
#      'pushPings': 0,
#      'puuid': 'MC9KsS35GrZS77MPukC6F5dJTJCXBtxXFyKZF64QMIH4AYT3iEl6gnYq_Ejjl_x_eLGQAHOPNpB2Ng',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'DUO',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 100,
#      'spell2Casts': 26,
#      'spell3Casts': 38,
#      'spell4Casts': 12,
#      'summoner1Casts': 2,
#      'summoner1Id': 12,
#      'summoner2Casts': 1,
#      'summoner2Id': 4,
#      'summonerId': '8bpzqvwqBFf-RzMz9oMq2tOW6IZuxSbL2nBvBUMEbb1Hdg',
#      'summonerLevel': 642,
#      'summonerName': 'Hide on bush',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'MIDDLE',
#      'timeCCingOthers': 3,
#      'timePlayed': 968,
#      'totalDamageDealt': 61932,
#      'totalDamageDealtToChampions': 15931,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 12331,
#      'totalHeal': 2351,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 132,
#      'totalTimeCCDealt': 58,
#      'totalTimeSpentDead': 35,
#      'totalUnitsHealed': 1,
#      'tripleKills': 0,
#      'trueDamageDealt': 0,
#      'trueDamageDealtToChampions': 0,
#      'trueDamageTaken': 414,
#      'turretKills': 0,
#      'turretTakedowns': 0,
#      'turretsLost': 0,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 13,
#      'visionWardsBoughtInGame': 2,
#      'wardsKilled': 0,
#      'wardsPlaced': 7,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 2,
#      'assists': 4,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 7,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 104,
#       'acesBefore15Minutes': 2,
#       'alliedJungleMonsterKills': 4.000000029802322,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 0,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardsPlaced': 0,
#       'damagePerMinute': 799.089934247677,
#       'damageTakenOnTeamPercentage': 0.122639836202963,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 1,
#       'dodgeSkillShotsSmallWindow': 2,
#       'doubleAces': 0,
#       'dragonTakedowns': 2,
#       'earliestDragonTakedown': 347.7597893361099,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 286.62646484375,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 9,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'firstTurretKilledTime': 667.3156046607903,
#       'flawlessAces': 1,
#       'fullTeamTakedown': 0,
#       'gameLength': 968.9257434117164,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 590.2407253418781,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 6,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 2,
#       'kda': 13,
#       'killAfterHiddenWithAlly': 3,
#       'killParticipation': 0.4642857142857143,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 1,
#       'killsNearEnemyTurret': 3,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 2,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 15,
#       'laneMinionsFirst10Minutes': 60,
#       'laningPhaseGoldExpAdvantage': 1,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 25.000000029802322,
#       'maxKillDeficit': 1,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 2,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 6671,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 3,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 8,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'skillshotsDodged': 12,
#       'skillshotsHit': 42,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 1,
#       'stealthWardsPlaced': 3,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 13,
#       'takedownsAfterGainingLevelAdvantage': 1,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 9,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.2693126982271843,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 9,
#       'turretTakedowns': 2,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 5,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': 0.026959896087646484,
#       'visionScorePerMinute': 0.6642131963689772,
#       'wardTakedowns': 3,
#       'wardTakedownsBefore20M': 3,
#       'wardsGuarded': 0},
#      'champExperience': 7285,
#      'champLevel': 10,
#      'championId': 498,
#      'championName': 'Xayah',
#      'championTransform': 0,
#      'commandPings': 4,
#      'consumablesPurchased': 1,
#      'damageDealtToBuildings': 5200,
#      'damageDealtToObjectives': 8623,
#      'damageDealtToTurrets': 5200,
#      'damageSelfMitigated': 3342,
#      'dangerPings': 0,
#      'deaths': 1,
#      'detectorWardsPlaced': 0,
#      'doubleKills': 2,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 3,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': True,
#      'firstTowerAssist': True,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': True,
#      'getBackPings': 0,
#      'goldEarned': 9531,
#      'goldSpent': 8100,
#      'holdPings': 0,
#      'individualPosition': 'BOTTOM',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 6671,
#      'item1': 1055,
#      'item2': 1001,
#      'item3': 2031,
#      'item4': 6675,
#      'item5': 1036,
#      'item6': 3363,
#      'itemsPurchased': 15,
#      'killingSprees': 2,
#      'kills': 9,
#      'lane': 'NONE',
#      'largestCriticalStrike': 431,
#      'largestKillingSpree': 7,
#      'largestMultiKill': 2,
#      'longestTimeSpentLiving': 464,
#      'magicDamageDealt': 660,
#      'magicDamageDealtToChampions': 660,
#      'magicDamageTaken': 495,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 4,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 17,
#      'participantId': 4,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 9923, 'var1': 26, 'var2': 96, 'var3': 0},
#          {'perk': 8139, 'var1': 322, 'var2': 0, 'var3': 0},
#          {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#          {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#         'style': 8100},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8009, 'var1': 1235, 'var2': 0, 'var3': 0},
#          {'perk': 9103, 'var1': 13, 'var2': 0, 'var3': 0}],
#         'style': 8000}]},
#      'physicalDamageDealt': 88165,
#      'physicalDamageDealtToChampions': 12243,
#      'physicalDamageTaken': 5538,
#      'profileIcon': 3018,
#      'pushPings': 0,
#      'puuid': 'nFpv88ijjLjVR_RG19pi7JpIyZHUWfew62mOibdLKsG2TO8DynlDlAKSBtF-NJ3cqzHX33fNbQrhsQ',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SUPPORT',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 44,
#      'spell2Casts': 18,
#      'spell3Casts': 38,
#      'spell4Casts': 4,
#      'summoner1Casts': 2,
#      'summoner1Id': 4,
#      'summoner2Casts': 2,
#      'summoner2Id': 7,
#      'summonerId': '48kLTDJdlxNY1oqhxayanhsU13YmGVnDXIF6oGWLzzXJfHot',
#      'summonerLevel': 168,
#      'summonerName': '짜니에몽',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'BOTTOM',
#      'timeCCingOthers': 11,
#      'timePlayed': 968,
#      'totalDamageDealt': 91430,
#      'totalDamageDealtToChampions': 12904,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 6103,
#      'totalHeal': 2016,
#      'totalHealsOnTeammates': 286,
#      'totalMinionsKilled': 137,
#      'totalTimeCCDealt': 17,
#      'totalTimeSpentDead': 14,
#      'totalUnitsHealed': 3,
#      'tripleKills': 0,
#      'trueDamageDealt': 2605,
#      'trueDamageDealtToChampions': 0,
#      'trueDamageTaken': 70,
#      'turretKills': 1,
#      'turretTakedowns': 2,
#      'turretsLost': 0,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 10,
#      'visionWardsBoughtInGame': 0,
#      'wardsKilled': 3,
#      'wardsPlaced': 4,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 0,
#      'assists': 17,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 0,
#      'challenges': {'12AssistStreakCount': 1,
#       'abilityUses': 71,
#       'acesBefore15Minutes': 2,
#       'alliedJungleMonsterKills': 0,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 0,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardTimeCoverageInRiverOrEnemyHalf': 0.3535420040872005,
#       'controlWardsPlaced': 5,
#       'damagePerMinute': 226.96622467105232,
#       'damageTakenOnTeamPercentage': 0.15675344380625408,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 1,
#       'dodgeSkillShotsSmallWindow': 2,
#       'doubleAces': 0,
#       'dragonTakedowns': 1,
#       'earliestDragonTakedown': 347.7597893361099,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 2665.591796875,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 14,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'firstTurretKilledTime': 667.3156046607903,
#       'flawlessAces': 1,
#       'fullTeamTakedown': 0,
#       'gameLength': 968.9257434117164,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 334.62815513882276,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 10,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 2,
#       'kda': 17,
#       'killAfterHiddenWithAlly': 4,
#       'killParticipation': 0.6071428571428571,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killsNearEnemyTurret': 0,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 0,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 4,
#       'laneMinionsFirst10Minutes': 19,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 4,
#       'maxKillDeficit': 1,
#       'maxLevelLeadLaneOpponent': 1,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 0,
#       'multikillsAfterAggressiveFlash': 0,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 0,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 9,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 1,
#       'saveAllyFromDeath': 5,
#       'scuttleCrabKills': 0,
#       'shortestTimeToAceFromFirstTakedown': 9.418938157588173,
#       'skillshotsDodged': 14,
#       'skillshotsHit': 12,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 0,
#       'stealthWardsPlaced': 9,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 4,
#       'takedownOnFirstTurret': 1,
#       'takedowns': 17,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 13,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.07649312518264413,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 3,
#       'turretTakedowns': 3,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 0,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': 0.23577821254730225,
#       'visionScorePerMinute': 2.3016784332800087,
#       'wardTakedowns': 4,
#       'wardTakedownsBefore20M': 4,
#       'wardsGuarded': 1},
#      'champExperience': 5324,
#      'champLevel': 9,
#      'championId': 497,
#      'championName': 'Rakan',
#      'championTransform': 0,
#      'commandPings': 13,
#      'consumablesPurchased': 9,
#      'damageDealtToBuildings': 945,
#      'damageDealtToObjectives': 2059,
#      'damageDealtToTurrets': 945,
#      'damageSelfMitigated': 7085,
#      'dangerPings': 0,
#      'deaths': 1,
#      'detectorWardsPlaced': 5,
#      'doubleKills': 0,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 2,
#      'enemyVisionPings': 2,
#      'firstBloodAssist': True,
#      'firstBloodKill': False,
#      'firstTowerAssist': True,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': True,
#      'getBackPings': 6,
#      'goldEarned': 5403,
#      'goldSpent': 3435,
#      'holdPings': 0,
#      'individualPosition': 'UTILITY',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 3859,
#      'item1': 3158,
#      'item2': 2055,
#      'item3': 3067,
#      'item4': 1004,
#      'item5': 1052,
#      'item6': 3364,
#      'itemsPurchased': 18,
#      'killingSprees': 0,
#      'kills': 0,
#      'lane': 'NONE',
#      'largestCriticalStrike': 0,
#      'largestKillingSpree': 0,
#      'largestMultiKill': 0,
#      'longestTimeSpentLiving': 745,
#      'magicDamageDealt': 4597,
#      'magicDamageDealtToChampions': 2231,
#      'magicDamageTaken': 1172,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 0,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 35,
#      'participantId': 5,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8465, 'var1': 1379, 'var2': 0, 'var3': 0},
#          {'perk': 8463, 'var1': 397, 'var2': 0, 'var3': 0},
#          {'perk': 8473, 'var1': 160, 'var2': 0, 'var3': 0},
#          {'perk': 8242, 'var1': 11, 'var2': 0, 'var3': 0}],
#         'style': 8400},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8136, 'var1': 7, 'var2': 14, 'var3': 0},
#          {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#         'style': 8100}]},
#      'physicalDamageDealt': 4353,
#      'physicalDamageDealtToChampions': 1087,
#      'physicalDamageTaken': 6545,
#      'profileIcon': 7,
#      'pushPings': 0,
#      'puuid': 'hL_QTu6-avL_IlgFXkV4Vy2d_jeePAt0eS-Lh4czTwvxcEW-RnZzbQZgAxdNXTTHa8tWWxu9I-KQ8Q',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SUPPORT',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 21,
#      'spell2Casts': 23,
#      'spell3Casts': 23,
#      'spell4Casts': 4,
#      'summoner1Casts': 2,
#      'summoner1Id': 4,
#      'summoner2Casts': 3,
#      'summoner2Id': 14,
#      'summonerId': 'X7QQngUAdS83s3VTKR9hKU8h8TgLxK2CFDsPd3kOS8kfcqE5eBil9cA5CA',
#      'summonerLevel': 49,
#      'summonerName': 'Straight to Hel1',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'UTILITY',
#      'timeCCingOthers': 15,
#      'timePlayed': 968,
#      'totalDamageDealt': 13649,
#      'totalDamageDealtToChampions': 3665,
#      'totalDamageShieldedOnTeammates': 1547,
#      'totalDamageTaken': 7801,
#      'totalHeal': 2865,
#      'totalHealsOnTeammates': 1118,
#      'totalMinionsKilled': 27,
#      'totalTimeCCDealt': 31,
#      'totalTimeSpentDead': 21,
#      'totalUnitsHealed': 5,
#      'tripleKills': 0,
#      'trueDamageDealt': 4698,
#      'trueDamageDealtToChampions': 346,
#      'trueDamageTaken': 84,
#      'turretKills': 0,
#      'turretTakedowns': 3,
#      'turretsLost': 0,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 37,
#      'visionWardsBoughtInGame': 6,
#      'wardsKilled': 4,
#      'wardsPlaced': 21,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 2,
#      'assists': 2,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 0,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 212,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 0,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 0,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardsPlaced': 1,
#       'damagePerMinute': 371.90292528563407,
#       'damageTakenOnTeamPercentage': 0.2641126178489733,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 4,
#       'dodgeSkillShotsSmallWindow': 53,
#       'doubleAces': 0,
#       'dragonTakedowns': 0,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 0,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 17,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'flawlessAces': 0,
#       'fullTeamTakedown': 0,
#       'gameLength': 968.9257434117164,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 279.3737938929725,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 1,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 0.5,
#       'killAfterHiddenWithAlly': 1,
#       'killParticipation': 0.2857142857142857,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killsNearEnemyTurret': 0,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 0,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 1,
#       'landSkillShotsEarlyGame': 7,
#       'laneMinionsFirst10Minutes': 59,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 7,
#       'maxKillDeficit': 0,
#       'maxLevelLeadLaneOpponent': 1,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 0,
#       'multikillsAfterAggressiveFlash': 0,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 0,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 2,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'skillshotsDodged': 269,
#       'skillshotsHit': 13,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 0,
#       'stealthWardsPlaced': 6,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 2,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 2,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.17433166926845114,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 0,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 1,
#       'turretTakedowns': 0,
#       'turretsTakenWithRiftHerald': 0,
#       'twentyMinionsIn3SecondsCount': 4,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': 0.1814190149307251,
#       'visionScorePerMinute': 0.6514667018819579,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 6242,
#      'champLevel': 10,
#      'championId': 79,
#      'championName': 'Gragas',
#      'championTransform': 0,
#      'commandPings': 14,
#      'consumablesPurchased': 3,
#      'damageDealtToBuildings': 556,
#      'damageDealtToObjectives': 556,
#      'damageDealtToTurrets': 556,
#      'damageSelfMitigated': 8201,
#      'dangerPings': 0,
#      'deaths': 4,
#      'detectorWardsPlaced': 1,
#      'doubleKills': 0,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 0,
#      'enemyVisionPings': 6,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': True,
#      'getBackPings': 3,
#      'goldEarned': 4511,
#      'goldSpent': 3925,
#      'holdPings': 0,
#      'individualPosition': 'TOP',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 2031,
#      'item1': 2422,
#      'item2': 3070,
#      'item3': 1056,
#      'item4': 6657,
#      'item5': 0,
#      'item6': 3340,
#      'itemsPurchased': 10,
#      'killingSprees': 0,
#      'kills': 0,
#      'lane': 'NONE',
#      'largestCriticalStrike': 0,
#      'largestKillingSpree': 0,
#      'largestMultiKill': 0,
#      'longestTimeSpentLiving': 526,
#      'magicDamageDealt': 31148,
#      'magicDamageDealtToChampions': 5226,
#      'magicDamageTaken': 9214,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 0,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 6,
#      'participantId': 6,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5008},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8369, 'var1': 126, 'var2': 154, 'var3': 0},
#          {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#          {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#          {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#         'style': 8300},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8226, 'var1': 250, 'var2': 327, 'var3': 0},
#          {'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0}],
#         'style': 8200}]},
#      'physicalDamageDealt': 6598,
#      'physicalDamageDealtToChampions': 660,
#      'physicalDamageTaken': 6303,
#      'profileIcon': 933,
#      'pushPings': 0,
#      'puuid': 'O0JEmHM7IYGetsw4DhFF140O420ycBCTLMaEqK2BtvXIyEM3-r2S5IqgnB1eudwa7JUON_zsg4nSNA',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SUPPORT',
#      'sightWardsBoughtInGame': 0,
# ...
#        'realTimestamp': 1678474715826,
#        'timestamp': 968925,
#        'type': 'GAME_END',
#        'winningTeam': 100}],
#      'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 84,
#         'armor': 78,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 79,
#         'attackSpeed': 130,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 0,
#         'cooldownReduction': 0,
#         'health': 608,
#         'healthMax': 1719,
#         'healthRegen': 20,
#         'lifesteal': 0,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 45,
#         'movementSpeed': 380,
#         'omnivamp': 0,
#         'physicalVamp': 0,
#         'power': 867,
#         'powerMax': 1182,
#         'powerRegen': 86,
#         'spellVamp': 0},
#        'currentGold': 1103,
#        'damageStats': {'magicDamageDone': 42848,
#         'magicDamageDoneToChampions': 7430,
#         'magicDamageTaken': 2774,
#         'physicalDamageDone': 9881,
#         'physicalDamageDoneToChampions': 1861,
#         'physicalDamageTaken': 8230,
#         'totalDamageDone': 52730,
#         'totalDamageDoneToChampions': 9292,
#         'totalDamageTaken': 11409,
#         'trueDamageDone': 0,
#         'trueDamageDoneToChampions': 0,
#         'trueDamageTaken': 404},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 0,
#        'level': 11,
#        'minionsKilled': 100,
#        'participantId': 1,
#        'position': {'x': 10231, 'y': 8977},
#        'timeEnemySpentControlled': 225484,
#        'totalGold': 6173,
#        'xp': 8467},
#       '2': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 0,
#         'armor': 108,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 195,
#         'attackSpeed': 172,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 0,
#         'cooldownReduction': 0,
#         'health': 1258,
#         'healthMax': 1744,
#         'healthRegen': 26,
#         'lifesteal': 0,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 60,
#         'movementSpeed': 395,
#         'omnivamp': 8,
#         'physicalVamp': 0,
#         'power': 467,
#         'powerMax': 725,
#         'powerRegen': 19,
#         'spellVamp': 0},
#        'currentGold': 885,
#        'damageStats': {'magicDamageDone': 6357,
#         'magicDamageDoneToChampions': 304,
#         'magicDamageTaken': 2447,
#         'physicalDamageDone': 65752,
#         'physicalDamageDoneToChampions': 5598,
#         'physicalDamageTaken': 9485,
#         'totalDamageDone': 103108,
#         'totalDamageDoneToChampions': 6122,
#         'totalDamageTaken': 12124,
#         'trueDamageDone': 30998,
#         'trueDamageDoneToChampions': 219,
#         'trueDamageTaken': 192},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 86,
#        'level': 10,
#        'minionsKilled': 11,
#        'participantId': 2,
#        'position': {'x': 8473, 'y': 8907},
#        'timeEnemySpentControlled': 251894,
#        'totalGold': 8275,
#        'xp': 7169},
#       '3': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 208,
#         'armor': 75,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 94,
#         'attackSpeed': 131,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 32,
#         'cooldownReduction': 0,
#         'health': 1435,
#         'healthMax': 2271,
#         'healthRegen': 80,
#         'lifesteal': 0,
#         'magicPen': 29,
#         'magicPenPercent': 0,
#         'magicResist': 71,
#         'movementSpeed': 390,
#         'omnivamp': 0,
#         'physicalVamp': 0,
#         'power': 200,
#         'powerMax': 200,
#         'powerRegen': 100,
#         'spellVamp': 0},
#        'currentGold': 720,
#        'damageStats': {'magicDamageDone': 53440,
#         'magicDamageDoneToChampions': 14762,
#         'magicDamageTaken': 3727,
#         'physicalDamageDone': 8491,
#         'physicalDamageDoneToChampions': 1168,
#         'physicalDamageTaken': 8190,
#         'totalDamageDone': 61932,
#         'totalDamageDoneToChampions': 15931,
#         'totalDamageTaken': 12331,
#         'trueDamageDone': 0,
#         'trueDamageDoneToChampions': 0,
#         'trueDamageTaken': 414},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 0,
#        'level': 12,
#        'minionsKilled': 132,
#        'participantId': 3,
#        'position': {'x': 11823, 'y': 9544},
#        'timeEnemySpentControlled': 58953,
#        'totalGold': 8760,
#        'xp': 8973},
#       '4': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 0,
#         'armor': 69,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 248,
#         'attackSpeed': 160,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 0,
#         'cooldownReduction': 0,
#         'health': 1623,
#         'healthMax': 1629,
#         'healthRegen': 18,
#         'lifesteal': 6,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 43,
#         'movementSpeed': 362,
#         'omnivamp': 2,
#         'physicalVamp': 0,
#         'power': 551,
#         'powerMax': 649,
#         'powerRegen': 143,
#         'spellVamp': 0},
#        'currentGold': 1416,
#        'damageStats': {'magicDamageDone': 660,
#         'magicDamageDoneToChampions': 660,
#         'magicDamageTaken': 495,
#         'physicalDamageDone': 88165,
#         'physicalDamageDoneToChampions': 12243,
#         'physicalDamageTaken': 5538,
#         'totalDamageDone': 91430,
#         'totalDamageDoneToChampions': 12904,
#         'totalDamageTaken': 6103,
#         'trueDamageDone': 2605,
#         'trueDamageDoneToChampions': 0,
#         'trueDamageTaken': 70},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 4,
#        'level': 10,
#        'minionsKilled': 137,
#        'participantId': 4,
#        'position': {'x': 9847, 'y': 9523},
#        'timeEnemySpentControlled': 17209,
#        'totalGold': 9531,
#        'xp': 7285},
#       '5': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 62,
#         'armor': 78,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 85,
#         'attackSpeed': 120,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 18,
#         'cooldownReduction': 0,
#         'health': 831,
#         'healthMax': 1577,
#         'healthRegen': 29,
#         'lifesteal': 0,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 49,
#         'movementSpeed': 380,
#         'omnivamp': 0,
#         'physicalVamp': 0,
#         'power': 174,
#         'powerMax': 652,
#         'powerRegen': 36,
#         'spellVamp': 0},
#        'currentGold': 1948,
#        'damageStats': {'magicDamageDone': 4597,
#         'magicDamageDoneToChampions': 2231,
#         'magicDamageTaken': 1172,
#         'physicalDamageDone': 4353,
#         'physicalDamageDoneToChampions': 1087,
#         'physicalDamageTaken': 6545,
#         'totalDamageDone': 13649,
#         'totalDamageDoneToChampions': 3665,
#         'totalDamageTaken': 7801,
#         'trueDamageDone': 4698,
#         'trueDamageDoneToChampions': 346,
#         'trueDamageTaken': 84},
#        'goldPerSecond': 30,
#        'jungleMinionsKilled': 0,
#        'level': 9,
#        'minionsKilled': 27,
#        'participantId': 5,
#        'position': {'x': 8893, 'y': 8633},
#        'timeEnemySpentControlled': 31590,
#        'totalGold': 5403,
#        'xp': 5324},
#       '6': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 101,
#         'armor': 75,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 91,
#         'attackSpeed': 115,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 0,
#         'cooldownReduction': 0,
#         'health': 0,
#         'healthMax': 2023,
#         'healthRegen': 18,
#         'lifesteal': 0,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 55,
#         'movementSpeed': 365,
#         'omnivamp': 0,
#         'physicalVamp': 0,
#         'power': 2075,
#         'powerMax': 2101,
#         'powerRegen': 24,
#         'spellVamp': 0},
#        'currentGold': 586,
#        'damageStats': {'magicDamageDone': 31148,
#         'magicDamageDoneToChampions': 5226,
#         'magicDamageTaken': 9214,
#         'physicalDamageDone': 6598,
#         'physicalDamageDoneToChampions': 660,
#         'physicalDamageTaken': 6303,
#         'totalDamageDone': 37866,
#         'totalDamageDoneToChampions': 6005,
#         'totalDamageTaken': 15699,
#         'trueDamageDone': 119,
#         'trueDamageDoneToChampions': 119,
#         'trueDamageTaken': 182},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 0,
#        'level': 10,
#        'minionsKilled': 88,
#        'participantId': 6,
#        'position': {'x': 7989, 'y': 10461},
#        'timeEnemySpentControlled': 182297,
#        'totalGold': 4511,
#        'xp': 6242},
#       '7': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 0,
#         'armor': 66,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 172,
#         'attackSpeed': 173,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 0,
#         'cooldownReduction': 0,
#         'health': 0,
#         'healthMax': 1277,
#         'healthRegen': 21,
#         'lifesteal': 0,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 38,
#         'movementSpeed': 360,
#         'omnivamp': 0,
#         'physicalVamp': 0,
#         'power': 500,
#         'powerMax': 535,
#         'powerRegen': 30,
#         'spellVamp': 0},
#        'currentGold': 817,
#        'damageStats': {'magicDamageDone': 10226,
#         'magicDamageDoneToChampions': 920,
#         'magicDamageTaken': 5773,
#         'physicalDamageDone': 53560,
#         'physicalDamageDoneToChampions': 6198,
#         'physicalDamageTaken': 6965,
#         'totalDamageDone': 77173,
#         'totalDamageDoneToChampions': 7850,
#         'totalDamageTaken': 12857,
#         'trueDamageDone': 13387,
#         'trueDamageDoneToChampions': 731,
#         'trueDamageTaken': 119},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 76,
#        'level': 9,
#        'minionsKilled': 5,
#        'participantId': 7,
#        'position': {'x': 8247, 'y': 10090},
#        'timeEnemySpentControlled': 115581,
#        'totalGold': 5432,
#        'xp': 5728},
#       '8': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 0,
#         'armor': 60,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 183,
#         'attackSpeed': 123,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 30,
#         'cooldownReduction': 0,
#         'health': 1513,
#         'healthMax': 1513,
#         'healthRegen': 21,
#         'lifesteal': 0,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 73,
#         'movementSpeed': 390,
#         'omnivamp': 2,
#         'physicalVamp': 0,
#         'power': 1529,
#         'powerMax': 1615,
#         'powerRegen': 24,
#         'spellVamp': 0},
#        'currentGold': 1616,
#        'damageStats': {'magicDamageDone': 6023,
#         'magicDamageDoneToChampions': 1566,
#         'magicDamageTaken': 5750,
#         'physicalDamageDone': 46771,
#         'physicalDamageDoneToChampions': 8191,
#         'physicalDamageTaken': 4662,
#         'totalDamageDone': 52795,
#         'totalDamageDoneToChampions': 9758,
#         'totalDamageTaken': 10413,
#         'trueDamageDone': 0,
#         'trueDamageDoneToChampions': 0,
#         'trueDamageTaken': 0},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 0,
#        'level': 10,
#        'minionsKilled': 117,
#        'participantId': 8,
#        'position': {'x': 11929, 'y': 11675},
#        'timeEnemySpentControlled': 73065,
#        'totalGold': 6466,
#        'xp': 6761},
#       '9': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 0,
#         'armor': 63,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 155,
#         'attackSpeed': 169,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 0,
#         'cooldownReduction': 0,
#         'health': 0,
#         'healthMax': 1384,
#         'healthRegen': 14,
#         'lifesteal': 2,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 38,
#         'movementSpeed': 370,
#         'omnivamp': 2,
#         'physicalVamp': 0,
#         'power': 358,
#         'powerMax': 597,
#         'powerRegen': 26,
#         'spellVamp': 0},
#        'currentGold': 738,
#        'damageStats': {'magicDamageDone': 1172,
#         'magicDamageDoneToChampions': 262,
#         'magicDamageTaken': 3318,
#         'physicalDamageDone': 45002,
#         'physicalDamageDoneToChampions': 7970,
#         'physicalDamageTaken': 7903,
#         'totalDamageDone': 46175,
#         'totalDamageDoneToChampions': 8232,
#         'totalDamageTaken': 11292,
#         'trueDamageDone': 0,
#         'trueDamageDoneToChampions': 0,
#         'trueDamageTaken': 70},
#        'goldPerSecond': 0,
#        'jungleMinionsKilled': 0,
#        'level': 9,
#        'minionsKilled': 121,
#        'participantId': 9,
#        'position': {'x': 9793, 'y': 9731},
#        'timeEnemySpentControlled': 28214,
#        'totalGold': 5213,
#        'xp': 5076},
#       '10': {'championStats': {'abilityHaste': 0,
#         'abilityPower': 45,
#         'armor': 50,
#         'armorPen': 0,
#         'armorPenPercent': 0,
#         'attackDamage': 74,
#         'attackSpeed': 130,
#         'bonusArmorPenPercent': 0,
#         'bonusMagicPenPercent': 0,
#         'ccReduction': 25,
#         'cooldownReduction': 0,
#         'health': 0,
#         'healthMax': 1593,
#         'healthRegen': 35,
#         'lifesteal': 0,
#         'magicPen': 0,
#         'magicPenPercent': 0,
#         'magicResist': 37,
#         'movementSpeed': 375,
#         'omnivamp': 0,
#         'physicalVamp': 0,
#         'power': 394,
#         'powerMax': 648,
#         'powerRegen': 31,
#         'spellVamp': 0},
#        'currentGold': 184,
#        'damageStats': {'magicDamageDone': 3420,
#         'magicDamageDoneToChampions': 1653,
#         'magicDamageTaken': 3099,
#         'physicalDamageDone': 2553,
#         'physicalDamageDoneToChampions': 634,
#         'physicalDamageTaken': 5886,
#         'totalDamageDone': 9915,
#         'totalDamageDoneToChampions': 2602,
#         'totalDamageTaken': 9180,
#         'trueDamageDone': 3941,
#         'trueDamageDoneToChampions': 313,
#         'trueDamageTaken': 194},
#        'goldPerSecond': 30,
#        'jungleMinionsKilled': 0,
#        'level': 8,
#        'minionsKilled': 28,
#        'participantId': 10,
#        'position': {'x': 9811, 'y': 10386},
#        'timeEnemySpentControlled': 132137,
#        'totalGold': 3684,
#        'xp': 4100}},
#      'timestamp': 968925}],
#    'gameId': 6399909863,
#    'participants': [{'participantId': 1,
#      'puuid': '8AunLkgaDU3m47xdnrxE88Aeb62DurhCAJ9QmbL-HtxCQbs_FYiwAMgluYBnVOF8LrEQJycwFfx05Q'},
#     {'participantId': 2,
#      'puuid': 'B-aTy61h3O6Oe5ZD80WZQh5idMTon3ZczhAW-MGJHCml4PGaRSdcEYTSLV0RZwbDtdQn5N7OjxImaQ'},
#     {'participantId': 3,
#      'puuid': 'MC9KsS35GrZS77MPukC6F5dJTJCXBtxXFyKZF64QMIH4AYT3iEl6gnYq_Ejjl_x_eLGQAHOPNpB2Ng'},
#     {'participantId': 4,
#      'puuid': 'nFpv88ijjLjVR_RG19pi7JpIyZHUWfew62mOibdLKsG2TO8DynlDlAKSBtF-NJ3cqzHX33fNbQrhsQ'},
#     {'participantId': 5,
#      'puuid': 'hL_QTu6-avL_IlgFXkV4Vy2d_jeePAt0eS-Lh4czTwvxcEW-RnZzbQZgAxdNXTTHa8tWWxu9I-KQ8Q'},
#     {'participantId': 6,
#      'puuid': 'O0JEmHM7IYGetsw4DhFF140O420ycBCTLMaEqK2BtvXIyEM3-r2S5IqgnB1eudwa7JUON_zsg4nSNA'},
#     {'participantId': 7,
#      'puuid': 'ZWhJwDalbfURuNr7NlZ1oR3IEOlc1m9Ypz0SAH5c2ltw7RBMclfREqrYGfhJkZjeXYEaAgy-W0-I8g'},
#     {'participantId': 8,
#      'puuid': 'S5nxI11RytiYvyRe_u54PHEEvmMCTsxBViCUM-VOUg18p1pVVB-8WNFcATVSiyyS4-UNPSxlrQmHnQ'},
#     {'participantId': 9,
#      'puuid': 'yqyIKMKb76xxNPv1UAOUrt01h9bebodGYUsHh3DSsdAYzQikeK93hPWkJWbvhj_R_yeSqQfg-JVJwQ'},
#     {'participantId': 10,
#      'puuid': 'dkwk4XGaTisr4TKrXEOgb_vO5Lp6K8m-ut4TNIvxwQ7PX_URECtdmpdxn-a5K_CO2D_QG0yetoEk2A'}]}})

# %%
df_creates = []
for s in tqdm(summoner_name_lst[:5]):
    try:
        puuid=get_puuid(s,riot_api_key)
        match_ids = get_match_id(puuid,riot_api_key)
        matches,timeline=get_matches_timelines(match_ids[0],riot_api_key)
        time.sleep(1)
        df_creates.append([match_ids[0],matches,timeline])
    except:
        continue
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:09<00:00,  1.93s/it]

# %%
df = pd.DataFrame(df_creates,columns = ['gemeid', 'matches', 'timeline'])

# %%
df
# Out:
#           gemeid                                            matches  \
# 0  KR_6403696069  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1  KR_6403597665  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2  KR_6402731925  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3  KR_6391207496  {'metadata': {'dataVersion': '2', 'matchId': '...
#
#                                             timeline
# 0  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3  {'metadata': {'dataVersion': '2', 'matchId': '...

# %%
df.iloc[0].matches['info']['participants'][0]['kills']
# Out:
# 2

# %%
df.iloc[i]['gemeid']
# Out:
# 'KR_6391207496'

# %%
len(df.iloc[i].matches['info']['participants'])
# Out:
# 10

# %%
df.iloc[0].matches['info']['participants'][4]
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 15,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 1,
#   'abilityUses': 234,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 1,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.39304934064174313,
#   'controlWardsPlaced': 7,
#   'damagePerMinute': 296.50683814514446,
#   'damageTakenOnTeamPercentage': 0.079092172939938,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 2,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 1,
#   'earliestBaron': 1504.754345147581,
#   'earliestDragonTakedown': 564.8252956874849,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 1752.56005859375,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 14,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'fasterSupportQuestCompletion': 1,
#   'firstTurretKilledTime': 688.4621943774578,
#   'flawlessAces': 0,
#   'fullTeamTakedown': 2,
#   'gameLength': 1518.0340967854536,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 293.76584703199285,
#   'hadOpenNexus': 0,
#   'highestWardKills': 1,
#   'immobilizeAndKillWithAlly': 3,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 1,
#   'kda': 7.5,
#   'killAfterHiddenWithAlly': 2,
#   'killParticipation': 0.6818181818181818,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killsNearEnemyTurret': 0,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 0,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 0,
#   'landSkillShotsEarlyGame': 15,
#   'laneMinionsFirst10Minutes': 9,
#   'laningPhaseGoldExpAdvantage': 0,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxCsAdvantageOnLaneOpponent': 0,
#   'maxKillDeficit': 1,
#   'maxLevelLeadLaneOpponent': 1,
#   'moreEnemyJungleThanOpponent': 0,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 0,
#   'multikillsAfterAggressiveFlash': 0,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 0,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 15,
#   'playedChampSelectPosition': 1,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 1,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'skillshotsDodged': 8,
#   'skillshotsHit': 47,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 0,
#   'stealthWardsPlaced': 20,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 2,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 15,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 10,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 1,
#   'teamDamagePercentage': 0.09885740092438294,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 1,
#   'threeWardsOneSweeperCount': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 4,
#   'turretTakedowns': 2,
#   'turretsTakenWithRiftHerald': 5,
#   'twentyMinionsIn3SecondsCount': 1,
#   'unseenRecalls': 0,
#   'visionScoreAdvantageLaneOpponent': 0.6906365156173706,
#   'visionScorePerMinute': 2.737232589928455,
#   'wardTakedowns': 15,
#   'wardTakedownsBefore20M': 9,
#   'wardsGuarded': 0},
#  'champExperience': 9257,
#  'champLevel': 12,
#  'championId': 26,
#  'championName': 'Zilean',
#  'championTransform': 0,
#  'commandPings': 1,
#  'consumablesPurchased': 9,
#  'damageDealtToBuildings': 988,
#  'damageDealtToObjectives': 2773,
#  'damageDealtToTurrets': 988,
#  'damageSelfMitigated': 5658,
#  'dangerPings': 0,
#  'deaths': 2,
#  'detectorWardsPlaced': 7,
#  'doubleKills': 0,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'enemyMissingPings': 12,
#  'enemyVisionPings': 11,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': True,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': True,
#  'getBackPings': 0,
#  'goldEarned': 7432,
#  'goldSpent': 6025,
#  'holdPings': 0,
#  'individualPosition': 'UTILITY',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 0,
#  'inhibitorsLost': 0,
#  'item0': 1028,
#  'item1': 3853,
#  'item2': 0,
#  'item3': 3916,
#  'item4': 3110,
#  'item5': 3111,
#  'item6': 3364,
#  'itemsPurchased': 21,
#  'killingSprees': 0,
#  'kills': 0,
#  'lane': 'BOTTOM',
#  'largestCriticalStrike': 0,
#  'largestKillingSpree': 0,
#  'largestMultiKill': 0,
#  'longestTimeSpentLiving': 964,
#  'magicDamageDealt': 16958,
#  'magicDamageDealtToChampions': 6515,
#  'magicDamageTaken': 1543,
#  'needVisionPings': 0,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'onMyWayPings': 3,
#  'participantId': 5,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8229, 'var1': 785, 'var2': 0, 'var3': 0},
#      {'perk': 8226, 'var1': 250, 'var2': 541, 'var3': 0},
#      {'perk': 8234, 'var1': 7746, 'var2': 0, 'var3': 0},
#      {'perk': 8237, 'var1': 506, 'var2': 0, 'var3': 0}],
#     'style': 8200},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8009, 'var1': 2913, 'var2': 0, 'var3': 0},
#      {'perk': 8014, 'var1': 93, 'var2': 0, 'var3': 0}],
#     'style': 8000}]},
#  'physicalDamageDealt': 2562,
#  'physicalDamageDealtToChampions': 986,
#  'physicalDamageTaken': 3910,
#  'profileIcon': 3017,
#  'pushPings': 0,
#  'puuid': 'YJRULGNcyorsTqiLlGB4cti1n6RK3ruC8GsMjiXZLJy5RmJB9evp8OxFrLS9Rbc5g4MLIz6MtgWyoQ',
#  'quadraKills': 0,
#  'riotIdName': '',
#  'riotIdTagline': '',
#  'role': 'SUPPORT',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 112,
#  'spell2Casts': 45,
#  'spell3Casts': 75,
#  'spell4Casts': 2,
#  'summoner1Casts': 4,
#  'summoner1Id': 3,
#  'summoner2Casts': 2,
#  'summoner2Id': 4,
#  'summonerId': 'AF6TruAZErQkQw0Vtnx_WdreCH0Qcl7TNaNQs6xpugyiOg',
#  'summonerLevel': 353,
#  'summonerName': '시계왕',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'UTILITY',
#  'timeCCingOthers': 13,
#  'timePlayed': 1517,
#  'totalDamageDealt': 19521,
#  'totalDamageDealtToChampions': 7501,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 6229,
#  'totalHeal': 2006,
#  'totalHealsOnTeammates': 1752,
#  'totalMinionsKilled': 28,
#  'totalTimeCCDealt': 190,
#  'totalTimeSpentDead': 36,
#  'totalUnitsHealed': 3,
#  'tripleKills': 0,
#  'trueDamageDealt': 0,
#  'trueDamageDealtToChampions': 0,
#  'trueDamageTaken': 774,
#  'turretKills': 0,
#  'turretTakedowns': 2,
#  'turretsLost': 1,
#  'unrealKills': 0,
#  'visionClearedPings': 3,
#  'visionScore': 69,
#  'visionWardsBoughtInGame': 7,
#  'wardsKilled': 15,
#  'wardsPlaced': 27,
#  'win': True}

# %% [markdown]
# # for문을 통해 df안의 모든 matches 컬럼을 돌아서
#
# # [match_id , chapionName, kils, deaths, assists]
#
# # 매치, 이름 킬 뎃 어시
#
# # kda_df라는 DataFrame 만들기

# %%
df.iloc[0].matches['info']['participants'][0]['championName']
# Out:
# 'KSante'

# %%
kda = []
for i in range(len(df)):
    for j in range(len(df.iloc[i].matches['info']['participants'])):
        full = []
        full.append(df.iloc[i]['gemeid'])
        full.append(df.iloc[i].matches['info']['participants'][j]['championName'])
        full.append(df.iloc[i].matches['info']['participants'][j]['kills'])
        full.append(df.iloc[i].matches['info']['participants'][j]['deaths'])
        full.append(df.iloc[i].matches['info']['participants'][j]['assists'])
        kda.append(full)

# %%
pd
# Out:
# [['KR_6403696069', 'KSante', 2, 1, 6],
#  ['KR_6403696069', 'Graves', 7, 1, 6],
#  ['KR_6403696069', 'Akali', 4, 3, 2],
#  ['KR_6403696069', 'Jinx', 9, 2, 9],
#  ['KR_6403696069', 'Zilean', 0, 2, 15],
#  ['KR_6403696069', 'Fiora', 2, 3, 1],
#  ['KR_6403696069', 'Rengar', 2, 5, 2],
#  ['KR_6403696069', 'Veigar', 2, 2, 1],
#  ['KR_6403696069', 'Xayah', 2, 8, 2],
#  ['KR_6403696069', 'Rakan', 1, 4, 5],
#  ['KR_6403597665', 'Alistar', 4, 5, 8],
#  ['KR_6403597665', 'Karthus', 8, 3, 11],
#  ['KR_6403597665', 'Qiyana', 13, 3, 5],
#  ['KR_6403597665', 'Xayah', 17, 4, 8],
#  ['KR_6403597665', 'Nautilus', 2, 3, 16],
#  ['KR_6403597665', 'Warwick', 3, 8, 3],
#  ['KR_6403597665', 'Nidalee', 4, 7, 2],
#  ['KR_6403597665', 'Zed', 6, 6, 2],
#  ['KR_6403597665', 'Caitlyn', 4, 12, 1],
#  ['KR_6403597665', 'Morgana', 1, 11, 6],
#  ['KR_6402731925', 'Rumble', 2, 5, 1],
#  ['KR_6402731925', 'Graves', 1, 6, 3],
#  ['KR_6402731925', 'Viktor', 2, 4, 1],
#  ['KR_6402731925', 'Zeri', 4, 5, 3],
#  ['KR_6402731925', 'Rakan', 1, 4, 4],
#  ['KR_6402731925', 'Jax', 4, 2, 5],
#  ['KR_6402731925', 'Hecarim', 11, 1, 9],
#  ['KR_6402731925', 'Annie', 5, 2, 9],
#  ['KR_6402731925', 'Kaisa', 3, 1, 7],
#  ['KR_6402731925', 'Nautilus', 1, 4, 11],
#  ['KR_6391207496', 'Jayce', 7, 6, 8],
#  ['KR_6391207496', 'JarvanIV', 8, 3, 13],
#  ['KR_6391207496', 'Viktor', 6, 2, 5],
#  ['KR_6391207496', 'Varus', 6, 3, 8],
#  ['KR_6391207496', 'Blitzcrank', 3, 3, 15],
#  ['KR_6391207496', 'Fiora', 7, 7, 2],
#  ['KR_6391207496', 'LeeSin', 5, 7, 4],
#  ['KR_6391207496', 'Akali', 3, 4, 2],
#  ['KR_6391207496', 'Ezreal', 1, 5, 1],
#  ['KR_6391207496', 'Ashe', 1, 7, 5]]

# %%
kda_df = pd.DataFrame(kda ,columns = ['match_id', 'championName', 'kills','deaths','assists'])

# %%
kda_df
# Out:
#          match_id championName  kills  deaths  assists
# 0   KR_6403696069       KSante      2       1        6
# 1   KR_6403696069       Graves      7       1        6
# 2   KR_6403696069        Akali      4       3        2
# 3   KR_6403696069         Jinx      9       2        9
# 4   KR_6403696069       Zilean      0       2       15
# 5   KR_6403696069        Fiora      2       3        1
# 6   KR_6403696069       Rengar      2       5        2
# 7   KR_6403696069       Veigar      2       2        1
# 8   KR_6403696069        Xayah      2       8        2
# 9   KR_6403696069        Rakan      1       4        5
# 10  KR_6403597665      Alistar      4       5        8
# 11  KR_6403597665      Karthus      8       3       11
# 12  KR_6403597665       Qiyana     13       3        5
# 13  KR_6403597665        Xayah     17       4        8
# 14  KR_6403597665     Nautilus      2       3       16
# 15  KR_6403597665      Warwick      3       8        3
# 16  KR_6403597665      Nidalee      4       7        2
# 17  KR_6403597665          Zed      6       6        2
# 18  KR_6403597665      Caitlyn      4      12        1
# 19  KR_6403597665      Morgana      1      11        6
# 20  KR_6402731925       Rumble      2       5        1
# 21  KR_6402731925       Graves      1       6        3
# 22  KR_6402731925       Viktor      2       4        1
# 23  KR_6402731925         Zeri      4       5        3
# 24  KR_6402731925        Rakan      1       4        4
# 25  KR_6402731925          Jax      4       2        5
# 26  KR_6402731925      Hecarim     11       1        9
# 27  KR_6402731925        Annie      5       2        9
# 28  KR_6402731925        Kaisa      3       1        7
# 29  KR_6402731925     Nautilus      1       4       11
# 30  KR_6391207496        Jayce      7       6        8
# 31  KR_6391207496     JarvanIV      8       3       13
# 32  KR_6391207496       Viktor      6       2        5
# 33  KR_6391207496        Varus      6       3        8
# 34  KR_6391207496   Blitzcrank      3       3       15
# 35  KR_6391207496        Fiora      7       7        2
# 36  KR_6391207496       LeeSin      5       7        4
# 37  KR_6391207496        Akali      3       4        2
# 38  KR_6391207496       Ezreal      1       5        1
# 39  KR_6391207496         Ashe      1       7        5

# %%
kda_df['kda'] = round((kda_df.kills+kda_df.assists)/kda_df.deaths,2)

# %%
kda_df
# Out:
#          match_id championName  kills  deaths  assists    kda
# 0   KR_6403696069       KSante      2       1        6   8.00
# 1   KR_6403696069       Graves      7       1        6  13.00
# 2   KR_6403696069        Akali      4       3        2   2.00
# 3   KR_6403696069         Jinx      9       2        9   9.00
# 4   KR_6403696069       Zilean      0       2       15   7.50
# 5   KR_6403696069        Fiora      2       3        1   1.00
# 6   KR_6403696069       Rengar      2       5        2   0.80
# 7   KR_6403696069       Veigar      2       2        1   1.50
# 8   KR_6403696069        Xayah      2       8        2   0.50
# 9   KR_6403696069        Rakan      1       4        5   1.50
# 10  KR_6403597665      Alistar      4       5        8   2.40
# 11  KR_6403597665      Karthus      8       3       11   6.33
# 12  KR_6403597665       Qiyana     13       3        5   6.00
# 13  KR_6403597665        Xayah     17       4        8   6.25
# 14  KR_6403597665     Nautilus      2       3       16   6.00
# 15  KR_6403597665      Warwick      3       8        3   0.75
# 16  KR_6403597665      Nidalee      4       7        2   0.86
# 17  KR_6403597665          Zed      6       6        2   1.33
# 18  KR_6403597665      Caitlyn      4      12        1   0.42
# 19  KR_6403597665      Morgana      1      11        6   0.64
# 20  KR_6402731925       Rumble      2       5        1   0.60
# 21  KR_6402731925       Graves      1       6        3   0.67
# 22  KR_6402731925       Viktor      2       4        1   0.75
# 23  KR_6402731925         Zeri      4       5        3   1.40
# 24  KR_6402731925        Rakan      1       4        4   1.25
# 25  KR_6402731925          Jax      4       2        5   4.50
# 26  KR_6402731925      Hecarim     11       1        9  20.00
# 27  KR_6402731925        Annie      5       2        9   7.00
# 28  KR_6402731925        Kaisa      3       1        7  10.00
# 29  KR_6402731925     Nautilus      1       4       11   3.00
# 30  KR_6391207496        Jayce      7       6        8   2.50
# 31  KR_6391207496     JarvanIV      8       3       13   7.00
# 32  KR_6391207496       Viktor      6       2        5   5.50
# 33  KR_6391207496        Varus      6       3        8   4.67
# 34  KR_6391207496   Blitzcrank      3       3       15   6.00
# 35  KR_6391207496        Fiora      7       7        2   1.29
# 36  KR_6391207496       LeeSin      5       7        4   1.29
# 37  KR_6391207496        Akali      3       4        2   1.25
# 38  KR_6391207496       Ezreal      1       5        1   0.40
# 39  KR_6391207496         Ashe      1       7        5   0.86

# %%
kda_df['kda'][kda_df.kda == np.inf] = 'Perfect'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8272\1273917366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kda_df['kda'][kda_df.kda == np.inf] = 'Perfect'

# %%
kda_df
# Out:
#          match_id championName  kills  deaths  assists    kda
# 0   KR_6403696069       KSante      2       1        6   8.00
# 1   KR_6403696069       Graves      7       1        6  13.00
# 2   KR_6403696069        Akali      4       3        2   2.00
# 3   KR_6403696069         Jinx      9       2        9   9.00
# 4   KR_6403696069       Zilean      0       2       15   7.50
# 5   KR_6403696069        Fiora      2       3        1   1.00
# 6   KR_6403696069       Rengar      2       5        2   0.80
# 7   KR_6403696069       Veigar      2       2        1   1.50
# 8   KR_6403696069        Xayah      2       8        2   0.50
# 9   KR_6403696069        Rakan      1       4        5   1.50
# 10  KR_6403597665      Alistar      4       5        8   2.40
# 11  KR_6403597665      Karthus      8       3       11   6.33
# 12  KR_6403597665       Qiyana     13       3        5   6.00
# 13  KR_6403597665        Xayah     17       4        8   6.25
# 14  KR_6403597665     Nautilus      2       3       16   6.00
# 15  KR_6403597665      Warwick      3       8        3   0.75
# 16  KR_6403597665      Nidalee      4       7        2   0.86
# 17  KR_6403597665          Zed      6       6        2   1.33
# 18  KR_6403597665      Caitlyn      4      12        1   0.42
# 19  KR_6403597665      Morgana      1      11        6   0.64
# 20  KR_6402731925       Rumble      2       5        1   0.60
# 21  KR_6402731925       Graves      1       6        3   0.67
# 22  KR_6402731925       Viktor      2       4        1   0.75
# 23  KR_6402731925         Zeri      4       5        3   1.40
# 24  KR_6402731925        Rakan      1       4        4   1.25
# 25  KR_6402731925          Jax      4       2        5   4.50
# 26  KR_6402731925      Hecarim     11       1        9  20.00
# 27  KR_6402731925        Annie      5       2        9   7.00
# 28  KR_6402731925        Kaisa      3       1        7  10.00
# 29  KR_6402731925     Nautilus      1       4       11   3.00
# 30  KR_6391207496        Jayce      7       6        8   2.50
# 31  KR_6391207496     JarvanIV      8       3       13   7.00
# 32  KR_6391207496       Viktor      6       2        5   5.50
# 33  KR_6391207496        Varus      6       3        8   4.67
# 34  KR_6391207496   Blitzcrank      3       3       15   6.00
# 35  KR_6391207496        Fiora      7       7        2   1.29
# 36  KR_6391207496       LeeSin      5       7        4   1.29
# 37  KR_6391207496        Akali      3       4        2   1.25
# 38  KR_6391207496       Ezreal      1       5        1   0.40
# 39  KR_6391207496         Ashe      1       7        5   0.86

# %%
query = """
create table lol_kda (gameid varchar(20), championName varchar(30), kills int,
deaths int, assists int, kda varchar(20))
"""
#Oracle버전

# %%
mu.db_open()
mu.oracle_execute(query)
mu.oracle_close()
# Out:
# oracle open!
# '오라클 닫힘'

# %%
query_mysql ="""
create table lol_kda (gameid varchar(20), championName varchar(30), kills int,
deaths int, assists int, kda varchar(20))
"""

# %%
conn = mu.connect_mysql('icia')
mu.mysql_execute(query_mysql,conn)
conn.close()

# %%
def insert(x):
    query =( 
    f'insert into lol_kda(gameid,championName,kills,deaths,assists,kda)'
    f'values({repr(x.match_id)},{repr(x.championName)},{x.kills},{x.deaths},{x.assists},{repr(x.kda)})'
    )
    mu.oracle_execute(query)
    mu.mysql_execute(query,conn)
    return

# %%
tqdm.pandas()

# %%
mu.db_open()
conn = mu.connect_mysql('icia')
kda_df.progress_apply(lambda x: insert(x), axis=1)
# Out:
# oracle open!
# 100%|█████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 211.56it/s]
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# dtype: object

# %%
a1 = mu.oracle_execute('select * from lol_kda')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
a1
# Out:
#            GAMEID CHAMPIONNAME  KILLS  DEATHS  ASSISTS   KDA
# 0   KR_6403696069       KSante      2       1        6     8
# 1   KR_6403696069       Graves      7       1        6    13
# 2   KR_6403696069        Akali      4       3        2     2
# 3   KR_6403696069         Jinx      9       2        9     9
# 4   KR_6403696069       Zilean      0       2       15   7.5
# 5   KR_6403696069        Fiora      2       3        1     1
# 6   KR_6403696069       Rengar      2       5        2    .8
# 7   KR_6403696069       Veigar      2       2        1   1.5
# 8   KR_6403696069        Xayah      2       8        2    .5
# 9   KR_6403696069        Rakan      1       4        5   1.5
# 10  KR_6403597665      Alistar      4       5        8   2.4
# 11  KR_6403597665      Karthus      8       3       11  6.33
# 12  KR_6403597665       Qiyana     13       3        5     6
# 13  KR_6403597665        Xayah     17       4        8  6.25
# 14  KR_6403597665     Nautilus      2       3       16     6
# 15  KR_6403597665      Warwick      3       8        3   .75
# 16  KR_6403597665      Nidalee      4       7        2   .86
# 17  KR_6403597665          Zed      6       6        2  1.33
# 18  KR_6403597665      Caitlyn      4      12        1   .42
# 19  KR_6403597665      Morgana      1      11        6   .64
# 20  KR_6402731925       Rumble      2       5        1    .6
# 21  KR_6402731925       Graves      1       6        3   .67
# 22  KR_6402731925       Viktor      2       4        1   .75
# 23  KR_6402731925         Zeri      4       5        3   1.4
# 24  KR_6402731925        Rakan      1       4        4  1.25
# 25  KR_6402731925          Jax      4       2        5   4.5
# 26  KR_6402731925      Hecarim     11       1        9    20
# 27  KR_6402731925        Annie      5       2        9     7
# 28  KR_6402731925        Kaisa      3       1        7    10
# 29  KR_6402731925     Nautilus      1       4       11     3
# 30  KR_6391207496        Jayce      7       6        8   2.5
# 31  KR_6391207496     JarvanIV      8       3       13     7
# 32  KR_6391207496       Viktor      6       2        5   5.5
# 33  KR_6391207496        Varus      6       3        8  4.67
# 34  KR_6391207496   Blitzcrank      3       3       15     6
# 35  KR_6391207496        Fiora      7       7        2  1.29
# 36  KR_6391207496       LeeSin      5       7        4  1.29
# 37  KR_6391207496        Akali      3       4        2  1.25
# 38  KR_6391207496       Ezreal      1       5        1    .4
# 39  KR_6391207496         Ashe      1       7        5   .86

# %%
a2 = pd.DataFramase(mu.mysql_execute_dict('select * from lol_kda',conn))

# %%
a2
# Out:
#            gameid championName  kills  deaths  assists   kda
# 0   KR_6403696069       KSante      2       1        6   8.0
# 1   KR_6403696069       Graves      7       1        6  13.0
# 2   KR_6403696069        Akali      4       3        2   2.0
# 3   KR_6403696069         Jinx      9       2        9   9.0
# 4   KR_6403696069       Zilean      0       2       15   7.5
# 5   KR_6403696069        Fiora      2       3        1   1.0
# 6   KR_6403696069       Rengar      2       5        2   0.8
# 7   KR_6403696069       Veigar      2       2        1   1.5
# 8   KR_6403696069        Xayah      2       8        2   0.5
# 9   KR_6403696069        Rakan      1       4        5   1.5
# 10  KR_6403597665      Alistar      4       5        8   2.4
# 11  KR_6403597665      Karthus      8       3       11  6.33
# 12  KR_6403597665       Qiyana     13       3        5   6.0
# 13  KR_6403597665        Xayah     17       4        8  6.25
# 14  KR_6403597665     Nautilus      2       3       16   6.0
# 15  KR_6403597665      Warwick      3       8        3  0.75
# 16  KR_6403597665      Nidalee      4       7        2  0.86
# 17  KR_6403597665          Zed      6       6        2  1.33
# 18  KR_6403597665      Caitlyn      4      12        1  0.42
# 19  KR_6403597665      Morgana      1      11        6  0.64
# 20  KR_6402731925       Rumble      2       5        1   0.6
# 21  KR_6402731925       Graves      1       6        3  0.67
# 22  KR_6402731925       Viktor      2       4        1  0.75
# 23  KR_6402731925         Zeri      4       5        3   1.4
# 24  KR_6402731925        Rakan      1       4        4  1.25
# 25  KR_6402731925          Jax      4       2        5   4.5
# 26  KR_6402731925      Hecarim     11       1        9  20.0
# 27  KR_6402731925        Annie      5       2        9   7.0
# 28  KR_6402731925        Kaisa      3       1        7  10.0
# 29  KR_6402731925     Nautilus      1       4       11   3.0
# 30  KR_6391207496        Jayce      7       6        8   2.5
# 31  KR_6391207496     JarvanIV      8       3       13   7.0
# 32  KR_6391207496       Viktor      6       2        5   5.5
# 33  KR_6391207496        Varus      6       3        8  4.67
# 34  KR_6391207496   Blitzcrank      3       3       15   6.0
# 35  KR_6391207496        Fiora      7       7        2  1.29
# 36  KR_6391207496       LeeSin      5       7        4  1.29
# 37  KR_6391207496        Akali      3       4        2  1.25
# 38  KR_6391207496       Ezreal      1       5        1   0.4
# 39  KR_6391207496         Ashe      1       7        5  0.86

# %%
lst = []

# %%
puuid = mu.get_puuid('hide on bush')
match_ids = mu.get_match_id(puuid,5)
for match_id in tqdm((match_ids)):
    matches , timeline = mu.get_matches_timelines(match_id)
    tmp.append(match_id,timeline)
    lst.append([match_id,matches,timeline])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6984\214562597.py in <module>
# ----> 1 puuid = mu.get_puuid('hide on bush')
#       2 match_ids = mu.get_match_id(puuid,5)
#       3 for match_id in tqdm((match_ids)):
#       4     matches , timeline = mu.get_matches_timelines(match_id)
#       5     tmp.append(match_id,timeline)
#
# TypeError: get_puuid() missing 1 required positional argument: 'riot_api_key'

# %%
df = pd.DataFrame(lst, columns = ['match_id', 'matches','timeline'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9164\1828679160.py in <module>
# ----> 1 df = pd.DataFrame(df, columns = ['match_id', 'matches','timeline'])
#
# NameError: name 'df' is not defined
